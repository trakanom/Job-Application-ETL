# %%
import numpy as np
import re
import nltk
from sklearn import datasets
nltk.download('stopwords')
from nltk.corpus import stopwords
import pickle
import email
import os
from bs4 import BeautifulSoup 
from models.config.cleaning_methods import decode_mime_stuff
import datetime as dt
from models.config.filter_methods import testing_platform_filters
from models.config.CONSTS import CONSTS
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\mikaw\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# def try_method(label, method, data):
#     try:
#         data_point = {label:method(data)}
#     except:
#         data_point = {label:}



platform_identification = {
    "linkedin.com":"LinkedIn",
    "untapped.gg":"Untapped",
    "ziprecruiter.com":"ZipRecruiter",
    "squarepeg.com":"SquarePeg",
}

platform_filters = {
    'LinkedIn' : {
        'email': {
            'match' : lambda x : "X-LinkedIn-Template" in x['headers'].keys(),
            'scan' : {
                'date'        : lambda x : dt.datetime.strptime(re.sub(r"\s\(\w{3}\)","", x['headers']['Received'].split(';')[1].split(",")[1].strip()), '%d %b %Y %H:%M:%S %z').strftime(CONSTS['date_format']), #standard to gmail format; gets datetime of email sent
                'update_type' : lambda x : re.search(r'jobs?_appli\w{4,6}_([a-z]+)', x['headers']['X-LinkedIn-Template']).group(1), #type of email update
                'subject'     : lambda x : decode_mime_stuff(x['headers']['Subject']).replace(",","").replace(".","").replace("&", "and").split(":")[0],
                # 'title' : lambda x : re.search(x,r''), #title of job posting
                # 'company' : lambda x : re.search(x,r''), #company name
            },
            'applied' : {
                'PostID'   : lambda x : re.search(r"(\d{10})",x['body'].find("a", href=re.compile(r"https://www.linkedin.com/comm/jobs/view/"))['href']).group(1),
                'url'      : lambda x : 'https://www.linkedin.com/jobs/view/{}/'.format(re.search(r"(\d{10})",x['body'].find("a", href=re.compile(r"https://www.linkedin.com/comm/jobs/view/"))['href']).group(1)),
                'position' : lambda x : x['subject'].split(" at ")[0],
                'company'  : lambda x : x['subject'].split(" at ")[1],
            },
            'viewed' : {
                'PostID'   : lambda x : re.search(re.compile(r'jobPostingId%3D(\d{10})%26pivotType%3Dsim'), x['body'].find("a", href=re.compile(r'jobPostingId%3D(\d{10})%26pivotType%3Dsim'))['href']).group(1), #re.search(re.compile(r'jobPostingId%3D(\d{10})%26pivotType%3Dsim', flags = re.DOTALL), x['body']).group(1),
                'position' : lambda x : x['subject'].split(" was viewed by ")[0],
                'company'  : lambda x : x['subject'].split(" was viewed by ")[1],
            },
            'rejected' : {
                # 'original_date_applied' : lambda x: dt.datetime.strptime(re.search(re.compile(r"Applied on (\w{3,9} \d{1,3}, \d{4})"), x['body']).group(1),'%B %d, %Y').strftime(CONSTS['date_format']),
                'position' : lambda x : x['subject'].split(" at ")[0],
                'company'  : lambda x : x['subject'].split(" at ")[1],
            },
        },
    },
    'TEMPLATE' : {
        'email': {
            'match' : lambda x: x,
            'scan' : {
                'date'        : lambda x: x,
                'update_type' : lambda x: x,
                'subject'     : lambda x: x,
                # 'title' : lambda x: x,
                # 'company' : lambda x: x,
            },
            'applied' : {
                'PostID'   : lambda x: x,
                'url'      : lambda x: x,
                'position' : lambda x: x,
                'company'  : lambda x: x,
            },
            'viewed' : {
                'PostID'   : lambda x: x,
                'position' : lambda x: x,
                'company'  : lambda x: x,
            },
            'rejected' : {
                'position' : lambda x: x,
                'company'  : lambda x: x,
            },
        },
    },
}

def cleaning_function_decorator(func):
    def wrapper(*args, **kwargs):
        results = func(*args,**kwargs)
        return clean_data(results)
    
    def clean_string(text):
        replace_chars = [('\n'," "), (re.compile(r"\s+")," ")]
        results = text
        for item in replace_chars:
            results = re.sub(item[0],item[1], results)
        results = results.strip()
        return results
    
    def clean_data(input_item):
        '''
        Recursive function that cleans strings 
        '''
        type_list = {"int":int, "str":str, "dict":dict, "list":list,}
        result_type = max([label if isinstance(input_item, type_example) else "" for (label,type_example) in type_list.items()]) #creates a list that checks the type of the input and returns a string representation of the type. Mostly using this so I can use match/case instead of an If/Else ladder.
        match result_type:
            case "str":
                print("string")
                if len(input_item)<128 and re.search(r"\d",input_item):
                    try: #This is going to hurt performance, but this will allow numerical strings to be relabeled as int or float
                        try:
                            return int(input_item.strip(","))
                        except:
                            return float(input_item.strip(","))
                    except:
                        return clean_string(input_item)
                return clean_string(input_item)
            case "dict":
                print("dictionary")
                input_item = {label:clean_data(item) for (label,item) in input_item.items()}
            case "list":
                print("list")
                return [clean_data(item) for item in input_item]
            case "int":
                print("int")
            case "float":
                print("float")
            case _:
                print(result_type)
        return input_item
    return wrapper

def handle_comprehension_errors(input_data, method_list):
    if "errors" not in input_data.keys():
        input_data |= {"errors":{}}
    for data_label in method_list: #loops through each data_label 
        try:
            input_data.update({data_label : method_list[data_label](input_data)}) #applies filter to captured data and inserts the key-value pair into input_data
        except Exception as e:
            input_data.update({data_label : None}) #If error, fills in value with null
            input_data["errors"].update({data_label:e}) #
    return input_data


def load_emails(directory):
    cached_emails = []
    file_list = os.listdir(directory)
    file_list = [file for file in file_list if ".eml" in file] #file not in read_files and 
    for item in file_list:
        path = directory+item
        with open(path, encoding="utf-8") as file:
            results = email.message_from_file(file)
            if results.is_multipart:
                # results = results.get_payload()
                body = results.get_payload()[1]
                print("Multipart")
            else:
                # results = results.get_payload()
                body = results.get_payload()
                print("Not Multipart")
            # print(results)
            body = re.sub(r"=$\n","", body.as_string(), flags=re.MULTILINE)
            headers = {part:re.sub(r"\n\s+"," ",value) for (part,value) in results.items()}
            html_contents = BeautifulSoup(body, "html5lib")
            data = { 
                'subject': headers['Subject'],
                'headers': headers,
                'body': html_contents,
                'from': headers['From']
            }
            
            cached_emails.append(data)
    return cached_emails

    
            # print(headers.keys())

def parse_email(data):
    input_method = 'email'

    # print(data['headers']['Subject'])
    sender = data['from'].split("@")[1].strip(">")
    platform = platform_identification[sender] if sender in platform_identification.keys() else "Unknown"
    # platform = 'LinkedIn'
    filters = platform_filters[platform][input_method]
    # filters = testing_platform_filters[platform][input_method]
    
    try:
        if filters['match'](data):
            email_data = {label:method(data) for (label,method) in filters['scan'].items()} #Initializes date, update_type, and subject
            email_data |= {label:method(email_data) for (label,method) in filters[data['update_type']].items()} #processes the above for more data
    except Exception as e:
        print(e, "!!!", data['subject'])
        print("Body: ", data['body'])
    return data


@cleaning_function_decorator
def parse_emails(input_data):
    results = [parse_email(item) for item in input_data]
    return results


    '''
    data = {
        "date:":headers['Received'].split(";")[1],
        "update_type": re.search(r'jobs?_appli\w{4,6}_([a-z]+)',headers['X-LinkedIn-Template']).group(1), 
        "JobID": re.search(r"(\d{10})",html_contents.find("a", href=re.compile(r"https://www.linkedin.com/comm/jobs/view/"))['href']).group(1),
        "Subject": headers['Subject'].replace(",","").replace(".","").replace("&", "and"), #re.search(r"Your? appli(cation|ed) (for|to) (.+)( at|was viewed by)(.+)",headers['Subject']), 
        "From":headers['From'],
        "To":headers['To'],
        # "Body":body,
    }
    # match data['update_type']:
    #     case 'applied':
    #         print(body)
    #         jobID = re.search( r'View job: https:(\S+&jobId=3D(\w+))' , html_contents, flags = re.DOTALL ).group(2)
    #     case 'viewed':
    #         jobID = re.search(r'jobPostingId%3D(\d{10})%26pivotType%3Dsim', html_contents, flags = re.DOTALL).group(1)
    #     case 'rejected':
    #         jobID = None
    #         # find jobID via match, perhaps. Maybe at later stage?
    #     case _:
    #         jobID = None
            
        

    # subject_filtering = re.search(re.compile("Your? appli(cation|ed) (for|to) (.+)( at|was viewed by)(.+)",flags=re.DOTALL),decode_mime_stuff(headers['Subject']))
    split_string = " was viewed by " if data['update_type']=="viewed" else " at "
    position, company = decode_mime_stuff(headers['Subject']).split(split_string)
    more_data = {
        "company": company, #subject_filtering.group(5),
        "position": position, #subject_filtering.group(3),
        "PostURL": 'https://www.linkedin.com/jobs/view/{}/'.format(data['JobID'])
    }
    # "JobID": re.search(r"(\d{10})",html_contents.find("a", href=re.compile(r"https://www.linkedin.com/comm/jobs/view/"))['href']).group(1),
    '''

# %%
@cleaning_function_decorator
def test_function(input_dict):
    # print(input_dict)
    return input_dict

test_results = [{"Test":["123","420.69", "Dick123"],"Frog":"15", "Returns4":lambda x: "4","4":"12"}, {"Frog":"12"} ]

cleaned_results = test_function(test_results)
try:
    assert isinstance(cleaned_results[0]["Test"][1], float), "FAILED: Float not converted"
    assert isinstance(cleaned_results[0]["Test"][0], int), "FAILED: Int not converted"
    assert cleaned_results[0]['Returns4'](9999)=="4", "FAILED: Lambda converted"
    print("PASSED")
    print(cleaned_results)
except AssertionError as e:
    print(e)
# Out:
# list
# dictionary
# list
# string
# string
# string
# string
#
# string
# dictionary
# string
# PASSED
# [{'Test': [123, 420.69, 'Dick123'], 'Frog': 15, 'Returns4': <function <lambda> at 0x0000019F2058BEB0>, '4': 12}, {'Frog': 12}]

# %%
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
import pickle
import os.path
import base64
import email
from bs4 import BeautifulSoup
from dotenv import load_dotenv
import re
def getEmails(credpath, filters = None, maxRequests = None, query=None, nextPage=None, maxResults=None):
    SCOPES = ['https://www.googleapis.com/auth/gmail.readonly']
    maxResults=500 if maxResults is None else maxResults
    cached_data = []
    duplicates = {}
    rejected_values = []
    # Variable creds will store the user access token.
    # If no valid token found, we will create one.
    creds = None
    pickle_path = '.\\dev\\models\\config\\token.pickle'
    pickle_path = re.search(r"(\.(\\\w+)+)\\\w+.json", credpath).group(1)+r"\\token.pickle"
    # The file token.pickle contains the user access token.
    # Check if it exists
    if os.path.exists(pickle_path):

        # Read the token from the file and store it in the variable creds
        with open(pickle_path, 'rb') as token:
            creds = pickle.load(token)

    # If credentials are not available or are invalid, ask the user to log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(f'{credpath}', SCOPES)
            creds = flow.run_local_server(port=0)

        # Save the access token in token.pickle file for the next run
        with open(pickle_path, 'wb') as token:
            pickle.dump(creds, token)

    # Connect to the Gmail API
    service = build('gmail', 'v1', credentials=creds)

    # request a list of all the messages
    if nextPage==None:
        result = service.users().messages().list(userId='me', maxResults=maxResults, q=query).execute()
    else:
        result = service.users().messages().list(userId='me', maxResults=maxResults, q=query, pageToken=nextPage).execute()
    
    # We can also pass maxResults to get any number of emails. Like this:
    # result = service.users().messages().list(maxResults=200, userId='me').execute()
    messages = result.get('messages')
    number_messages = len(messages)
    print("Number of messages for this round: ", number_messages)
    # messages is a list of dictionaries where each dictionary contains a message id.

            
    # iterate through all the messages
    for msg in messages:
        # Get the message from its id
        txt = service.users().messages().get(userId='me', id=msg['id']).execute()
        # Use try-except to avoid any Errors
        # try:
        # Get value of 'payload' from dictionary 'txt'
        payload = txt['payload']
        headers = payload['headers']
        headers = {item['name']:item['value'] for item in headers}
        # Look for Subject and Sender Email in the headers
        filter_stuff = 'X-LinkedIn-Template' in headers.keys() #eventually call all email classification methods #TODO undo hardcoded linkedin
        target_values = ['jobs_applicant_applied', 'email_jobs_job_application_viewed_01', 'email_jobs_application_rejected_01']
        if filter_stuff: # Checks if 
            if headers['X-LinkedIn-Template'] not in target_values:
                rejected_values.append(headers['X-LinkedIn-Template'])
                continue
            print("FILTER RESULT", headers['X-LinkedIn-Template'])
            pass
        else:
            continue
        subject = headers['Subject']
        sender = headers['From']
        
        # The Body of the message is in Encrypted format. So, we have to decode it.
        # Get the data and decode it with base 64 decoder.
        parts = payload.get('parts')[0]
        data = parts['body']['data']
        data = data.replace("-","+").replace("_","/")
        decoded_data = base64.b64decode(data)

        # Now, the data obtained is in lxml. So, we will parse
        # it with BeautifulSoup library
        soup = BeautifulSoup(decoded_data , "lxml")
        body = soup.body()

        # Printing the subject, sender's email and message
        # wrapped_data = [headers,subject,sender,body]
        # print("Headers: ", headers)
        # print("Subject: ", subject)
        # print("From: ", sender)
        # print("Message: ", body)
        # print('\n')
        data = {
            "date_scanned":dt.now(),
            "subject":subject,
            "headers":headers,
            "body":body,
            "from":sender,
        }
        
        cached_data.append(data)
    # except Exception as e:
    # 	print(e,'"EXCEPTION')
    rejected_values = set(rejected_values)
    # print(cached_data)
    print("Duplicates", duplicates)
    print("Unfiltered Emails", rejected_values)
    if number_messages == maxResults: #capped query; need to rerun until all messages are parsed.
        print("Next round of parsing!")
        cached_data.extend(getEmails(credpath=credpath, filters=filters, query=query, nextPage=result['nextPageToken'], maxResults=maxResults)) # Creating a union between these sets. Allows for recursion.
    
    return cached_data

# %%
credential_path = ".\\models\\config\\mika_wisener_gmail_credentials.json"
query=r'from:jobs-noreply@linkedin.com|jobs-listings@linkedin.com -"apply now|to" -"new job|jobs" -"don\'t forget"'
email_cache = getEmails(credpath=credential_path, query=query, maxResults=500)
# Out:
# Number of messages for this round:  500
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT email_jobs_application_rejected_01
# FILTER RESULT email_jobs_job_application_viewed_01
# FILTER RESULT jobs_applicant_applied
# FILTER RESULT jobs_applicant_applied
# Duplicates {}
# Unfiltered Emails {'jobs_jymbii_digest', 'email_jobs_boost_your_application_01', 'email_skillassessments_seekerguidance_01', 'email_job_seeker_launch_pad_final_01'}
# Next round of parsing!
# Number of messages for this round:  91
# Duplicates {}
# Unfiltered Emails {'jobs_jymbii_digest', 'email_jobs_viewed_job_reminder_01', 'email_jobs_first_time_job_seeker_01'}

# %%
#Local Files
email_data = load_emails('.\\data\\test_input_files\\')

email_data = parse_emails(email_data)

# %%
#Cloud
parsed_emails = parse_emails(email_cache)
app_history = pd.DataFrame(parsed_emails)
app_history
# Out:
# Your application to Guidance, Navigation, and Control Engineer  at AeroVironment
# DECODE RESULTS:  Your application to Guidance, Navigation, and Control Engineer  at AeroVironment
# Your application for Senior Software Engineer was viewed by Coachable.
# DECODE RESULTS:  Your application for Senior Software Engineer was viewed by Coachable.
# 'body' !!! Your application for Senior Software Engineer was viewed by Coachable
# Body:  <html><body><p>Your application was viewed
#
# ----------------------------------------------------------------
# Coachable
# Senior Software Engineer
# United States
# ----------------------------------------------------------------
# Job posted by
#
# Bethany R.
# Chief Marketing Officer
# View Profile
# https://www.linkedin.com/comm/in/coffeefueled?midToken=AQEYDKs6Z-Mi0A&amp;midSig=2WESs5ScUM5Gw1&amp;trk=eml-email_jobs_job_application_viewed_01-profile-2-profile_name&amp;trkEmail=eml-email_jobs_job_application_viewed_01-profile-2-profile_name-null-dvkh33%7Ela2o3utd%7Eid-null-neptune%2Fprofile%7Evanity%2Eview&amp;lipi=urn%3Ali%3Apage%3Aemail_email_jobs_job_application_viewed_01%3Bs8KhV54qTNaOqp6En44Mew%3D%3D
# ----------------------------------------------------------------
#
# Coachable
# Professional Training and Coaching
# Are you graduating with a CS or STEM degree without a job lined up?
# Are you ridden with tons of student debt and looking for a great job to pay it off?
# Do you feel lost in the software engineering i...
# Learn more about Coachable
# https://www.linkedin.com/e/v2?e=dvkh33-la2o3utd-id&amp;lipi=urn%3Ali%3Apage%3Aemail_email_jobs_job_application_viewed_01%3Bs8KhV54qTNaOqp6En44Mew%3D%3D&amp;t=bzo&amp;midToken=AQEYDKs6Z-Mi0A&amp;midSig=2WESs5ScUM5Gw1&amp;ek=email_jobs_job_application_viewed_01&amp;li=9&amp;m=company&amp;ts=company&amp;companyId=14047553
# ----------------------------------------------------------------
# Your saved jobs
#
# Expires in 15 days
# Model-Based Systems Engineer, Junior
# Booz Allen Hamilton - Charleston, South Carolina, United States
#
# ----------------------------------------------------------------
# Expires in 15 days
# Remote Python Developer
# Piper Companies - United States
#
# ----------------------------------------------------------------
# See all saved jobs
# https://www.linkedin.com/e/v2?e=dvkh33-la2o3utd-id&amp;lipi=urn%3Ali%3Apage%3Aemail_email_jobs_job_application_viewed_01%3Bs8KhV54qTNaOqp6En44Mew%3D%3D&amp;t=plh&amp;midToken=AQEYDKs6Z-Mi0A&amp;ek=email_jobs_job_application_viewed_01&amp;urlhash=CU-E&amp;url=https%3A%2F%2Fwww%2Elinkedin%2Ecom%2Fjobs%2Fsaved%2F
# ----------------------------------------------------------------
# Similar jobs
# Software Developer, Security
# BitPay - United States
#
# ----------------------------------------------------------------
# Business Intelligence Developer
# Florida Orthopaedic Institute - Tampa, Florida, United States
#
# ----------------------------------------------------------------
# Python Developer
# EA Team Inc - United States
#
# ----------------------------------------------------------------
# See more jobs
# https://www.linkedin.com/e/v2?e=dvkh33-la2o3utd-id&amp;lipi=urn%3Ali%3Apage%3Aemail_email_jobs_job_application_viewed_01%3Bs8KhV54qTNaOqp6En44Mew%3D%3D&amp;t=plh&amp;midToken=AQEYDKs6Z-Mi0A&amp;ek=email_jobs_job_application_viewed_01&amp;urlhash=n3Mu&amp;url=https%3A%2F%2Fwww%2Elinkedin%2Ecom%2Fjobs%2Fsearch%2F%3FjobPostingId%3D3324247147%26pivotType%3Dsim
# ----------------------------------------------------------------
#
#
#
#
#
#
#
# Message
#
#
# .....................................
#
# Unsubscribe: https://www.linkedin.com/e/v2?e=dvkh33-la2o3utd-id&amp;t=lun&amp;midToken=AQEYDKs6Z-Mi0A&amp;midSig=2WESs5ScUM5Gw1&amp;ek=email_jobs_job_application_viewed_01&amp;li=25&amp;m=unsub&amp;ts=unsub&amp;eid=dvkh33-la2o3utd-id&amp;loid=AQFOHG1BFAMVVAAAAYRDUP901B7pbfIQLDyjptPdg9qRgHwmZf_1EzmiQhoAOW24V6nt9HS5vMlFb3FY30-HRLZotaDXz1XM574tlOzKl69AhvBOD8rE6A
#
# Help: https://www.linkedin.com/e/v2?e=dvkh33-la2o3utd-id&amp;lipi=urn%3Ali%3Apage%3Aemail_email_jobs_job_application_viewed_01%3Bs8KhV54qTNaOqp6En44Mew%3D%3D&amp;a=customerServiceUrl&amp;midToken=AQEYDKs6Z-Mi0A&amp;midSig=2WESs5ScUM5Gw1&amp;ek=email_jobs_job_application_viewed_01&amp;li=24&amp;m=footer&amp;ts=help&amp;articleId=67
#
#
# You are receiving LinkedIn notification emails.
#
# This email was intended for Mika Wisener-Brandt (Programmer Analyst).
# Learn why we included this: https://www.linkedin.com/e/v2?e=dvkh33-la2o3utd-id&amp;lipi=urn%3Ali%3Apage%3Aemail_email_jobs_job_application_viewed_01%3Bs8KhV54qTNaOqp6En44Mew%3D%3D&amp;a=customerServiceUrl&amp;midToken=AQEYDKs6Z-Mi0A&amp;midSig=2WESs5ScUM5Gw1&amp;ek=email_jobs_job_application_viewed_01&amp;articleId=4788
#
# © 2022 LinkedIn Corporation, 1000 West Maude Avenue, Sunnyvale, CA 94085. LinkedIn and the LinkedIn logo are registered trademarks of LinkedIn.</p></body></html>
# Your application to Database Engineer at Advisor360°
# DECODE RESULTS:  Your application to Database Engineer at Advisor360°
# Your application to Data Engineer at Applicantz
# DECODE RESULTS:  Your application to Data Engineer at Applicantz
# Your application to Back-End Python Developer at Climate
# DECODE RESULTS:  Your application to Back-End Python Developer at Climate
# Your application for Data Engineer was viewed by TEKsystems.
# DECODE RESULTS:  Your application for Data Engineer was viewed by TEKsystems.
# 'body' !!! Your application for Data Engineer was viewed by TEKsystems
# Body:  <html><body><p>Your application was viewed
#
# ----------------------------------------------------------------
# TEKsystems
# Data Engineer
# New York, United States
# ----------------------------------------------------------------
# Job posted by
#
# Veda Venugopal
# Technical Recruiter
# View Profile
# https://www.linkedin.com/comm/in/veda-venugopal-1043311b4?midToken=AQEYDKs6Z-Mi0A&amp;midSig=20HFjjytC5Yas1&amp;trk=eml-email_jobs_job_application_viewed_01-profile-2-profile_name&amp;trkEmail=eml-email_jobs_job_application_viewed_01-profile-2-profile_name-null-dvkh33%7El9t3m8hu%7Eo3-null-neptune%2Fprofile%7Evanity%2Eview&amp;lipi=urn%3Ali%3Apage%3Aemail_email_jobs_job_application_viewed_01%3BhpfTtq%2F9Twuo%2BjXD86nt%2Bw%3D%3D
# ----------------------------------------------------------------
# People who work here
#
# Johnny Eberenz
# - 2nd
# Sr. Account Manager
# View Profile
# https://www.linkedin.com/comm/in/johnny-eberenz-9764028?midToken=AQEYDKs6Z-Mi0A&amp;midSig=20HFjjytC5Yas1&amp;trk=eml-email_jobs_job_application_viewed_01-members_from_company-6-profile_name&amp;trkEmail=eml-email_jobs_job_application_viewed_01-members_from_company-6-profile_name-null-dvkh33%7El9t3m8hu%7Eo3-null-neptune%2Fprofile%7Evanity%2Eview&amp;lipi=urn%3Ali%3Apage%3Aemail_email_jobs_job_application_viewed_01%3BhpfTtq%2F9Twuo%2BjXD86nt%2Bw%3D%3D
# ----------------------------------------------------------------
# Tim Hughes
# - 2nd
# Sr. Account Executive
# View Profile
# https://www.linkedin.com/comm/in/timhughes4?midToken=AQEYDKs6Z-Mi0A&amp;midSig=20HFjjytC5Yas1&amp;trk=eml-email_jobs_job_application_viewed_01-members_from_company-7-profile_name&amp;trkEmail=eml-email_jobs_job_application_viewed_01-members_from_company-7-profile_name-null-dvkh33%7El9t3m8hu%7Eo3-null-neptune%2Fprofile%7Evanity%2Eview&amp;lipi=urn%3Ali%3Apage%3Aemail_email_jobs_job_application_viewed_01%3BhpfTtq%2F9Twuo%2BjXD86nt%2Bw%3D%3D
# ----------------------------------------------------------------
# David Perez
# - 2nd
# REALTOR/BROKER
# View Profile
# https://www.linkedin.com/comm/in/davidperezindy?midToken=AQEYDKs6Z-Mi0A&amp;midSig=20HFjjytC5Yas1&amp;trk=eml-email_jobs_job_application_viewed_01-members_from_company-8-profile_name&amp;trkEmail=eml-email_jobs_job_application_viewed_01-members_from_company-8-profile_name-null-dvkh33%7El9t3m8hu%7Eo3-null-neptune%2Fprofile%7Evanity%2Eview&amp;lipi=urn%3Ali%3Apage%3Aemail_email_jobs_job_application_viewed_01%3BhpfTtq%2F9Twuo%2BjXD86nt%2Bw%3D%3D
# ----------------------------------------------------------------
# See more
# https://www.linkedin.com/comm/search/results/people/?facetCurrentCompany=2152&amp;midToken=AQEYDKs6Z-Mi0A&amp;midSig=20HFjjytC5Yas1&amp;trk=eml-email_jobs_job_application_viewed_01-members_from_company-16-see_all&amp;trkEmail=eml-email_jobs_job_application_viewed_01-members_from_company-16-see_all-null-dvkh33%7El9t3m8hu%7Eo3-null-neptune%2Fsearch%2Eresults%2Epeople&amp;lipi=urn%3Ali%3Apage%3Aemail_email_jobs_job_application_viewed_01%3BhpfTtq%2F9Twuo%2BjXD86nt%2Bw%3D%3D
# ----------------------------------------------------------------
#
# TEKsystems
# IT Services and IT Consulting
# We’re TEKsystems. We accelerate business transformation by solving complex technology, business and talent challenges—across the globe. We partner with 80% of the Fortune 500 to create solutions tha...
# Learn more about TEKsystems
# https://www.linkedin.com/e/v2?e=dvkh33-l9t3m8hu-o3&amp;lipi=urn%3Ali%3Apage%3Aemail_email_jobs_job_application_viewed_01%3BhpfTtq%2F9Twuo%2BjXD86nt%2Bw%3D%3D&amp;t=bzo&amp;midToken=AQEYDKs6Z-Mi0A&amp;midSig=20HFjjytC5Yas1&amp;ek=email_jobs_job_application_viewed_01&amp;li=15&amp;m=company&amp;ts=company&amp;companyId=2152
# ----------------------------------------------------------------
# Your saved jobs
#
# Expires in 22 days
# Model-Based Systems Engineer, Junior
# Booz Allen Hamilton - Charleston, South Carolina, United States
#
# ----------------------------------------------------------------
# Expires in 22 days
# Remote Python Developer
# Piper Companies - United States
#
# ----------------------------------------------------------------
# Expires in 3 months
# Data Engineer
# CPSI - United States
#
# ----------------------------------------------------------------
# See all saved jobs
# https://www.linkedin.com/e/v2?e=dvkh33-l9t3m8hu-o3&amp;lipi=urn%3Ali%3Apage%3Aemail_email_jobs_job_application_viewed_01%3BhpfTtq%2F9Twuo%2BjXD86nt%2Bw%3D%3D&amp;t=plh&amp;midToken=AQEYDKs6Z-Mi0A&amp;ek=email_jobs_job_application_viewed_01&amp;urlhash=CU-E&amp;url=https%3A%2F%2Fwww%2Elinkedin%2Ecom%2Fjobs%2Fsaved%2F
# ----------------------------------------------------------------
# Similar jobs
# Python Developer
# Workcog Inc - United States
#
# ----------------------------------------------------------------
# Software Developer / Programmer [Equity Only]
# Roialty Hub - Los Angeles, California, United States
#
# ----------------------------------------------------------------
# Python Developer
# VBeyond Corporation - Houston, Texas, United States
#
# ----------------------------------------------------------------
# See more jobs
# https://www.linkedin.com/e/v2?e=dvkh33-l9t3m8hu-o3&amp;lipi=urn%3Ali%3Apage%3Aemail_email_jobs_job_application_viewed_01%3BhpfTtq%2F9Twuo%2BjXD86nt%2Bw%3D%3D&amp;t=plh&amp;midToken=AQEYDKs6Z-Mi0A&amp;ek=email_jobs_job_application_viewed_01&amp;urlhash=Z4Kk&amp;url=https%3A%2F%2Fwww%2Elinkedin%2Ecom%2Fjobs%2Fsearch%2F%3FjobPostingId%3D3323291181%26pivotType%3Dsim
# ----------------------------------------------------------------
#
#
#
#
#
#
#
# Message
#
#
# .....................................
#
# Unsubscribe: https://www.linkedin.com/e/v2?e=dvkh33-l9t3m8hu-o3&amp;t=lun&amp;midToken=AQEYDKs6Z-Mi0A&amp;midSig=20HFjjytC5Yas1&amp;ek=email_jobs_job_application_viewed_01&amp;li=31&amp;m=unsub&amp;ts=unsub&amp;eid=dvkh33-l9t3m8hu-o3&amp;loid=AQEnG3DnbNIZKgAAAYQg1B08f1yb1AsEOujU7BwEBDHOZlrMnlcG6dhKbOHgvpso6i2Hx1QWusm5mUZSSoS-MDM8Qn3WceVzQvNKbD7qIaB8MOapoEaOhA
#
# Help: https://www.linkedin.com/e/v2?e=dvkh33-l9t3m8hu-o3&amp;lipi=urn%3Ali%3Apage%3Aemail_email_jobs_job_application_viewed_01%3BhpfTtq%2F9Twuo%2BjXD86nt%2Bw%3D%3D&amp;a=customerServiceUrl&amp;midToken=AQEYDKs6Z-Mi0A&amp;midSig=20HFjjytC5Yas1&amp;ek=email_jobs_job_application_viewed_01&amp;li=30&amp;m=footer&amp;ts=help&amp;articleId=67
#
#
# You are receiving LinkedIn notification emails.
#
# This email was intended for Mika Wisener-Brandt (Programmer Analyst).
# Learn why we included this: https://www.linkedin.com/e/v2?e=dvkh33-l9t3m8hu-o3&amp;lipi=urn%3Ali%3Apage%3Aemail_email_jobs_job_application_viewed_01%3BhpfTtq%2F9Twuo%2BjXD86nt%2Bw%3D%3D&amp;a=customerServiceUrl&amp;midToken=AQEYDKs6Z-Mi0A&amp;midSig=20HFjjytC5Yas1&amp;ek=email_jobs_job_application_viewed_01&amp;articleId=4788
#
# © 2022 LinkedIn Corporation, 1000 West Maude Avenue, Sunnyvale, CA 94085. LinkedIn and the LinkedIn logo are registered trademarks of LinkedIn.</p></body></html>
# Your application for Python Developer was viewed by NextGen Solutions.
# DECODE RESULTS:  Your application for Python Developer was viewed by NextGen Solutions.
# 'body' !!! Your application for Python Developer was viewed by NextGen Solutions
# Body:  <html><body><p>Your application was viewed
#
# ----------------------------------------------------------------
# NextGen Solutions
# Python Developer
# United States
# ----------------------------------------------------------------
# Job posted by
#
# Sai Nikhil Yanaganti
# Information Technology Recruiter
# View Profile
# https://www.linkedin.com/comm/in/sai-nikhil-yanaganti-357785251?midToken=AQEYDKs6Z-Mi0A&amp;midSig=1U7tu_1zTFVas1&amp;trk=eml-email_jobs_job_application_viewed_01-profile-2-profile_name&amp;trkEmail=eml-email_jobs_job_application_viewed_01-profile-2-profile_name-null-dvkh33%7El9q5gd1w%7Eq9-null-neptune%2Fprofile%7Evanity%2Eview&amp;lipi=urn%3Ali%3Apage%3Aemail_email_jobs_job_application_viewed_01%3BC%2FEbpOMjTyKiGbo%2FGS%2B58w%3D%3D
# ----------------------------------------------------------------
#
# NextGen Solutions
# Staffing and Recruiting
# Nextgen Soltuions is an IT staffing services provider placing highly qualified IT professionals with companies and organizations nationwide. We offer a broad range of staffing options and solutions,...
# Learn more about NextGen Solutions
# https://www.linkedin.com/e/v2?e=dvkh33-l9q5gd1w-q9&amp;lipi=urn%3Ali%3Apage%3Aemail_email_jobs_job_application_viewed_01%3BC%2FEbpOMjTyKiGbo%2FGS%2B58w%3D%3D&amp;t=bzo&amp;midToken=AQEYDKs6Z-Mi0A&amp;midSig=1U7tu_1zTFVas1&amp;ek=email_jobs_job_application_viewed_01&amp;li=11&amp;m=company&amp;ts=company&amp;companyId=24775193
# ----------------------------------------------------------------
# Your saved jobs
#
# Expires in 24 days
# Model-Based Systems Engineer, Junior
# Booz Allen Hamilton - Charleston, South Carolina, United States
#
# ----------------------------------------------------------------
# Expires in 24 days
# Remote Python Developer
# Piper Companies - United States
#
# ----------------------------------------------------------------
# Expires in 3 months
# Data Engineer
# CPSI - United States
#
# ----------------------------------------------------------------
# See all saved jobs
# https://www.linkedin.com/e/v2?e=dvkh33-l9q5gd1w-q9&amp;lipi=urn%3Ali%3Apage%3Aemail_email_jobs_job_application_viewed_01%3BC%2FEbpOMjTyKiGbo%2FGS%2B58w%3D%3D&amp;t=plh&amp;midToken=AQEYDKs6Z-Mi0A&amp;ek=email_jobs_job_application_viewed_01&amp;urlhash=CU-E&amp;url=https%3A%2F%2Fwww%2Elinkedin%2Ecom%2Fjobs%2Fsaved%2F
# ----------------------------------------------------------------
# Similar jobs
# Entry-Level Jr Python Developer
# Mindlance - United States
#
# ----------------------------------------------------------------
# Python Developer
# Raretec Consulting - Greater Orlando
#
# ----------------------------------------------------------------
# Python Developer
# Confidential - Atlanta, Georgia, United States
#
# ----------------------------------------------------------------
# See more jobs
# https://www.linkedin.com/e/v2?e=dvkh33-l9q5gd1w-q9&amp;lipi=urn%3Ali%3Apage%3Aemail_email_jobs_job_application_viewed_01%3BC%2FEbpOMjTyKiGbo%2FGS%2B58w%3D%3D&amp;t=plh&amp;midToken=AQEYDKs6Z-Mi0A&amp;ek=email_jobs_job_application_viewed_01&amp;urlhash=5Sra&amp;url=https%3A%2F%2Fwww%2Elinkedin%2Ecom%2Fjobs%2Fsearch%2F%3FjobPostingId%3D3326568412%26pivotType%3Dsim
# ----------------------------------------------------------------
#
#
#
#
#
#
#
# Message
#
#
# .....................................
#
# Unsubscribe: https://www.linkedin.com/e/v2?e=dvkh33-l9q5gd1w-q9&amp;t=lun&amp;midToken=AQEYDKs6Z-Mi0A&amp;midSig=1U7tu_1zTFVas1&amp;ek=email_jobs_job_application_viewed_01&amp;li=27&amp;m=unsub&amp;ts=unsub&amp;eid=dvkh33-l9q5gd1w-q9&amp;loid=AQHiThAG4HjKVQAAAYQWM0OahC_wzn1b5k1QUmYBBa1KB3D4VM5QaT7WedbnyC1zBepRe5w5AH3VzEEKE4RiyF_B5UgKphgIrQytQGimYpM6JM5DsalUDg
#
# Help: https://www.linkedin.com/e/v2?e=dvkh33-l9q5gd1w-q9&amp;lipi=urn%3Ali%3Apage%3Aemail_email_jobs_job_application_viewed_01%3BC%2FEbpOMjTyKiGbo%2FGS%2B58w%3D%3D&amp;a=customerServiceUrl&amp;midToken=AQEYDKs6Z-Mi0A&amp;midSig=1U7tu_1zTFVas1&amp;ek=email_jobs_job_application_viewed_01&amp;li=26&amp;m=footer&amp;ts=help&amp;articleId=67
#
#
# You are receiving LinkedIn notification emails.
#
# This email was intended for Mika Wisener-Brandt (Programmer Analyst).
# Learn why we included this: https://www.linkedin.com/e/v2?e=dvkh33-l9q5gd1w-q9&amp;lipi=urn%3Ali%3Apage%3Aemail_email_jobs_job_application_viewed_01%3BC%2FEbpOMjTyKiGbo%2FGS%2B58w%3D%3D&amp;a=customerServiceUrl&amp;midToken=AQEYDKs6Z-Mi0A&amp;midSig=1U7tu_1zTFVas1&amp;ek=email_jobs_job_application_viewed_01&amp;articleId=4788
#
# © 2022 LinkedIn Corporation, 1000 West Maude Avenue, Sunnyvale, CA 94085. LinkedIn and the LinkedIn logo are registered trademarks of LinkedIn.</p></body></html>
# You applied for Data Engineer (remote) at Skylight
# DECODE RESULTS:  You applied for Data Engineer (remote) at Skylight
# 'body' !!! You applied for Data Engineer (remote) at Skylight
# Body:  <html><body><p>Your application was sent to Skylight
# ----------------------------------------------------------------
#
# Data Engineer (remote)
# Skylight
# Applied:Applied: 1 second ago
# View job: https://www.linkedin.com/comm/jobs?viewJob=&amp;jobId=3317379575&amp;midToken=AQEYDKs6Z-Mi0A&amp;midSig=1Gw0kZJ8TAVas1&amp;trk=eml-jobs_applicant_applied-applied_jobs-9-applied_job&amp;trkEmail=eml-jobs_applicant_applied-applied_jobs-9-applied_job-null-dvkh33%7El9q59mx7%7Efa-vjs-viewJob&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BKtfE0e36SfqxUhd4mClnhw%3D%3D
#
# ----------------------------------------------------------------
# Here are similar jobs you may be interested in!
# ----------------------------------------------------------------
#
# Data Engineer
# Vivanti Consulting
#
# 10 hours ago
# View job: https://www.linkedin.com/comm/jobs/view/3330936970?midToken=AQEYDKs6Z-Mi0A&amp;midSig=1Gw0kZJ8TAVas1&amp;trk=eml-jobs_applicant_applied-similar_jobs-0-similar_job&amp;trkEmail=eml-jobs_applicant_applied-similar_jobs-0-similar_job-null-dvkh33%7El9q59mx7%7Efa-null-jobs%7Eview&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BKtfE0e36SfqxUhd4mClnhw%3D%3D
#
# ----------------------------------------------------------------
#
# Data Engineer
# Medix™
#
# 1 month ago
# View job: https://www.linkedin.com/comm/jobs/view/3239911480?midToken=AQEYDKs6Z-Mi0A&amp;midSig=1Gw0kZJ8TAVas1&amp;trk=eml-jobs_applicant_applied-similar_jobs-1-similar_job&amp;trkEmail=eml-jobs_applicant_applied-similar_jobs-1-similar_job-null-dvkh33%7El9q59mx7%7Efa-null-jobs%7Eview&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BKtfE0e36SfqxUhd4mClnhw%3D%3D
#
# ----------------------------------------------------------------
#
# Bioprocess Data Engineer
# Catapult Solutions Group
#
# 27 days ago
# View job: https://www.linkedin.com/comm/jobs/view/3282233591?midToken=AQEYDKs6Z-Mi0A&amp;midSig=1Gw0kZJ8TAVas1&amp;trk=eml-jobs_applicant_applied-similar_jobs-2-similar_job&amp;trkEmail=eml-jobs_applicant_applied-similar_jobs-2-similar_job-null-dvkh33%7El9q59mx7%7Efa-null-jobs%7Eview&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BKtfE0e36SfqxUhd4mClnhw%3D%3D
#
# ----------------------------------------------------------------
#
# Data Engineer (Remote - US)
# Alteryx
#
# 11 hours ago
# View job: https://www.linkedin.com/comm/jobs/view/3270115948?midToken=AQEYDKs6Z-Mi0A&amp;midSig=1Gw0kZJ8TAVas1&amp;trk=eml-jobs_applicant_applied-similar_jobs-3-similar_job&amp;trkEmail=eml-jobs_applicant_applied-similar_jobs-3-similar_job-null-dvkh33%7El9q59mx7%7Efa-null-jobs%7Eview&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BKtfE0e36SfqxUhd4mClnhw%3D%3D
#
# ----------------------------------------------------------------
#
# Data Engineer
# Modis
#
# 1 hour ago
# View job: https://www.linkedin.com/comm/jobs/view/3327870396?midToken=AQEYDKs6Z-Mi0A&amp;midSig=1Gw0kZJ8TAVas1&amp;trk=eml-jobs_applicant_applied-similar_jobs-4-similar_job&amp;trkEmail=eml-jobs_applicant_applied-similar_jobs-4-similar_job-null-dvkh33%7El9q59mx7%7Efa-null-jobs%7Eview&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BKtfE0e36SfqxUhd4mClnhw%3D%3D
#
# ----------------------------------------------------------------
#
# Data Engineer - Remote - USA
# FullStack Labs
#
# 9 days ago
# View job: https://www.linkedin.com/comm/jobs/view/2968223383?midToken=AQEYDKs6Z-Mi0A&amp;midSig=1Gw0kZJ8TAVas1&amp;trk=eml-jobs_applicant_applied-similar_jobs-5-similar_job&amp;trkEmail=eml-jobs_applicant_applied-similar_jobs-5-similar_job-null-dvkh33%7El9q59mx7%7Efa-null-jobs%7Eview&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BKtfE0e36SfqxUhd4mClnhw%3D%3D
#
# ----------------------------------------------------------------
#
# See more jobs: https://www.linkedin.com/comm/jobs/?midToken=AQEYDKs6Z-Mi0A&amp;midSig=1Gw0kZJ8TAVas1&amp;trk=eml-jobs_applicant_applied-similar_jobs-7-see_all_jobs&amp;trkEmail=eml-jobs_applicant_applied-similar_jobs-7-see_all_jobs-null-dvkh33%7El9q59mx7%7Efa-null-jobs%7Ehome&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BKtfE0e36SfqxUhd4mClnhw%3D%3D
#
#
#
# .....................................
#
# Unsubscribe: https://www.linkedin.com/e/v2?e=dvkh33-l9q59mx7-fa&amp;t=lun&amp;midToken=AQEYDKs6Z-Mi0A&amp;midSig=1Gw0kZJ8TAVas1&amp;ek=jobs_applicant_applied&amp;li=45&amp;m=unsub&amp;ts=unsub&amp;eid=dvkh33-l9q59mx7-fa&amp;loid=AQES0F3U7VaS_AAAAYQWLno1rFpJbtqbSOJIYVlqX1n-Allqqf689qN1rcK7NhzhuJxm1nD8dAaWPADW13DK_y2c1G9cHZygD1NSmj3BF27N85M2b0kG_A
#
# Help: https://www.linkedin.com/e/v2?e=dvkh33-l9q59mx7-fa&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BKtfE0e36SfqxUhd4mClnhw%3D%3D&amp;a=customerServiceUrl&amp;midToken=AQEYDKs6Z-Mi0A&amp;midSig=1Gw0kZJ8TAVas1&amp;ek=jobs_applicant_applied&amp;li=44&amp;m=footer&amp;ts=help&amp;articleId=67
#
#
# You are receiving LinkedIn notification emails.
#
# This email was intended for Mika Wisener-Brandt (Programmer Analyst).
# Learn why we included this: https://www.linkedin.com/e/v2?e=dvkh33-l9q59mx7-fa&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BKtfE0e36SfqxUhd4mClnhw%3D%3D&amp;a=customerServiceUrl&amp;midToken=AQEYDKs6Z-Mi0A&amp;midSig=1Gw0kZJ8TAVas1&amp;ek=jobs_applicant_applied&amp;articleId=4788
#
# © 2022 LinkedIn Corporation, 1000 West Maude Avenue, Sunnyvale, CA 94085. LinkedIn and the LinkedIn logo are registered trademarks of LinkedIn.</p></body></html>
# You applied for Data Engineer II at IT Avalon
# DECODE RESULTS:  You applied for Data Engineer II at IT Avalon
# 'body' !!! You applied for Data Engineer II at IT Avalon
# Body:  <html><body><p>Your application was sent to IT Avalon
# ----------------------------------------------------------------
#
# Data Engineer II
# IT Avalon
# Applied:Applied: 1 minute ago
# View job: https://www.linkedin.com/comm/jobs?viewJob=&amp;jobId=3325878661&amp;midToken=AQEYDKs6Z-Mi0A&amp;midSig=3IX6fGzSTzVas1&amp;trk=eml-jobs_applicant_applied-applied_jobs-9-applied_job&amp;trkEmail=eml-jobs_applicant_applied-applied_jobs-9-applied_job-null-dvkh33%7El9q562ma%7E78-vjs-viewJob&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BJByp4AYHR0%2BvzSWzZzjV1Q%3D%3D
#
# ----------------------------------------------------------------
# Show recruiters your skill level
# Take a 15 minute skill assessment to stand out to recruiters
#
# Object-Oriented Programming (OOP)
# Get started
# https://www.linkedin.com/comm/in/mikawb/detail/assessments/Object-Oriented%20Programming%20(OOP)/quiz-intro/?midToken=AQEYDKs6Z-Mi0A&amp;midSig=3IX6fGzSTzVas1&amp;trk=eml-jobs_applicant_applied-skill_assessment_recommendations-11-available_skill&amp;trkEmail=eml-jobs_applicant_applied-skill_assessment_recommendations-11-available_skill-null-dvkh33%7El9q562ma%7E78-null-neptune%2Fprofile%7Evanity%2Eskill%2Eassessments%2Equiz%2Estart&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BJByp4AYHR0%2BvzSWzZzjV1Q%3D%3D
#
# C++
# Get started
# https://www.linkedin.com/comm/in/mikawb/detail/assessments/C++/quiz-intro/?midToken=AQEYDKs6Z-Mi0A&amp;midSig=3IX6fGzSTzVas1&amp;trk=eml-jobs_applicant_applied-skill_assessment_recommendations-12-available_skill&amp;trkEmail=eml-jobs_applicant_applied-skill_assessment_recommendations-12-available_skill-null-dvkh33%7El9q562ma%7E78-null-neptune%2Fprofile%7Evanity%2Eskill%2Eassessments%2Equiz%2Estart&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BJByp4AYHR0%2BvzSWzZzjV1Q%3D%3D
#
# C (Programming Language)
# Get started
# https://www.linkedin.com/comm/in/mikawb/detail/assessments/C%20(Programming%20Language)/quiz-intro/?midToken=AQEYDKs6Z-Mi0A&amp;midSig=3IX6fGzSTzVas1&amp;trk=eml-jobs_applicant_applied-skill_assessment_recommendations-13-available_skill&amp;trkEmail=eml-jobs_applicant_applied-skill_assessment_recommendations-13-available_skill-null-dvkh33%7El9q562ma%7E78-null-neptune%2Fprofile%7Evanity%2Eskill%2Eassessments%2Equiz%2Estart&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BJByp4AYHR0%2BvzSWzZzjV1Q%3D%3D
#
# .NET Framework
# Get started
# https://www.linkedin.com/comm/in/mikawb/detail/assessments/.NET%20Framework/quiz-intro/?midToken=AQEYDKs6Z-Mi0A&amp;midSig=3IX6fGzSTzVas1&amp;trk=eml-jobs_applicant_applied-skill_assessment_recommendations-14-available_skill&amp;trkEmail=eml-jobs_applicant_applied-skill_assessment_recommendations-14-available_skill-null-dvkh33%7El9q562ma%7E78-null-neptune%2Fprofile%7Evanity%2Eskill%2Eassessments%2Equiz%2Estart&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BJByp4AYHR0%2BvzSWzZzjV1Q%3D%3D
#
# Bash
# Get started
# https://www.linkedin.com/comm/in/mikawb/detail/assessments/Bash/quiz-intro/?midToken=AQEYDKs6Z-Mi0A&amp;midSig=3IX6fGzSTzVas1&amp;trk=eml-jobs_applicant_applied-skill_assessment_recommendations-15-available_skill&amp;trkEmail=eml-jobs_applicant_applied-skill_assessment_recommendations-15-available_skill-null-dvkh33%7El9q562ma%7E78-null-neptune%2Fprofile%7Evanity%2Eskill%2Eassessments%2Equiz%2Estart&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BJByp4AYHR0%2BvzSWzZzjV1Q%3D%3D
#
# JavaScript
# Get started
# https://www.linkedin.com/comm/in/mikawb/detail/assessments/JavaScript/quiz-intro/?midToken=AQEYDKs6Z-Mi0A&amp;midSig=3IX6fGzSTzVas1&amp;trk=eml-jobs_applicant_applied-skill_assessment_recommendations-16-available_skill&amp;trkEmail=eml-jobs_applicant_applied-skill_assessment_recommendations-16-available_skill-null-dvkh33%7El9q562ma%7E78-null-neptune%2Fprofile%7Evanity%2Eskill%2Eassessments%2Equiz%2Estart&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BJByp4AYHR0%2BvzSWzZzjV1Q%3D%3D
#
# jQuery
# Get started
# https://www.linkedin.com/comm/in/mikawb/detail/assessments/jQuery/quiz-intro/?midToken=AQEYDKs6Z-Mi0A&amp;midSig=3IX6fGzSTzVas1&amp;trk=eml-jobs_applicant_applied-skill_assessment_recommendations-17-available_skill&amp;trkEmail=eml-jobs_applicant_applied-skill_assessment_recommendations-17-available_skill-null-dvkh33%7El9q562ma%7E78-null-neptune%2Fprofile%7Evanity%2Eskill%2Eassessments%2Equiz%2Estart&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BJByp4AYHR0%2BvzSWzZzjV1Q%3D%3D
#
# C#
# Get started
# https://www.linkedin.com/comm/in/mikawb/detail/assessments/C%23/quiz-intro/?midToken=AQEYDKs6Z-Mi0A&amp;midSig=3IX6fGzSTzVas1&amp;trk=eml-jobs_applicant_applied-skill_assessment_recommendations-18-available_skill&amp;trkEmail=eml-jobs_applicant_applied-skill_assessment_recommendations-18-available_skill-null-dvkh33%7El9q562ma%7E78-null-neptune%2Fprofile%7Evanity%2Eskill%2Eassessments%2Equiz%2Estart&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BJByp4AYHR0%2BvzSWzZzjV1Q%3D%3D
#
# Linux
# Get started
# https://www.linkedin.com/comm/in/mikawb/detail/assessments/Linux/quiz-intro/?midToken=AQEYDKs6Z-Mi0A&amp;midSig=3IX6fGzSTzVas1&amp;trk=eml-jobs_applicant_applied-skill_assessment_recommendations-19-available_skill&amp;trkEmail=eml-jobs_applicant_applied-skill_assessment_recommendations-19-available_skill-null-dvkh33%7El9q562ma%7E78-null-neptune%2Fprofile%7Evanity%2Eskill%2Eassessments%2Equiz%2Estart&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BJByp4AYHR0%2BvzSWzZzjV1Q%3D%3D
#
# ----------------------------------------------------------------
# Here are similar jobs you may be interested in!
# ----------------------------------------------------------------
#
# Data Engineer II
# RiskLens
#
# 13 hours ago
# View job: https://www.linkedin.com/comm/jobs/view/3330377251?midToken=AQEYDKs6Z-Mi0A&amp;midSig=3IX6fGzSTzVas1&amp;trk=eml-jobs_applicant_applied-similar_jobs-0-similar_job&amp;trkEmail=eml-jobs_applicant_applied-similar_jobs-0-similar_job-null-dvkh33%7El9q562ma%7E78-null-jobs%7Eview&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BJByp4AYHR0%2BvzSWzZzjV1Q%3D%3D
#
# ----------------------------------------------------------------
#
# Data Engineer
# Fusion Business Solutions (P) Limited
#
# 5 hours ago
# View job: https://www.linkedin.com/comm/jobs/view/3326532837?midToken=AQEYDKs6Z-Mi0A&amp;midSig=3IX6fGzSTzVas1&amp;trk=eml-jobs_applicant_applied-similar_jobs-1-similar_job&amp;trkEmail=eml-jobs_applicant_applied-similar_jobs-1-similar_job-null-dvkh33%7El9q562ma%7E78-null-jobs%7Eview&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BJByp4AYHR0%2BvzSWzZzjV1Q%3D%3D
#
# ----------------------------------------------------------------
#
# Data Engineer
# CIBER
#
# 1 hour ago
# View job: https://www.linkedin.com/comm/jobs/view/3331951869?midToken=AQEYDKs6Z-Mi0A&amp;midSig=3IX6fGzSTzVas1&amp;trk=eml-jobs_applicant_applied-similar_jobs-2-similar_job&amp;trkEmail=eml-jobs_applicant_applied-similar_jobs-2-similar_job-null-dvkh33%7El9q562ma%7E78-null-jobs%7Eview&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BJByp4AYHR0%2BvzSWzZzjV1Q%3D%3D
#
# ----------------------------------------------------------------
#
# Data Engineer
# IBM
#
# 4 hours ago
# View job: https://www.linkedin.com/comm/jobs/view/3326549073?midToken=AQEYDKs6Z-Mi0A&amp;midSig=3IX6fGzSTzVas1&amp;trk=eml-jobs_applicant_applied-similar_jobs-3-similar_job&amp;trkEmail=eml-jobs_applicant_applied-similar_jobs-3-similar_job-null-dvkh33%7El9q562ma%7E78-null-jobs%7Eview&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BJByp4AYHR0%2BvzSWzZzjV1Q%3D%3D
#
# ----------------------------------------------------------------
#
# DATA ENGINEER II
# University of Wisconsin-Madison
#
# 5 days ago
# View job: https://www.linkedin.com/comm/jobs/view/3323203516?midToken=AQEYDKs6Z-Mi0A&amp;midSig=3IX6fGzSTzVas1&amp;trk=eml-jobs_applicant_applied-similar_jobs-4-similar_job&amp;trkEmail=eml-jobs_applicant_applied-similar_jobs-4-similar_job-null-dvkh33%7El9q562ma%7E78-null-jobs%7Eview&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BJByp4AYHR0%2BvzSWzZzjV1Q%3D%3D
#
# ----------------------------------------------------------------
#
# Data Engineer
# The Select Group
#
# 5 hours ago
# View job: https://www.linkedin.com/comm/jobs/view/3331621822?midToken=AQEYDKs6Z-Mi0A&amp;midSig=3IX6fGzSTzVas1&amp;trk=eml-jobs_applicant_applied-similar_jobs-5-similar_job&amp;trkEmail=eml-jobs_applicant_applied-similar_jobs-5-similar_job-null-dvkh33%7El9q562ma%7E78-null-jobs%7Eview&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BJByp4AYHR0%2BvzSWzZzjV1Q%3D%3D
#
# ----------------------------------------------------------------
#
# See more jobs: https://www.linkedin.com/comm/jobs/?midToken=AQEYDKs6Z-Mi0A&amp;midSig=3IX6fGzSTzVas1&amp;trk=eml-jobs_applicant_applied-similar_jobs-7-see_all_jobs&amp;trkEmail=eml-jobs_applicant_applied-similar_jobs-7-see_all_jobs-null-dvkh33%7El9q562ma%7E78-null-jobs%7Ehome&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BJByp4AYHR0%2BvzSWzZzjV1Q%3D%3D
#
#
#
# .....................................
#
# Unsubscribe: https://www.linkedin.com/e/v2?e=dvkh33-l9q562ma-78&amp;t=lun&amp;midToken=AQEYDKs6Z-Mi0A&amp;midSig=3IX6fGzSTzVas1&amp;ek=jobs_applicant_applied&amp;li=54&amp;m=unsub&amp;ts=unsub&amp;eid=dvkh33-l9q562ma-78&amp;loid=AQGWVIoVQbPnKQAAAYQWLWJU3SYknK6sR2dZCbD3-H2S2DWlQ7kcBjkbLpZgZVuvzlY-wDG4mRFSmiU-vPA_aTNW4R60DrYIKYfPXAc6XblG3_ZHe47Yew
#
# Help: https://www.linkedin.com/e/v2?e=dvkh33-l9q562ma-78&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BJByp4AYHR0%2BvzSWzZzjV1Q%3D%3D&amp;a=customerServiceUrl&amp;midToken=AQEYDKs6Z-Mi0A&amp;midSig=3IX6fGzSTzVas1&amp;ek=jobs_applicant_applied&amp;li=53&amp;m=footer&amp;ts=help&amp;articleId=67
#
#
# You are receiving LinkedIn notification emails.
#
# This email was intended for Mika Wisener-Brandt (Programmer Analyst).
# Learn why we included this: https://www.linkedin.com/e/v2?e=dvkh33-l9q562ma-78&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BJByp4AYHR0%2BvzSWzZzjV1Q%3D%3D&amp;a=customerServiceUrl&amp;midToken=AQEYDKs6Z-Mi0A&amp;midSig=3IX6fGzSTzVas1&amp;ek=jobs_applicant_applied&amp;articleId=4788
#
# © 2022 LinkedIn Corporation, 1000 West Maude Avenue, Sunnyvale, CA 94085. LinkedIn and the LinkedIn logo are registered trademarks of LinkedIn.</p></body></html>
# You applied for Analytics Implementation Engineer at Robert Half
# DECODE RESULTS:  You applied for Analytics Implementation Engineer at Robert Half
# 'body' !!! You applied for Analytics Implementation Engineer at Robert Half
# Body:  <html><body><p>Your application was sent to Robert Half
# ----------------------------------------------------------------
#
# Analytics Implementation Engineer
# Robert Half
# Applied:Applied: 1 second ago
# View job: https://www.linkedin.com/comm/jobs?viewJob=&amp;jobId=3325883027&amp;midToken=AQEYDKs6Z-Mi0A&amp;midSig=3IX6fGzSTzVas1&amp;trk=eml-jobs_applicant_applied-applied_jobs-9-applied_job&amp;trkEmail=eml-jobs_applicant_applied-applied_jobs-9-applied_job-null-dvkh33%7El9q581r6%7Egd-vjs-viewJob&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BMVqDnaEXQe%2BQOWm%2FFYQi5Q%3D%3D
#
# ----------------------------------------------------------------
# Show recruiters your skill level
# Take a 15 minute skill assessment to stand out to recruiters
#
# Front-End Development
# Get started
# https://www.linkedin.com/comm/in/mikawb/detail/assessments/Front-End%20Development/quiz-intro/?midToken=AQEYDKs6Z-Mi0A&amp;midSig=3IX6fGzSTzVas1&amp;trk=eml-jobs_applicant_applied-skill_assessment_recommendations-11-available_skill&amp;trkEmail=eml-jobs_applicant_applied-skill_assessment_recommendations-11-available_skill-null-dvkh33%7El9q581r6%7Egd-null-neptune%2Fprofile%7Evanity%2Eskill%2Eassessments%2Equiz%2Estart&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BMVqDnaEXQe%2BQOWm%2FFYQi5Q%3D%3D
#
# JavaScript
# Get started
# https://www.linkedin.com/comm/in/mikawb/detail/assessments/JavaScript/quiz-intro/?midToken=AQEYDKs6Z-Mi0A&amp;midSig=3IX6fGzSTzVas1&amp;trk=eml-jobs_applicant_applied-skill_assessment_recommendations-12-available_skill&amp;trkEmail=eml-jobs_applicant_applied-skill_assessment_recommendations-12-available_skill-null-dvkh33%7El9q581r6%7Egd-null-neptune%2Fprofile%7Evanity%2Eskill%2Eassessments%2Equiz%2Estart&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BMVqDnaEXQe%2BQOWm%2FFYQi5Q%3D%3D
#
# jQuery
# Get started
# https://www.linkedin.com/comm/in/mikawb/detail/assessments/jQuery/quiz-intro/?midToken=AQEYDKs6Z-Mi0A&amp;midSig=3IX6fGzSTzVas1&amp;trk=eml-jobs_applicant_applied-skill_assessment_recommendations-13-available_skill&amp;trkEmail=eml-jobs_applicant_applied-skill_assessment_recommendations-13-available_skill-null-dvkh33%7El9q581r6%7Egd-null-neptune%2Fprofile%7Evanity%2Eskill%2Eassessments%2Equiz%2Estart&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BMVqDnaEXQe%2BQOWm%2FFYQi5Q%3D%3D
#
# ----------------------------------------------------------------
# Here are similar jobs you may be interested in!
# ----------------------------------------------------------------
#
# Analytics Implementation Engineer
# Robert Half - NA/US/SEP
#
# 5 hours ago
# View job: https://www.linkedin.com/comm/jobs/view/3331574368?midToken=AQEYDKs6Z-Mi0A&amp;midSig=3IX6fGzSTzVas1&amp;trk=eml-jobs_applicant_applied-similar_jobs-0-similar_job&amp;trkEmail=eml-jobs_applicant_applied-similar_jobs-0-similar_job-null-dvkh33%7El9q581r6%7Egd-null-jobs%7Eview&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BMVqDnaEXQe%2BQOWm%2FFYQi5Q%3D%3D
#
# ----------------------------------------------------------------
#
# Implementation Engineer
# aPriori Technologies
#
# 7 days ago
# View job: https://www.linkedin.com/comm/jobs/view/3320154886?midToken=AQEYDKs6Z-Mi0A&amp;midSig=3IX6fGzSTzVas1&amp;trk=eml-jobs_applicant_applied-similar_jobs-1-similar_job&amp;trkEmail=eml-jobs_applicant_applied-similar_jobs-1-similar_job-null-dvkh33%7El9q581r6%7Egd-null-jobs%7Eview&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BMVqDnaEXQe%2BQOWm%2FFYQi5Q%3D%3D
#
# ----------------------------------------------------------------
#
# Implementation Engineer
# Dice - JW
#
# 6 days ago
# View job: https://www.linkedin.com/comm/jobs/view/3324234921?midToken=AQEYDKs6Z-Mi0A&amp;midSig=3IX6fGzSTzVas1&amp;trk=eml-jobs_applicant_applied-similar_jobs-2-similar_job&amp;trkEmail=eml-jobs_applicant_applied-similar_jobs-2-similar_job-null-dvkh33%7El9q581r6%7Egd-null-jobs%7Eview&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BMVqDnaEXQe%2BQOWm%2FFYQi5Q%3D%3D
#
# ----------------------------------------------------------------
#
# Implementation Engineer
# Ricoh USA, Inc.
#
# 8 days ago
# View job: https://www.linkedin.com/comm/jobs/view/3318257075?midToken=AQEYDKs6Z-Mi0A&amp;midSig=3IX6fGzSTzVas1&amp;trk=eml-jobs_applicant_applied-similar_jobs-3-similar_job&amp;trkEmail=eml-jobs_applicant_applied-similar_jobs-3-similar_job-null-dvkh33%7El9q581r6%7Egd-null-jobs%7Eview&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BMVqDnaEXQe%2BQOWm%2FFYQi5Q%3D%3D
#
# ----------------------------------------------------------------
#
# Implementation Engineer
# Servion Global Solutions
#
# 8 days ago
# View job: https://www.linkedin.com/comm/jobs/view/3318091949?midToken=AQEYDKs6Z-Mi0A&amp;midSig=3IX6fGzSTzVas1&amp;trk=eml-jobs_applicant_applied-similar_jobs-4-similar_job&amp;trkEmail=eml-jobs_applicant_applied-similar_jobs-4-similar_job-null-dvkh33%7El9q581r6%7Egd-null-jobs%7Eview&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BMVqDnaEXQe%2BQOWm%2FFYQi5Q%3D%3D
#
# ----------------------------------------------------------------
#
# Adobe Analytics Implementation Engineer
# Harnham
#
# 5 minutes ago
# View job: https://www.linkedin.com/comm/jobs/view/3331991297?midToken=AQEYDKs6Z-Mi0A&amp;midSig=3IX6fGzSTzVas1&amp;trk=eml-jobs_applicant_applied-similar_jobs-5-similar_job&amp;trkEmail=eml-jobs_applicant_applied-similar_jobs-5-similar_job-null-dvkh33%7El9q581r6%7Egd-null-jobs%7Eview&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BMVqDnaEXQe%2BQOWm%2FFYQi5Q%3D%3D
#
# ----------------------------------------------------------------
#
# See more jobs: https://www.linkedin.com/comm/jobs/?midToken=AQEYDKs6Z-Mi0A&amp;midSig=3IX6fGzSTzVas1&amp;trk=eml-jobs_applicant_applied-similar_jobs-7-see_all_jobs&amp;trkEmail=eml-jobs_applicant_applied-similar_jobs-7-see_all_jobs-null-dvkh33%7El9q581r6%7Egd-null-jobs%7Ehome&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BMVqDnaEXQe%2BQOWm%2FFYQi5Q%3D%3D
#
#
#
# .....................................
#
# Unsubscribe: https://www.linkedin.com/e/v2?e=dvkh33-l9q581r6-gd&amp;t=lun&amp;midToken=AQEYDKs6Z-Mi0A&amp;midSig=3IX6fGzSTzVas1&amp;ek=jobs_applicant_applied&amp;li=48&amp;m=unsub&amp;ts=unsub&amp;eid=dvkh33-l9q581r6-gd&amp;loid=AQH-75UKv2iLoQAAAYQWLVjL6nRpUJ-L9PFOyqxai5x1cXTYef_EbJLxyqRQS0HMQawU_19Jm6sp82vQTezxcEtnUFuVATUaweQ4AQgVp_UO4rVLV1hmbw
#
# Help: https://www.linkedin.com/e/v2?e=dvkh33-l9q581r6-gd&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BMVqDnaEXQe%2BQOWm%2FFYQi5Q%3D%3D&amp;a=customerServiceUrl&amp;midToken=AQEYDKs6Z-Mi0A&amp;midSig=3IX6fGzSTzVas1&amp;ek=jobs_applicant_applied&amp;li=47&amp;m=footer&amp;ts=help&amp;articleId=67
#
#
# You are receiving LinkedIn notification emails.
#
# This email was intended for Mika Wisener-Brandt (Programmer Analyst).
# Learn why we included this: https://www.linkedin.com/e/v2?e=dvkh33-l9q581r6-gd&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BMVqDnaEXQe%2BQOWm%2FFYQi5Q%3D%3D&amp;a=customerServiceUrl&amp;midToken=AQEYDKs6Z-Mi0A&amp;midSig=3IX6fGzSTzVas1&amp;ek=jobs_applicant_applied&amp;articleId=4788
#
# © 2022 LinkedIn Corporation, 1000 West Maude Avenue, Sunnyvale, CA 94085. LinkedIn and the LinkedIn logo are registered trademarks of LinkedIn.</p></body></html>
# You applied for Data Engineer with Python & SQL at SmartIT Frame
# DECODE RESULTS:  You applied for Data Engineer with Python & SQL at SmartIT Frame
# 'body' !!! You applied for Data Engineer with Python and SQL at SmartIT Frame
# Body:  <html><body><p>Your application was sent to SmartIT Frame
# ----------------------------------------------------------------
#
# Data Engineer with Python &amp; SQL
# SmartIT Frame
# Applied:Applied: 15 seconds ago
# View job: https://www.linkedin.com/comm/jobs?viewJob=&amp;jobId=3326509275&amp;midToken=AQEYDKs6Z-Mi0A&amp;midSig=2CN75Sx43yVas1&amp;trk=eml-jobs_applicant_applied-applied_jobs-9-applied_job&amp;trkEmail=eml-jobs_applicant_applied-applied_jobs-9-applied_job-null-dvkh33%7El9q56zc0%7E1l-vjs-viewJob&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BYH24eA0rTp6UzIP5wdF0NA%3D%3D
#
# ----------------------------------------------------------------
# Show recruiters your skill level
# Take a 15 minute skill assessment to stand out to recruiters
#
# Microsoft Outlook
# Get started
# https://www.linkedin.com/comm/in/mikawb/detail/assessments/Microsoft%20Outlook/quiz-intro/?midToken=AQEYDKs6Z-Mi0A&amp;midSig=2CN75Sx43yVas1&amp;trk=eml-jobs_applicant_applied-skill_assessment_recommendations-11-available_skill&amp;trkEmail=eml-jobs_applicant_applied-skill_assessment_recommendations-11-available_skill-null-dvkh33%7El9q56zc0%7E1l-null-neptune%2Fprofile%7Evanity%2Eskill%2Eassessments%2Equiz%2Estart&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BYH24eA0rTp6UzIP5wdF0NA%3D%3D
#
# Amazon Web Services (AWS)
# Get started
# https://www.linkedin.com/comm/in/mikawb/detail/assessments/Amazon%20Web%20Services%20(AWS)/quiz-intro/?midToken=AQEYDKs6Z-Mi0A&amp;midSig=2CN75Sx43yVas1&amp;trk=eml-jobs_applicant_applied-skill_assessment_recommendations-12-available_skill&amp;trkEmail=eml-jobs_applicant_applied-skill_assessment_recommendations-12-available_skill-null-dvkh33%7El9q56zc0%7E1l-null-neptune%2Fprofile%7Evanity%2Eskill%2Eassessments%2Equiz%2Estart&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BYH24eA0rTp6UzIP5wdF0NA%3D%3D
#
# ----------------------------------------------------------------
# Here are similar jobs you may be interested in!
# ----------------------------------------------------------------
#
# Data Engineer with Python &amp; SQL
# Dice - JW
#
# 6 hours ago
# View job: https://www.linkedin.com/comm/jobs/view/3331557139?midToken=AQEYDKs6Z-Mi0A&amp;midSig=2CN75Sx43yVas1&amp;trk=eml-jobs_applicant_applied-similar_jobs-0-similar_job&amp;trkEmail=eml-jobs_applicant_applied-similar_jobs-0-similar_job-null-dvkh33%7El9q56zc0%7E1l-null-jobs%7Eview&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BYH24eA0rTp6UzIP5wdF0NA%3D%3D
#
# ----------------------------------------------------------------
#
# Data Engineer
# Insight Global
#
# 2 hours ago
# View job: https://www.linkedin.com/comm/jobs/view/3326573652?midToken=AQEYDKs6Z-Mi0A&amp;midSig=2CN75Sx43yVas1&amp;trk=eml-jobs_applicant_applied-similar_jobs-1-similar_job&amp;trkEmail=eml-jobs_applicant_applied-similar_jobs-1-similar_job-null-dvkh33%7El9q56zc0%7E1l-null-jobs%7Eview&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BYH24eA0rTp6UzIP5wdF0NA%3D%3D
#
# ----------------------------------------------------------------
#
# Data Engineer
# Jobot
#
# 8 hours ago
# View job: https://www.linkedin.com/comm/jobs/view/3325180967?midToken=AQEYDKs6Z-Mi0A&amp;midSig=2CN75Sx43yVas1&amp;trk=eml-jobs_applicant_applied-similar_jobs-2-similar_job&amp;trkEmail=eml-jobs_applicant_applied-similar_jobs-2-similar_job-null-dvkh33%7El9q56zc0%7E1l-null-jobs%7Eview&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BYH24eA0rTp6UzIP5wdF0NA%3D%3D
#
# ----------------------------------------------------------------
#
# Data Engineer
# Motion Recruitment
#
# 5 days ago
# View job: https://www.linkedin.com/comm/jobs/view/3325510673?midToken=AQEYDKs6Z-Mi0A&amp;midSig=2CN75Sx43yVas1&amp;trk=eml-jobs_applicant_applied-similar_jobs-3-similar_job&amp;trkEmail=eml-jobs_applicant_applied-similar_jobs-3-similar_job-null-dvkh33%7El9q56zc0%7E1l-null-jobs%7Eview&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BYH24eA0rTp6UzIP5wdF0NA%3D%3D
#
# ----------------------------------------------------------------
#
# Data Engineer
# RightClick
#
# 14 minutes ago
# View job: https://www.linkedin.com/comm/jobs/view/3326590379?midToken=AQEYDKs6Z-Mi0A&amp;midSig=2CN75Sx43yVas1&amp;trk=eml-jobs_applicant_applied-similar_jobs-4-similar_job&amp;trkEmail=eml-jobs_applicant_applied-similar_jobs-4-similar_job-null-dvkh33%7El9q56zc0%7E1l-null-jobs%7Eview&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BYH24eA0rTp6UzIP5wdF0NA%3D%3D
#
# ----------------------------------------------------------------
#
# Data Engineer
# Velocity Global, LLC
#
# 9 hours ago
# View job: https://www.linkedin.com/comm/jobs/view/3326288623?midToken=AQEYDKs6Z-Mi0A&amp;midSig=2CN75Sx43yVas1&amp;trk=eml-jobs_applicant_applied-similar_jobs-5-similar_job&amp;trkEmail=eml-jobs_applicant_applied-similar_jobs-5-similar_job-null-dvkh33%7El9q56zc0%7E1l-null-jobs%7Eview&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BYH24eA0rTp6UzIP5wdF0NA%3D%3D
#
# ----------------------------------------------------------------
#
# See more jobs: https://www.linkedin.com/comm/jobs/?midToken=AQEYDKs6Z-Mi0A&amp;midSig=2CN75Sx43yVas1&amp;trk=eml-jobs_applicant_applied-similar_jobs-7-see_all_jobs&amp;trkEmail=eml-jobs_applicant_applied-similar_jobs-7-see_all_jobs-null-dvkh33%7El9q56zc0%7E1l-null-jobs%7Ehome&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BYH24eA0rTp6UzIP5wdF0NA%3D%3D
#
#
#
# .....................................
#
# Unsubscribe: https://www.linkedin.com/e/v2?e=dvkh33-l9q56zc0-1l&amp;t=lun&amp;midToken=AQEYDKs6Z-Mi0A&amp;midSig=2CN75Sx43yVas1&amp;ek=jobs_applicant_applied&amp;li=47&amp;m=unsub&amp;ts=unsub&amp;eid=dvkh33-l9q56zc0-1l&amp;loid=AQHcGbjkp3x_GAAAAYQWLNDRLZCzar3vd9khedo45jul4DfmLmSlxh6uU6kpjV2gq_S2P-2JTDTP9CIfwtR-ngK4iwY6Pb6pppYvwkez6ERAxim27LwOlQ
#
# Help: https://www.linkedin.com/e/v2?e=dvkh33-l9q56zc0-1l&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BYH24eA0rTp6UzIP5wdF0NA%3D%3D&amp;a=customerServiceUrl&amp;midToken=AQEYDKs6Z-Mi0A&amp;midSig=2CN75Sx43yVas1&amp;ek=jobs_applicant_applied&amp;li=46&amp;m=footer&amp;ts=help&amp;articleId=67
#
#
# You are receiving LinkedIn notification emails.
#
# This email was intended for Mika Wisener-Brandt (Programmer Analyst).
# Learn why we included this: https://www.linkedin.com/e/v2?e=dvkh33-l9q56zc0-1l&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3BYH24eA0rTp6UzIP5wdF0NA%3D%3D&amp;a=customerServiceUrl&amp;midToken=AQEYDKs6Z-Mi0A&amp;midSig=2CN75Sx43yVas1&amp;ek=jobs_applicant_applied&amp;articleId=4788
#
# © 2022 LinkedIn Corporation, 1000 West Maude Avenue, Sunnyvale, CA 94085. LinkedIn and the LinkedIn logo are registered trademarks of LinkedIn.</p></body></html>
# You applied for Data Engineer at Applicantz
# DECODE RESULTS:  You applied for Data Engineer at Applicantz
# 'body' !!! You applied for Data Engineer at Applicantz
# Body:  <html><body><p>Your application was sent to Applicantz
# ----------------------------------------------------------------
#
# Data Engineer
# Applicantz
# Applied:Applied: 2 minutes ago
# View job: https://www.linkedin.com/comm/jobs?viewJob=&amp;jobId=3330629760&amp;midToken=AQEYDKs6Z-Mi0A&amp;midSig=1UAzmx6MnxVas1&amp;trk=eml-jobs_applicant_applied-applied_jobs-9-applied_job&amp;trkEmail=eml-jobs_applicant_applied-applied_jobs-9-applied_job-null-dvkh33%7El9q53a7a%7Ely-vjs-viewJob&amp;lipi=urn%3Ali%3Apage%3Aemail_jobs_applicant_applied%3B2On1o7wpTTm3ZR2xPDlgBQ%3D%3D
#
# ----------------------------------------------------------------
# Show recruiters your skill level
# Take a 15 minute skill assessment to stand out to recruiters
#
# AWS Lambda
# Get started
# ...
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
# dictionary
# string
# dictionary
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
# string
#
# string
# string
# string
#                                                subject  \
# 0    Your application to Guidance Navigation and Co...
# 1    Your application for Senior Software Engineer ...
# 2    Your application to Database Engineer at Advis...
# 3      Your application to Data Engineer at Applicantz
# 4    Your application to Back-End Python Developer ...
# ..                                                 ...
# 292  You applied for Data Analyst at Integrated Hea...
# 293   Your application to Python Developer at Mulberry
# 294  Your application for Python Developer was view...
# 295  You applied for Python Developer at Mulberry T...
# 296          You applied for Financial Analyst at Onbe
#
#                                                headers  \
# 0    {'Delivered-To': 'mika.wisener@gmail.com', 'Re...
# 1    {'Delivered-To': 'mika.wisener@gmail.com', 'Re...
# 2    {'Delivered-To': 'mika.wisener@gmail.com', 'Re...
# 3    {'Delivered-To': 'mika.wisener@gmail.com', 'Re...
# 4    {'Delivered-To': 'mika.wisener@gmail.com', 'Re...
# ..                                                 ...
# 292  {'Delivered-To': 'mika.wisener@gmail.com', 'Re...
# 293  {'Delivered-To': 'mika.wisener@gmail.com', 'Re...
# 294  {'Delivered-To': 'mika.wisener@gmail.com', 'Re...
# 295  {'Delivered-To': 'mika.wisener@gmail.com', 'Re...
# 296  {'Delivered-To': 'mika.wisener@gmail.com', 'Re...
#
#                                                   body  \
# 0    [[[<p>AeroVironment has an update for you.\r\n...
# 1    [[[<p>Your application was viewed\r\n\r\n-----...
# 2    [[[<p>Advisor360° has an update for you.\r\n--...
# 3    [[[<p>Applicantz has an update for you.\r\n---...
# 4    [[[<p>Climate has an update for you.\r\n------...
# ..                                                 ...
# 292  [[[<p>Your application was sent to Integrated ...
# 293  [[[<p>Mulberry has an update for you.\r\n-----...
# 294  [[[<p>Your application was viewed\r\n\r\n-----...
# 295  [[[<p>Your application was sent to Mulberry Te...
# 296  [[[<p>Your application was sent to Onbe\r\n---...
#
#                                       from                           date  \
# 0     LinkedIn <jobs-noreply@linkedin.com>  2022-11-10 12:23:38 UTC-08:00
# 1     LinkedIn <jobs-noreply@linkedin.com>  2022-11-04 08:44:55 UTC-07:00
# 2     LinkedIn <jobs-noreply@linkedin.com>  2022-10-30 10:14:03 UTC-07:00
# 3     LinkedIn <jobs-noreply@linkedin.com>  2022-10-29 14:20:28 UTC-07:00
# 4     LinkedIn <jobs-noreply@linkedin.com>  2022-10-29 14:10:12 UTC-07:00
# ..                                     ...                            ...
# 292  LinkedIn <jobs-listings@linkedin.com>  2022-08-11 16:25:55 UTC-07:00
# 293   LinkedIn <jobs-noreply@linkedin.com>  2022-08-05 11:54:08 UTC-07:00
# 294   LinkedIn <jobs-noreply@linkedin.com>  2022-07-29 17:55:39 UTC-07:00
# 295  LinkedIn <jobs-listings@linkedin.com>  2022-07-28 20:04:27 UTC-07:00
# 296  LinkedIn <jobs-listings@linkedin.com>  2022-07-28 16:39:51 UTC-07:00
#
#     update_type                                           position  \
# 0      rejected  Your application to Guidance Navigation and Co...
# 1        viewed                                                NaN
# 2      rejected              Your application to Database Engineer
# 3      rejected                  Your application to Data Engineer
# 4      rejected      Your application to Back-End Python Developer
# ..          ...                                                ...
# 292     applied                                                NaN
# 293    rejected               Your application to Python Developer
# 294      viewed                                                NaN
# 295     applied                                                NaN
# 296     applied                                                NaN
#
#            company
# 0    AeroVironment
# 1              NaN
# 2      Advisor360°
# 3       Applicantz
# 4          Climate
# ..             ...
# 292            NaN
# 293       Mulberry
# 294            NaN
# 295            NaN
# 296            NaN
#
# [297 rows x 8 columns]

# %%
# from .models.Parser import 

# parsed_features = self.scrape_html(input_data['url'])
# post_data = self.parser.scrape_posting(input_data['PostID'], parsing_library="html5lib", filter_path="selenium-client.post")
# company_data = self.parser.scrape_company_data(post_data)

# data.update(parsed_features)f
# data.update(post_data)



from dotenv import dotenv_values
from models.Parser import Parser
configuration = dotenv_values(".env")
p = Parser()
more_features = [p.add_features(item) for item in app_history]
# Out:
#   Cell In [72], line 1
#     from .models.Parser import
#                                ^
# SyntaxError: invalid syntax

# %%
'''
SCRATCHWORK FOR LAMBDA FUNCTION CREATION

Creating a lambda function to convert a string containing a date into the desired date format.

Input: dictionary object containing email data
Output: formatted date string
'''


'''
EXAMPLE INPUT:
'''
dict_input =  {
    'subject': str(None),
    'body': BeautifulSoup("None", "html5lib"),
    'headers': {
        'Received' : 'by 2002:a05:6102:31b8:0:0:0:0 with SMTP id d24csp1274775vsh; Fri, 9 Sep 2022 11:37:46 -0700 (PDT)', #Location of date string
    },
}
match_pattern = '%d %b %Y %H:%M:%S %z' #Input date format
output_pattern = '%Y-%m-%d %H:%M:%S %Z' #Desired output date format


'''
FUNCTION DEFINITIONS:
Creating step by step lambdas to brainstorm the best order of the one-line solution.
The one-liner is made by collapsing each lambda with the one above

Ex:

lambda x : f(x)
lambda y : g(y)
lambda z : h(z)

becomes

lambda x : h(g(f(x)))
'''


#Individual functions to be chained together
input_method = lambda x: x['headers']['Received'].split(';')[1].split(",")[1].strip() #Locates and isolates the date string
cleaning_method = lambda x : re.sub(r"\s\(\w{3}\)","", x) #Removes time zone identifier. Since we already have the time-zone offset, we can avoid the parsing error where '%Z' doesn't match 'PDT'
convert_method = lambda x : dt.datetime.strptime(x, match_pattern) #converts string to datetime object
output_method = lambda x : x.strftime(output_pattern) #converts datetime object to desired string format.


#Parameterized version. Receives a clean string along with matching and desired date formats.
date_method = lambda string_input, match_pattern, output_pattern : dt.datetime.strptime(string_input, match_pattern).strftime(output_pattern)

#All the above as a one-line solution with parameterized formatting:
oneliner_method_with_parameters = lambda x : dt.datetime.strptime(re.sub(r"\s\(\w{3}\)","", x['headers']['Received'].split(';')[1].split(",")[1].strip()), match_pattern).strftime(output_pattern)
oneliner_method_without_parameters = lambda x : dt.datetime.strptime(re.sub(r"\s\(\w{3}\)","", x['headers']['Received'].split(';')[1].split(",")[1].strip()), '%d %b %Y %H:%M:%S %z').strftime('%Y-%m-%d %H:%M:%S %Z')


'''
OPERATIONS
'''

#Step by step operation:
input_test = input_method(dict_input) #Locates and isolates the date string
cleaning_test = cleaning_method(input_test) #Formats string for conversion
convert_test = convert_method(cleaning_test) #Converts string to a datetime object
output_test = output_method(convert_test) #Converts datetime object to desired format

#Variations on one-lining:
date_test = date_method(cleaning_test, match_pattern, output_pattern) #Converts a cleaned string to a datetime object according to the match_pattern, converts to desired output_pattern. Not used for this project, but has use elsewhere.
oneliner_test = oneliner_method_with_parameters(dict_input) #The one-line solution. Hard to read, but functional. This will be stored in our method dictionary.


'''
OUTPUTS
'''

print('input_test:\t',input_test)       #input_test:	 9 Sep 2022 11:37:46 -0700 (PDT)
print('cleaning_test:\t',cleaning_test) #cleaning_test:	 9 Sep 2022 11:37:46 -0700
print('convert_test:\t',convert_test)   #convert_test:	 2022-09-09 11:37:46-07:00
print('output_test:\t',output_test)     #output_test:	 2022-09-09 11:37:46 UTC-07:00

print('date_test:\t',date_test)         #date_test:      2022-09-09 11:37:46 UTC-07:00
print('oneliner_test:\t',oneliner_test) #oneliner_test:	 2022-09-09 11:37:46 UTC-07:00
# Out:
# input_test:	 9 Sep 2022 11:37:46 -0700 (PDT)
# cleaning_test:	 9 Sep 2022 11:37:46 -0700
# convert_test:	 2022-09-09 11:37:46-07:00
# output_test:	 2022-09-09 11:37:46 UTC-07:00
# date_test:	 2022-09-09 11:37:46 UTC-07:00
# oneliner_test:	 2022-09-09 11:37:46 UTC-07:00

# %%
testing_platform_filters

input_data = None
if input_data("platform.email.match")
    _changelog = "platform.email.scan"
    _application_info = "platform.email.{}".format(_changelog["Update_Type"])
    if "LinkedIn":
        _new_results = [method_list for method_list in "platform.selenium-client".keys()]
