# %%
import requests
import time
import csv
import re
import html5lib
from bs4 import BeautifulSoup

# %%
PostID = 3318210330
PostURL = f'https://www.linkedin.com/jobs/view/{PostID}/'

def soupify(URL, parsing_lib=None):
    parsing_lib = "html5lib" if parsing_lib==None else parsing_lib
    html_text = requests.get(URL).text
    soup = BeautifulSoup(html_text, parsing_lib)
    return soup

# try:
html_text = requests.get(PostURL).text
# print(html_text)
soup = BeautifulSoup(html_text, "html5lib")





print(soup)
# except Error as e:
#     print("Error", e)
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
#         <meta content="d_jobs_guest_details" name="pageKey"/>
# <!---->        <meta content="en_US" name="locale"/>
#         <meta data-app-version="2.0.1117" data-browser-id="7cf50c29-28a5-4cc0-81c7-8426a5c9b866" data-call-tree-id="AAXsNp49ODo4VFAkHwfDWg==" data-disable-jsbeacon-pagekey-suffix="false" data-enable-page-view-heartbeat-tracking="" data-member-id="0" data-multiproduct-name="jobs-guest-frontend" data-page-instance="urn:li:page:d_jobs_guest_details;aQO46IRPTJ6+NQ6MFlc5xw==" data-service-name="jobs-guest-frontend" id="config"/>
#         <link href="https://www.linkedin.com/jobs/view/data-analyst-at-phibro-animal-health-3318210330" rel="canonical"/>
# <!----><!---->
# <!---->
#           <meta content="https://www.linkedin.com/jobs/view/data-analyst-at-phibro-animal-health-3318210330" property="al:android:url"/>
#           <meta content="com.linkedin.android" property="al:android:package"/>
#           <meta content="LinkedIn" property="al:android:app_name"/>
#           <meta content="https://www.linkedin.com/jobs/view/data-analyst-at-phibro-animal-health-3318210330" property="al:ios:url"/>
#           <meta content="288429040" property="al:ios:app_store_id"/>
#           <meta content="LinkedIn" property="al:ios:app_name"/>
#
# <!---->
#           <link href="https://static-exp1.licdn.com/sc/h/al2o9zrvru7aqj8e1x2rzsrca" rel="icon"/>
#
#         <script>
#           function getDfd() {let yFn,nFn;const p=new Promise(function(y, n){yFn=y;nFn=n;});p.resolve=yFn;p.reject=nFn;return p;}
#           window.lazyloader = getDfd();
#           window.tracking = getDfd();
#           window.impressionTracking = getDfd();
#           window.ingraphTracking = getDfd();
#           window.appDetection = getDfd();
#           window.pemTracking = getDfd();
#         </script>
#
# <!---->
#
#         <title>Phibro Animal Health hiring Data Analyst in Teaneck, New Jersey, United States | LinkedIn</title>
#         <meta content="Posted 5:50:35 PM. Must-haves - 5+ years of experience as a Data Analyst - Basic SQL knowledge, writing scripts -…See this and similar jobs on LinkedIn." name="description"/>
#         <meta content="noarchive" name="robots"/>
#         <meta content="#293e49" name="theme-color"/>
#         <meta content="width=device-width, initial-scale=1" name="viewport"/>
#         <meta content="jobs-guest-frontend" name="litmsProfileName"/>
#         <meta content="1" data-counter-metric-endpoint="/jobs-guest/api/ingraphs/counter" data-gauge-metric-endpoint="/jobs-guest/api/ingraphs/gauge" name="clientSideIngraphs"/>
#         <meta charset="utf-8"/>
#
#         <meta content="website" property="og:type"/>
#         <meta content="Phibro Animal Health hiring Data Analyst in Teaneck, New Jersey, United States | LinkedIn" property="og:title"/>
#         <meta content="https://www.linkedin.com/jobs/view/data-analyst-at-phibro-animal-health-3318210330" property="og:url"/>
#         <meta content="Posted 5:50:35 PM. Must-haves - 5+ years of experience as a Data Analyst - Basic SQL knowledge, writing scripts -…See this and similar jobs on LinkedIn." property="og:description"/>
#         <meta content="https://static-exp1.licdn.com/sc/h/9a9u41thxt325ucfh5z8ga4m8" property="og:image"/>
#
#         <meta content="Phibro Animal Health hiring Data Analyst in Teaneck, New Jersey, United States | LinkedIn" name="twitter:title"/>
#         <meta content="summary_large_image" name="twitter:card"/>
#         <meta content="@LinkedIn" name="twitter:site"/>
#         <meta content="Posted 5:50:35 PM. Must-haves - 5+ years of experience as a Data Analyst - Basic SQL knowledge, writing scripts -…See this and similar jobs on LinkedIn." name="twitter:description"/>
#         <meta content="https://static-exp1.licdn.com/sc/h/9a9u41thxt325ucfh5z8ga4m8" name="twitter:image"/>
#           <meta content="340" name="titleId"/>
#           <meta content="41089" name="companyId"/>
#           <meta content="15" name="industryIds"/>
#           <meta content="https://www.linkedin.com/jobs/view/3318210330/" property="lnkd:url"/>
#
#
#     <script type="application/ld+json">
#       {"@context":"http://schema.org","@type":"JobPosting","datePosted":"2022-10-18T17:50:35.000Z","description":"&lt;p&gt;&lt;strong&gt;Must-haves &lt;/strong&gt;&lt;/p&gt;&lt;p&gt;- 5+ years of experience as a Data Analyst &lt;/p&gt;&lt;p&gt;- Basic SQL knowledge, writing scripts &lt;/p&gt;&lt;p&gt;- Experience with Excel &lt;/p&gt;&lt;p&gt;-On analytical side of data more than reporting &lt;/p&gt;&lt;p&gt;&lt;strong&gt; &lt;/strong&gt;&lt;/p&gt;&lt;p&gt;&lt;strong&gt;Plusses &lt;/strong&gt;&lt;/p&gt;&lt;p&gt;- Background in financial industry &lt;/p&gt;&lt;p&gt;&lt;strong&gt; &lt;/strong&gt;&lt;/p&gt;&lt;p&gt;&lt;strong&gt;Day-to-Day &lt;/strong&gt;&lt;/p&gt;&lt;ul&gt;&lt;li&gt;PAHC is seeking a Data Analyst to join their team. This person will be working with financial data, investigating discrepancies in the data, reporting issues to the teams, looking at data quality, and assisting with automation efforts currently at hand. This person will be on-site in Teaneck, NJ at least 2 days a week.&lt;/li&gt;&lt;/ul&gt;","employmentType":"FULL_TIME","hiringOrganization":{"@type":"Organization","name":"Phibro Animal Health","sameAs":"https://www.linkedin.com/company/phibro-animal-health","logo":"https://media.licdn.com/dms/image/C510BAQE0oKCD75S1fQ/company-logo_200_200/0/1519856381131?e=2147483647&amp;v=beta&amp;t=SHroImwApNFekw7gIGE-ZxYl5aYGu5w1AZ9sp1LAc2s"},"identifier":{"@type":"PropertyValue","name":"Phibro Animal Health"},"image":"https://media.licdn.com/dms/image/C510BAQE0oKCD75S1fQ/company-logo_100_100/0/1519856381131?e=2147483647&amp;v=beta&amp;t=RpLbkhNkWVL41JSX8bc9ASCqrr_3h0yY0h2Hp-fzh1w","industry":"Pharmaceutical Manufacturing","jobLocation":{"@type":"Place","address":{"@type":"PostalAddress","addressCountry":"US","addressLocality":"Teaneck","addressRegion":"NJ","streetAddress":null},"latitude":40.88482,"longitude":-74.00655},"skills":"","title":"Data Analyst","validThrough":"2022-11-17T17:50:34.000Z","educationRequirements":{"@type":"EducationalOccupationalCredential","credentialCategory":"bachelor degree"},"experienceRequirements":{"@type":"OccupationalExperienceRequirements","monthsOfExperience":60},"baseSalary":{"@type":"MonetaryAmount","currency":"USD","value":{"@type":"QuantitativeValue","minValue":115000,"maxValue":120000,"unitText":"YEAR"}}}
#     </script>
#
#
#         <link href="https://static-exp1.licdn.com/sc/h/5j6b39yz2qe3vt5rbex0fcc2" rel="stylesheet"/>
#
# <!---->      </head>
#       <body dir="ltr">
# <!----><!---->
#
#
#
#
#
#
#     <a class="skip-link btn-md btn-primary absolute z-11 -top-[100vh] focus:top-0" href="#main-content">
#       Skip to main content
#     </a>
#
#     <header class="header global-alert-offset sticky-header">
#
#
#
#
#
#
#
#     <nav aria-label="Primary" class="nav pt-1.5 pb-2 flex items-center justify-between relative flex-nowrap babybear:flex-wrap babybear:py-1.5 nav--minified-mobile babybear:flex-wrap">
#
# <!---->
#       <a class="nav__logo-link link-no-visited-state z-1 mr-auto babybear:z-0 babybear:mr-0 babybear:flex-1 hover:no-underline focus:no-underline active:no-underline" data-tracking-control-name="public_jobs_nav-header-logo" data-tracking-will-navigate="" href="/?trk=public_jobs_nav-header-logo">
#
#
#
#     <span class="sr-only">LinkedIn</span>
#       <icon class="text-color-brand papabear:hidden mamabear:hidden babybear:block babybear:h-[27px]" data-delayed-url="https://static-exp1.licdn.com/sc/h/4zqr0f9jf98vi2nkijyc3bex2" data-test-id="nav-logo--mobile-inbug"></icon>
#     <icon class="block text-color-brand w-[84px] h-[21px] papabear:w-[135px] papabear:h-[34px] babybear:hidden" data-delayed-url="https://static-exp1.licdn.com/sc/h/8fkga714vy9b2wk5auqo5reeb" data-test-id="nav-logo"></icon>
#
#
#       </a>
#
#
#
#
#
#
#
#
#     <section class="search-bar search-bar--minified-mobile" data-current-search-type="JOBS">
#       <button class="search-bar__placeholder show-on-mobile hide-on-desktop" data-tracking-control-name="public_jobs_search-switcher-opener">
#         <div class="search-bar__full-placeholder">
# <!---->              Data Analyst in Fresno, CA
# <!---->        </div>
#         <span class="sr-only">Expand search</span>
#       </button>
#
#
#
#
#
#
#
#
#
#     <div class="switcher-tabs__trigger-and-tabs">
#       <button aria-expanded="false" class="switcher-tabs__placeholder hide-on-mobile" data-tracking-control-name="public_jobs_switcher-tabs-placeholder">
#         <span class="switcher-tabs__placeholder-text"></span>
#         <icon class="switcher-tabs__caret-down-filled onload" data-delayed-url="https://static-exp1.licdn.com/sc/h/7asbl4deqijhoy3z2ivveispv"></icon>
#       </button>
#
#       <div class="switcher-tabs hide-on-desktop hide-on-mobile">
#         <ul class="switcher-tabs__list" role="tablist">
#           <li aria-selected="true" class="switcher-tabs__tab switcher-tabs__tab--active" role="tab">
#             <button class="switcher-tabs__button" data-switcher-type="JOBS" data-tracking-control-name="public_jobs_switcher-tabs-jobs-search-switcher" type="button">
#               Jobs
#             </button>
#           </li>
#           <li aria-selected="false" class="switcher-tabs__tab" role="tab">
#             <button class="switcher-tabs__button" data-switcher-type="PEOPLE" data-tracking-control-name="public_jobs_switcher-tabs-people-search-switcher" type="button">
#               People
#             </button>
#           </li>
#           <li aria-selected="false" class="switcher-tabs__tab" role="tab">
#             <button class="switcher-tabs__button" data-switcher-type="LEARNING" data-tracking-control-name="public_jobs_switcher-tabs-learning-search-switcher" type="button">
#               Learning
#             </button>
#           </li>
#         </ul>
#
#         <button aria-label="Close" class="switcher-tabs__cancel-btn hide-on-desktop" data-tracking-control-name="public_jobs_switcher-tabs-cancel-search-switcher" type="button">
#           <icon class="switcher-tabs__cancel-icon onload" data-delayed-url="https://static-exp1.licdn.com/sc/h/cs55jggk4p3uqh9ozxdmpvjg7"></icon>
#         </button>
#       </div>
#     </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <section class="base-search-bar w-full h-full" data-searchbar-type="PEOPLE">
#       <form action="/pub/dir" class="base-search-bar__form w-full h-fit flex babybear:mx-mobile-container-padding babybear:flex-col" data-tracking-control-name="public_jobs_people-search-bar_base-search-bar-form" role="search">
#
#
#
#
#
#     <section class="dismissable-input search-input">
#       <input aria-label="First Name" autocomplete="on" class="dismissable-input__input" data-tracking-control-name="public_jobs_people-search-bar_first-name_dismissable-input" maxlength="500" name="firstName" placeholder="First Name" type="search"/>
#
#         <button class="dismissable-input__button" data-tracking-control-name="public_jobs_people-search-bar_first-name_dismissable-input-clear" type="button">
#           <label class="sr-only">Dismiss</label>
#           <icon class="dismissable-input__button-icon" data-delayed-url="https://static-exp1.licdn.com/sc/h/cs55jggk4p3uqh9ozxdmpvjg7"></icon>
#         </button>
#     </section>
#
#
#
#
#
#
#     <section class="dismissable-input search-input">
#       <input aria-label="Last Name" autocomplete="on" class="dismissable-input__input" data-tracking-control-name="public_jobs_people-search-bar_last-name_dismissable-input" maxlength="500" name="lastName" placeholder="Last Name" type="search"/>
#
#         <button class="dismissable-input__button" data-tracking-control-name="public_jobs_people-search-bar_last-name_dismissable-input-clear" type="button">
#           <label class="sr-only">Dismiss</label>
#           <icon class="dismissable-input__button-icon" data-delayed-url="https://static-exp1.licdn.com/sc/h/cs55jggk4p3uqh9ozxdmpvjg7"></icon>
#         </button>
#     </section>
#
#
#
#         <input name="trk" type="hidden" value="public_jobs_people-search-bar_search-submit"/>
#         <button aria-label="Search" class="base-search-bar__submit-btn block basis-[40px] flex-shrink-0 cursor-pointer babybear:invisible babybear:ml-[-9999px] babybear:w-[1px] babybear:h-[1px]" data-tracking-control-name="public_jobs_people-search-bar_base-search-bar-search-submit" type="submit">
#           <icon class="base-search-bar__search-icon onload mx-auto" data-delayed-url="https://static-exp1.licdn.com/sc/h/cb5bsr4tsn2r4sjg9e3ls4tjl"></icon>
#         </button>
#       </form>
#     </section>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <section class="base-search-bar w-full h-full" data-searchbar-type="JOBS">
#       <form action="/jobs/search" class="base-search-bar__form w-full h-fit flex babybear:mx-mobile-container-padding babybear:flex-col" data-tracking-control-name="public_jobs_jobs-search-bar_base-search-bar-form" role="search">
#
#
#
#
#
#
#
#     <code id="i18n_aria_live_text_no-suggestions" style="display: none"><!--"No suggestions found"--></code>
#     <code id="i18n_aria_live_text_one-suggestion" style="display: none"><!--"One Suggestion. Use up and down keys to navigate"--></code>
#     <code id="i18n_aria_live_text_multiple-suggestions" style="display: none"><!--"Multiple Suggestions. Use up and down keys to navigate"--></code>
#
#
#
#
#     <section class="dismissable-input typeahead-input keywords-typeahead-input text-input">
#       <input aria-autocomplete="list" aria-controls="job-search-bar-keywords-typeahead-list" aria-haspopup="listbox" aria-label="Search job titles or companies" autocomplete="off" class="dismissable-input__input" data-tracking-control-name="public_jobs_dismissable-input" maxlength="500" name="keywords" placeholder="Search job titles or companies" role="combobox" type="search" value="Data Analyst"/>
#
# <!---->      <div class="typeahead-input__dropdown">
#         <template class="typeahead-item-template">
#           <li class="typeahead-input__dropdown-item" role="option">
#             <span class="typeahead-input__dropdown-text"></span>
#           </li>
#         </template>
#
#         <ul class="typeahead-input__dropdown-list" id="job-search-bar-keywords-typeahead-list" role="listbox"></ul>
#       </div>
# <!---->
#         <button class="dismissable-input__button" data-tracking-control-name="public_jobs_dismissable-input-clear" type="button">
#           <label class="sr-only">Dismiss</label>
#           <icon class="dismissable-input__button-icon" data-delayed-url="https://static-exp1.licdn.com/sc/h/cs55jggk4p3uqh9ozxdmpvjg7"></icon>
#         </button>
#     </section>
#
#
# <!---->
#
#
#
#
#
#     <code id="i18n_aria_live_text_no-suggestions" style="display: none"><!--"No suggestions found"--></code>
#     <code id="i18n_aria_live_text_one-suggestion" style="display: none"><!--"One Suggestion. Use up and down keys to navigate"--></code>
#     <code id="i18n_aria_live_text_multiple-suggestions" style="display: none"><!--"Multiple Suggestions. Use up and down keys to navigate"--></code>
#
#
#
#
#     <section class="dismissable-input typeahead-input location-typeahead-input">
#       <input aria-autocomplete="list" aria-controls="job-search-bar-location-typeahead-list" aria-haspopup="listbox" aria-label="Location" autocomplete="off" class="dismissable-input__input" data-tracking-control-name="public_jobs_dismissable-input" maxlength="500" name="location" placeholder="Location" role="combobox" type="search" value="Fresno, CA"/>
#
# <!---->      <div class="typeahead-input__dropdown">
#         <template class="typeahead-item-template">
#           <li class="typeahead-input__dropdown-item" role="option">
#             <span class="typeahead-input__dropdown-text"></span>
#           </li>
#         </template>
#
#         <ul class="typeahead-input__dropdown-list" id="job-search-bar-location-typeahead-list" role="listbox"></ul>
#       </div>
# <!---->
#         <button class="dismissable-input__button" data-tracking-control-name="public_jobs_dismissable-input-clear" type="button">
#           <label class="sr-only">Dismiss</label>
#           <icon class="dismissable-input__button-icon" data-delayed-url="https://static-exp1.licdn.com/sc/h/cs55jggk4p3uqh9ozxdmpvjg7"></icon>
#         </button>
#     </section>
#
#
#         <input name="geoId" type="hidden" value="100969510"/>
#
#         <input name="trk" type="hidden" value="public_jobs_jobs-search-bar_search-submit"/>
#         <button aria-label="Search" class="base-search-bar__submit-btn block basis-[40px] flex-shrink-0 cursor-pointer babybear:invisible babybear:ml-[-9999px] babybear:w-[1px] babybear:h-[1px]" data-tracking-control-name="public_jobs_jobs-search-bar_base-search-bar-search-submit" type="submit">
#           <icon class="base-search-bar__search-icon onload mx-auto" data-delayed-url="https://static-exp1.licdn.com/sc/h/cb5bsr4tsn2r4sjg9e3ls4tjl"></icon>
#         </button>
#       </form>
#     </section>
#
#
#
#
#
#
#
#
#
#
#
#     <section class="base-search-bar w-full h-full" data-searchbar-type="LEARNING">
#       <form action="/learning/search" class="base-search-bar__form w-full h-fit flex babybear:mx-mobile-container-padding babybear:flex-col" data-tracking-control-name="public_jobs_learning-search-bar_base-search-bar-form" role="search">
#
#
#
#
#
#     <section class="dismissable-input search-input">
#       <input aria-label="Search skills, subjects, or software" autocomplete="on" class="dismissable-input__input" data-tracking-control-name="public_jobs_learning-search-bar_keywords_dismissable-input" maxlength="500" name="keywords" placeholder="Search skills, subjects, or software" type="search" value="Data Analyst"/>
#
#         <button class="dismissable-input__button" data-tracking-control-name="public_jobs_learning-search-bar_keywords_dismissable-input-clear" type="button">
#           <label class="sr-only">Dismiss</label>
#           <icon class="dismissable-input__button-icon" data-delayed-url="https://static-exp1.licdn.com/sc/h/cs55jggk4p3uqh9ozxdmpvjg7"></icon>
#         </button>
#     </section>
#
#
#         <input class="nav__search-uoo" name="upsellOrderOrigin" type="hidden"/>
#
#
#         <input name="trk" type="hidden" value="public_jobs_learning-search-bar_search-submit"/>
#         <button aria-label="Search" class="base-search-bar__submit-btn block basis-[40px] flex-shrink-0 cursor-pointer babybear:invisible babybear:ml-[-9999px] babybear:w-[1px] babybear:h-[1px]" data-tracking-control-name="public_jobs_learning-search-bar_base-search-bar-search-submit" type="submit">
#           <icon class="base-search-bar__search-icon onload mx-auto" data-delayed-url="https://static-exp1.licdn.com/sc/h/cb5bsr4tsn2r4sjg9e3ls4tjl"></icon>
#         </button>
#       </form>
#     </section>
#
#
#         <div aria-live="polite" class="search-bar__live-text sr-only" role="status"></div>
#
#
#     </section>
#
#
# <!---->
#       <div class="nav__cta-container order-3 flex gap-x-1 justify-end min-w-[100px] flex-nowrap flex-shrink-0 babybear:flex-wrap flex-2">
#
#
#     <a class="nav__button-tertiary btn-md btn-tertiary" data-test-live-nav-primary-cta="" data-tracking-control-name="public_jobs_nav-header-join" data-tracking-will-navigate="" href="https://www.linkedin.com/signup/cold-join?source=jobs_registration&amp;session_redirect=https%3A%2F%2Fwww.linkedin.com%2Fjobs%2Fview%2F3318210330%2F&amp;trk=public_jobs_nav-header-join">
#       Join now
#     </a>
#
#
#
#
#       <a class="nav__button-secondary btn-md btn-secondary-emphasis" data-tracking-control-name="public_jobs_nav-header-signin" data-tracking-will-navigate="" href="https://www.linkedin.com/login?session_redirect=https%3A%2F%2Fwww%2Elinkedin%2Ecom%2Fjobs%2Fview%2Fdata-analyst-at-phibro-animal-health-3318210330&amp;fromSignIn=true&amp;trk=public_jobs_nav-header-signin">
#         Sign in
#       </a>
#
#
#           <a aria-label="Sign in" class="nav__link-person papabear:hidden mamabear:hidden" data-tracking-control-name="public_jobs_nav-header-signin" data-tracking-will-navigate="" href="https://www.linkedin.com/login?session_redirect=https%3A%2F%2Fwww%2Elinkedin%2Ecom%2Fjobs%2Fview%2Fdata-analyst-at-phibro-animal-health-3318210330&amp;fromSignIn=true&amp;trk=public_jobs_nav-header-signin">
#
#       <img alt="" class="inline-block relative rounded-[50%] w-4 h-4 bg-color-entity-ghost-background" data-delayed-url="https://static-exp1.licdn.com/sc/h/9c8pery4andzj6ohjkjp54ma2" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static-exp1.licdn.com/sc/h/9c8pery4andzj6ohjkjp54ma2"/>
#
#           </a>
#       </div>
#
# <!---->
# <!---->    </nav>
#
#
#     </header>
#
#
# <!---->
#
# <!---->
#     <main class="main" id="main-content" role="main">
#       <section class="core-rail">
#
#
#
#
#         <div class="details">
#
#
#
#
#
#       <section class="sub-nav-cta global-alert-offset" data-impression-id="public_jobs_sub-nav-cta">
#         <div class="sub-nav-cta__content">
#
#
#
#       <img alt="Phibro Animal Health" class="artdeco-entity-image artdeco-entity-image--square-3 sub-nav-cta__image" data-delayed-url="https://media.licdn.com/dms/image/C510BAQE0oKCD75S1fQ/company-logo_100_100/0/1519856381131?e=2147483647&amp;v=beta&amp;t=RpLbkhNkWVL41JSX8bc9ASCqrr_3h0yY0h2Hp-fzh1w" data-ghost-classes="artdeco-entity-image--ghost" data-ghost-url="https://static-exp1.licdn.com/sc/h/9a9u41thxt325ucfh5z8ga4m8"/>
#
#           <div class="sub-nav-cta__text-container">
#             <h3 class="sub-nav-cta__header">Data Analyst</h3>
#               <div class="sub-nav-cta__sub-text-container">
#                   <a class="sub-nav-cta__optional-url" data-tracking-control-name="public_jobs_sub-nav-cta-optional-url" data-tracking-will-navigate="" href="https://www.linkedin.com/company/phibro-animal-health?trk=public_jobs_sub-nav-cta-optional-url" title="Phibro Animal Health">Phibro Animal Health</a>
#
#                   <span class="sub-nav-cta__meta-text">Teaneck, NJ</span>
#               </div>
#           </div>
#
#
#
#
#
#       <button class="apply-button apply-button--default btn-md btn-primary" data-reference-id="25AtnvfwSSqG29BSr+TDEg==" data-tracking-control-name="public_jobs_apply-link-onsite" id="topbar-apply">
#         Apply
#       </button>
#
#
#         </div>
#       </section>
#
#
#
#
#
#
#
#     <section class="top-card-layout container-lined overflow-hidden babybear:rounded-[0px]">
#
#
#
#       <div class="top-card-layout__card relative p-2 papabear:p-details-container-padding">
#
#
#       <a data-tracking-control-name="public_jobs_topcard_logo" data-tracking-will-navigate="" href="https://www.linkedin.com/company/phibro-animal-health?trk=public_jobs_topcard_logo" target="_self">
#
#
#       <img alt="Phibro Animal Health" class="artdeco-entity-image artdeco-entity-image--square-5" data-delayed-url="https://media.licdn.com/dms/image/C510BAQE0oKCD75S1fQ/company-logo_100_100/0/1519856381131?e=2147483647&amp;v=beta&amp;t=RpLbkhNkWVL41JSX8bc9ASCqrr_3h0yY0h2Hp-fzh1w" data-ghost-classes="artdeco-entity-image--ghost" data-ghost-url="https://static-exp1.licdn.com/sc/h/9a9u41thxt325ucfh5z8ga4m8"/>
#
#
#       </a>
#
#
#
#           <div class="top-card-layout__entity-info-container flex flex-wrap papabear:flex-nowrap">
#             <div class="top-card-layout__entity-info flex-grow flex-shrink-0 basis-0 babybear:flex-none babybear:w-full babybear:flex-none babybear:w-full">
#
#           <h1 class="top-card-layout__title font-sans text-lg papabear:text-xl font-bold leading-open text-color-text mb-0 topcard__title">Data Analyst</h1>
#
# <!---->
# <!---->
#                 <h4 class="top-card-layout__second-subline font-sans text-sm leading-open text-color-text-low-emphasis mt-0.5">
#
#         <div class="topcard__flavor-row">
#           <span class="topcard__flavor">
#               <a class="topcard__org-name-link topcard__flavor--black-link" data-tracking-control-name="public_jobs_topcard-org-name" data-tracking-will-navigate="" href="https://www.linkedin.com/company/phibro-animal-health?trk=public_jobs_topcard-org-name" rel="noopener" target="_blank">
#                 Phibro Animal Health
#               </a>
#           </span>
#             <span class="topcard__flavor topcard__flavor--bullet">
#               Teaneck, NJ
#             </span>
#         </div>
#         <div class="topcard__flavor-row">
#
#       <span class="posted-time-ago__text topcard__flavor--metadata">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     1 week ago
#
#       </span>
#
#
#
#
#
#
#         <span class="num-applicants__caption topcard__flavor--metadata topcard__flavor--bullet">
#           110 applicants
#         </span>
#
#         </div>
#
#
#
#
#
#     <div class="face-pile flex see-who-was-hired">
#       <div class="face-pile__images-container self-start flex-shrink-0 mr-1 leading-[1]">
#
#       <img alt="" class="inline-block relative rounded-[50%] w-4 h-4 face-pile__image border-1 border-solid border-color-transparent -ml-2 first:ml-0" data-delayed-url="https://static-exp1.licdn.com/sc/h/9xu9nvkhqn88oqusz8vit8jn1" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static-exp1.licdn.com/sc/h/9c8pery4andzj6ohjkjp54ma2"/>
#
#
#       <img alt="" class="inline-block relative rounded-[50%] w-4 h-4 face-pile__image border-1 border-solid border-color-transparent -ml-2 first:ml-0" data-delayed-url="https://static-exp1.licdn.com/sc/h/5vnaamtwzolc4fzm3bnyri2ps" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static-exp1.licdn.com/sc/h/9c8pery4andzj6ohjkjp54ma2"/>
#
#
#       <img alt="" class="inline-block relative rounded-[50%] w-4 h-4 face-pile__image border-1 border-solid border-color-transparent -ml-2 first:ml-0" data-delayed-url="https://static-exp1.licdn.com/sc/h/dllr01kyryecqdysdilses9oh" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static-exp1.licdn.com/sc/h/9c8pery4andzj6ohjkjp54ma2"/>
#
#       </div>
#           <a class="face-pile__cta self-center link-no-visited-state" data-tracking-control-name="public_jobs_see-who-was-hired_people-search-link_face-pile-cta" data-tracking-will-navigate="" href="https://www.linkedin.com/login?session_redirect=https%3A%2F%2Fwww%2Elinkedin%2Ecom%2Fsearch%2Fresults%2Fpeople%2F%3FfacetCurrentCompany%3D41089%26title%3DData%2BAnalyst&amp;emailAddress=&amp;fromSignIn=&amp;trk=public_jobs_see-who-was-hired_people-search-link_face-pile-cta">
#             See who Phibro Animal Health has hired for this role
#           </a>
#     </div>
#
#
#
# <!---->
#                 </h4>
#
#               <div class="top-card-layout__cta-container flex flex-wrap mt-0.5 papabear:mt-0 ml-[-12px]">
#
#
#
#
#
#       <button class="apply-button apply-button--default top-card-layout__cta mt-2 ml-1.5 h-auto babybear:flex-auto top-card-layout__cta--primary btn-md btn-primary" data-reference-id="25AtnvfwSSqG29BSr+TDEg==" data-tracking-control-name="public_jobs_apply-link-onsite">
#         Apply
#       </button>
#
#
#
#
#           <button class="top-card-layout__cta mt-2 ml-1.5 h-auto babybear:flex-auto top-card-layout__cta--secondary btn-md btn-secondary save-job-modal-outlet" data-impression-id="public_jobs_topcard-save-job" data-modal="save-job-modal-outlet" data-tracking-control-name="public_jobs_topcard-save-job">
#             Save
#           </button>
#
#
#
#
#
#
#     <div class="">
# <!---->
#       <div class="modal save-job-modal" data-outlet="save-job-modal-outlet" id="save-job-modal">
#         <div class="modal__overlay flex items-center bg-color-background-scrim justify-center fixed bottom-0 left-0 right-0 top-0 opacity-0 invisible pointer-events-none z-[1000] transition-[opacity] ease-[cubic-bezier(0.25,0.1,0.25,1.0)] duration-[0.17s] py-4">
#           <section aria-labelledby="save-job-modal-modal-header" aria-modal="true" class="max-h-full modal__wrapper overflow-auto p-0 bg-color-background-container max-w-[1128px] min-h-[160px] relative scale-[0.25] shadow-sm shadow-color-border-faint transition-[transform] ease-[cubic-bezier(0.25,0.1,0.25,1.0)] duration-[0.33s] focus:outline-0 w-[1128px] mamabear:w-[744px] babybear:w-[360px] rounded-md" role="dialog" tabindex="-1">
#               <header class="modal__header flex items-center justify-between border-b-1 border-solid border-color-border-faint py-1.5 px-3">
#                   <h2 class="modal__title font-normal leading-open text-color-text text-lg" id="save-job-modal-modal-header">Save job</h2>
#                 <button aria-label="Dismiss" class="modal__dismiss modal__dismiss--with-icon btn-tertiary h-[40px] w-[40px] p-0 rounded-full indent-0" data-tracking-control-name="public_jobs_save-job-modal_modal_dismiss" type="button">
#                     <icon class="modal__dismiss-icon relative top-[2px]" data-delayed-url="https://static-exp1.licdn.com/sc/h/gs508lg3t2o81tq7pmcgn6m2"></icon>
#                 </button>
# <!---->              </header>
#             <main class="modal__main w-full">
#
#
#     <div class="loader loader--absolute">
#       <div class="loader__container mb-2 overflow-hidden">
#         <icon class="loader__icon inline-block loader__icon--muted text-color-icon-active" data-delayed-url="https://static-exp1.licdn.com/sc/h/ddi43qwelxeqjxdd45pe3fvs1" data-svg-class-name="loader__icon-svg--small fill-currentColor h-[30px] min-h-[30px] w-[30px] min-w-[30px]"></icon>
#       </div>
#     </div>
#
#
#
#
#
#
#
#
#
#     <code id="i18n_save_job_form_email_check_error" style="display: none"><!--"We’re sorry, something went wrong on our end. Please try again."--></code>
#
#
#
#
#
#     <div class="email-input-page save-job-form-page">
#
#       <form class="email-input-page__content-new-user">
#         <div class="email-input-page__content">
#           <h3 class="email-input-page__header">
#
#         <figure class="save-job-form__inbug">
#           <icon data-delayed-url="https://static-exp1.licdn.com/sc/h/ercwkzy8m5jnkaliyweviswct" data-svg-class-name="save-job-form__inbug-icon"></icon>
#         </figure>
#         Save this job with your existing LinkedIn profile, or create a new one.
#
#           </h3>
#           <span class="email-input-page__body">
#
#         Your job seeking activity is only visible to you.
#
#           </span>
#
#     <div class="mt-1.5" data-js-module-id="guest-input">
#       <div class="flex flex-col">
#         <label class="input-label mb-1" for="public_jobs_save-job_email-input">
#           Email
#         </label>
#         <div class="text-input flex">
#           <input autocomplete="off" class="text-color-text font-sans text-md outline-0 bg-color-transparent grow" data-tracking-control-name="public_jobs_save-job_enter-email" id="public_jobs_save-job_email-input" name="email-input-page__input" placeholder="Email address" required="" type="text"/>
#
#         </div>
#       </div>
#
#       <p class="input-helper mt-1.5" data-js-module-id="guest-input__message" for="public_jobs_save-job_email-input" role="alert"></p>
#     </div>
#
#
#           <code id="email-input-page-error-message" style="display: none"><!--"Please enter a valid email address."--></code>
#         </div>
#
#         <footer class="save-job-form__footer">
#           <button class="save-job-form__button" data-tracking-control-name="public_jobs_save-job-form-continue" type="submit">
#             Continue
#           </button>
#         </footer>
#
#       </form>
#
#
#
#     <div class="welcome-back-sign-in-form welcome-back-sign-in-form--hidden" data-impression-id="save-job-sign-in-form">
#       <h3 class="welcome-back-sign-in-form__header">
#         Welcome back
#       </h3>
#
#         <p class="welcome-back-sign-in-form__subline">
#
#
#         Sign in to save <b>Data Analyst</b> at <b>Phibro Animal Health</b>.
#
#
#         </p>
#
#
#
#
#
#
#
#
#
#
#
#
#     <code id="i18n_sign_in_form_show_text" style="display: none"><!--"Show"--></code>
#     <code id="i18n_sign_in_form_show_label" style="display: none"><!--"Show your LinkedIn password"--></code>
#     <code id="i18n_sign_in_form_hide_text" style="display: none"><!--"Hide"--></code>
#     <code id="i18n_sign_in_form_hide_label" style="display: none"><!--"Hide your LinkedIn password"--></code>
#
#
#     <code id="i18n_username_error_empty" style="display: none"><!--"Please enter an email address or phone number"--></code>
#
#     <code id="i18n_username_error_too_long" style="display: none"><!--"Email or phone number must be between 3 to 128 characters"--></code>
#     <code id="i18n_username_error_too_short" style="display: none"><!--"Email or phone number must be between 3 to 128 characters"--></code>
#
#
#     <code id="i18n_password_error_empty" style="display: none"><!--"Please enter a password"--></code>
#
#     <code id="i18n_password_error_too_short" style="display: none"><!--"The password you provided must have at least 6 characters"--></code>
#
#     <code id="i18n_password_error_too_long" style="display: none"><!--"The password you provided must have at most 400 characters"--></code>
#
#     <form action="https://www.linkedin.com/uas/login-submit" class="save-job-form-sign-in-form" data-id="sign-in-form" method="post" novalidate="">
#       <input name="loginCsrfParam" type="hidden" value="7cf50c29-28a5-4cc0-81c7-8426a5c9b866"/>
#
#       <div class="flex flex-col">
#
#     <div class="mt-1.5" data-js-module-id="guest-input">
#       <div class="flex flex-col">
#         <label class="input-label mb-1" for="session_key">
#           Email or phone
#         </label>
#         <div class="text-input flex">
#           <input autocomplete="username" class="text-color-text font-sans text-md outline-0 bg-color-transparent grow" id="session_key" name="session_key" required="" type="text"/>
#
#         </div>
#       </div>
#
#       <p class="input-helper mt-1.5" data-js-module-id="guest-input__message" for="session_key" role="alert"></p>
#     </div>
#
#
#
#     <div class="mt-1.5" data-js-module-id="guest-input">
#       <div class="flex flex-col">
#         <label class="input-label mb-1" for="session_password">
#           Password
#         </label>
#         <div class="text-input flex">
#           <input autocomplete="current-password" class="text-color-text font-sans text-md outline-0 bg-color-transparent grow" id="session_password" name="session_password" required="" type="password"/>
#
#             <button aria-label="Show your LinkedIn password" class="font-sans text-md font-bold text-color-action z-10 ml-[12px] hover:cursor-pointer" data-id="sign-in-form__password-visibility-toggle" data-tracking-control-name="public_jobs_save-job_sign-in-password-visibility-toggle-btn" type="button">Show</button>
#
#         </div>
#       </div>
#
#       <p class="input-helper mt-1.5" data-js-module-id="guest-input__message" for="session_password" role="alert"></p>
#     </div>
#
#
#         <input name="session_redirect" type="hidden" value="https://www.linkedin.com/jobs/view/data-analyst-at-phibro-animal-health-3318210330"/>
#
# <!---->      </div>
#
#       <div class="flex justify-between items-center mt-[16px]" data-id="sign-in-form__footer">
#         <a class="font-sans text-md font-bold link leading-regular" data-id="sign-in-form__forgot-password" data-tracking-control-name="public_jobs_save-job_forgot_password" data-tracking-will-navigate="" href="https://www.linkedin.com/uas/request-password-reset?trk=public_jobs_save-job_forgot_password">Forgot password?</a>
#
# <!---->
#         <input name="trk" type="hidden" value="public_jobs_save-job_sign-in-submit"/>
#         <button class="btn-md btn-primary !text-[20px] px-[24px] flex-shrink-0 cursor-pointer ml-[8px]" data-id="sign-in-form__submit-btn" data-tracking-control-name="public_jobs_save-job_sign-in-submit-btn" data-tracking-litms="" type="submit">
#           Sign in
#         </button>
#       </div>
#     </form>
#
#     </div>
#
#     </div>
#
#
#
#             </main>
#
# <!---->          </section>
#         </div>
#       </div>
#     </div>
#
#
#
#               </div>
#             </div>
#
# <!---->          </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#       <div class="ellipsis-menu absolute right-0 top-0 top-card-layout__ellipsis-menu mr-1 papabear:mt-0.5 papabear:mr-2">
#
#
#
#
#     <div class="collapsible-dropdown flex items-center relative hyphens-auto">
#
#             <button aria-expanded="false" aria-label="Open menu" class="ellipsis-menu__trigger collapsible-dropdown__button btn-md btn-tertiary cursor-pointer !py-[6px] !px-1 flex items-center rounded-[50%]" data-tracking-control-name="public_jobs_ellipsis-menu-trigger">
#               <icon class="ellipsis-menu__trigger-icon m-0 p-0 centered-icon" data-delayed-url="https://static-exp1.licdn.com/sc/h/671xosfpvk4c0kqtyl87hashi"></icon>
#             </button>
#
#
#         <ul class="collapsible-dropdown__list hidden container-raised absolute w-auto overflow-y-auto flex-col items-stretch z-1 bottom-auto top-[100%]" role="menu" tabindex="-1">
#
#
#
#                 <li class="ellipsis-menu__item border-t-1 border-solid border-color-border-low-emphasis first-of-type:border-none">
#                   <a class="ellipsis-menu__item-button flex items-center w-full p-1 cursor-pointer font-sans text-sm font-bold link-styled focus:link-styled link:no-underline active:bg-color-background-container-tint focus:bg-color-background-container-tint hover:bg-color-background-container-tint" data-tracking-control-name="public_jobs_ellipsis-menu-sign-in-redirect" data-tracking-will-navigate="" href="https://www.linkedin.com/login?session_redirect=https%3A%2F%2Fwww%2Elinkedin%2Ecom%2Fjobs%2Fview%2Fdata-analyst-at-phibro-animal-health-3318210330&amp;fromSignIn=true&amp;trk=public_jobs_ellipsis-menu-sign-in-redirect">
#                     <icon class="ellipsis-menu__item-icon text-color-text h-[24px] w-[24px] mr-1" data-delayed-url="https://static-exp1.licdn.com/sc/h/iq0x9q37wj214o129ai1yjut"></icon>
#                     Report this company
#                   </a>
#                 </li>
#
#         </ul>
#
# <!---->    </div>
#
#
#       </div>
#
#
# <!---->      </div>
#     </section>
#
#
#
#     <div class="decorated-job-posting__details">
# <!---->
#
#
#
#
#
#
#
#
#     <section class="core-section-container my-3 description">
# <!---->
# <!---->
# <!---->
#       <div class="core-section-container__content break-words">
#
#
#
#
#
#     <div class="message-the-recruiter">
#       <p>Direct message the job poster from Phibro Animal Health</p>
#
#
#
#
#
#
# <!---->
#
#       <div class="base-card relative w-full hover:no-underline focus:no-underline base-main-card flex flex-wrap py-2 pr-2 babybear:pr-0">
#
#
# <!---->
#
#
#       <img alt="Emma Zazzali" class="inline-block relative rounded-[50%] w-6 h-6" data-delayed-url="https://media-exp1.licdn.com/dms/image/C4E03AQFEs53Vs2OZ2g/profile-displayphoto-shrink_100_100/0/1659991458522?e=1672876800&amp;v=beta&amp;t=3O_t86WLA8ydMuXscfEa0fQ0AovuPLo9Hs34R6pRZ6g" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static-exp1.licdn.com/sc/h/9c8pery4andzj6ohjkjp54ma2"/>
#
#
#         <div class="base-main-card__info self-center ml-1 flex-1">
#           <h3 class="base-main-card__title font-sans text-[18px] font-bold text-color-text overflow-hidden">
#
#         Emma Zazzali
#
# <!---->
#           </h3>
#
#             <h4 class="base-main-card__subtitle body-text text-color-text overflow-hidden">
#
#         Recruiter at Insight Global
#
#             </h4>
#
# <!---->
# <!---->        </div>
#
#           <div class="base-main-card__ctas z-[3] self-center ml-3 babybear:ml-1">
#
#
#           <a aria-label="Message Emma Zazzali" class="message-the-recruiter__cta" data-tracking-control-name="public_jobs_message-the-recruiter-cta" data-tracking-will-navigate="" href="https://www.linkedin.com/login?session_redirect=https%3A%2F%2Fwww%2Elinkedin%2Ecom%2Fin%2Femmazazzali&amp;emailAddress=&amp;fromSignIn=&amp;trk=public_jobs_message-the-recruiter-cta">
#             <icon class="message-the-recruiter__cta-icon" data-delayed-url="https://static-exp1.licdn.com/sc/h/em62t8ujch4hqqc45owxy6auu" data-tracking-will-navigate=""></icon>
#           </a>
#
#
#           </div>
#
#
#       </div>
#
#
#
#
#     </div>
#
#
#     <div class="description__text description__text--rich">
#
#     <section class="show-more-less-html" data-max-lines="5">
#       <div class="show-more-less-html__markup show-more-less-html__markup--clamp-after-5">
#         <p><strong>Must-haves </strong></p><p>- 5+ years of experience as a Data Analyst </p><p>- Basic SQL knowledge, writing scripts </p><p>- Experience with Excel </p><p>-On analytical side of data more than reporting </p><p><strong> </strong></p><p><strong>Plusses </strong></p><p>- Background in financial industry </p><p><strong> </strong></p><p><strong>Day-to-Day </strong></p><ul><li>PAHC is seeking a Data Analyst to join their team. This person will be working with financial data, investigating discrepancies in the data, reporting issues to the teams, looking at data quality, and assisting with automation efforts currently at hand. This person will be on-site in Teaneck, NJ at least 2 days a week.</li></ul>
#       </div>
#
#
#
#
#
#
#
#     <button aria-expanded="false" aria-label="Show more, visually expands previously read content above" class="show-more-less-html__button show-more-less-html__button--more" data-tracking-control-name="public_jobs_show-more-html-btn">
#         Show more
#
#         <icon class="show-more-less-html__button-icon" data-delayed-url="https://static-exp1.licdn.com/sc/h/cyolgscd0imw2ldqppkrb84vo"></icon>
#     </button>
#
#
#
#
#
#
#
#
#     <button aria-expanded="true" aria-label="Show less" class="show-more-less-html__button show-more-less-html__button--less" data-tracking-control-name="public_jobs_show-less-html-btn">
#         Show less
#
#         <icon class="show-more-less-html__button-icon" data-delayed-url="https://static-exp1.licdn.com/sc/h/4chtt12k98xwnba1nimld2oyg"></icon>
#     </button>
#
#     </section>
#
#     </div>
#
#     <ul class="description__job-criteria-list">
#         <li class="description__job-criteria-item">
#           <h3 class="description__job-criteria-subheader">
#             Seniority level
#           </h3>
#           <span class="description__job-criteria-text description__job-criteria-text--criteria">
#             Mid-Senior level
#           </span>
#         </li>
#       <li class="description__job-criteria-item">
#         <h3 class="description__job-criteria-subheader">
#           Employment type
#         </h3>
#         <span class="description__job-criteria-text description__job-criteria-text--criteria">
#           Full-time
#         </span>
#       </li>
#         <li class="description__job-criteria-item">
#           <h3 class="description__job-criteria-subheader">
#             Job function
#           </h3>
#           <span class="description__job-criteria-text description__job-criteria-text--criteria">
#             Information Technology
#           </span>
#         </li>
#         <li class="description__job-criteria-item">
#           <h3 class="description__job-criteria-subheader">
#             Industries
#           </h3>
#           <span class="description__job-criteria-text description__job-criteria-text--criteria">
#           Pharmaceutical Manufacturing
#           </span>
#         </li>
#     </ul>
#
#       </div>
#     </section>
#
#
#
#
#
#
#
#
#     <section class="core-section-container my-3 find-a-referral">
# <!---->
# <!---->
# <!---->
#       <div class="core-section-container__content break-words">
#
#
#
#     <div class="face-pile flex">
#       <div class="face-pile__images-container self-start flex-shrink-0 mr-1 leading-[1]">
#
#       <img alt="" class="inline-block relative rounded-[50%] w-4 h-4 face-pile__image border-1 border-solid border-color-transparent -ml-2 first:ml-0" data-delayed-url="https://static-exp1.licdn.com/sc/h/bzm35e3651eojcpnxxuyvpjpo" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static-exp1.licdn.com/sc/h/9c8pery4andzj6ohjkjp54ma2"/>
#
#
#       <img alt="" class="inline-block relative rounded-[50%] w-4 h-4 face-pile__image border-1 border-solid border-color-transparent -ml-2 first:ml-0" data-delayed-url="https://static-exp1.licdn.com/sc/h/224mq0thanhnrp5hhso7l1k9p" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static-exp1.licdn.com/sc/h/9c8pery4andzj6ohjkjp54ma2"/>
#
#
#       <img alt="" class="inline-block relative rounded-[50%] w-4 h-4 face-pile__image border-1 border-solid border-color-transparent -ml-2 first:ml-0" data-delayed-url="https://static-exp1.licdn.com/sc/h/31zq62dby0m9b2ti4h5267rjk" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static-exp1.licdn.com/sc/h/9c8pery4andzj6ohjkjp54ma2"/>
#
#       </div>
#
#
#           <div class="find-a-referral__cta-container">
#             <p>Referrals increase your chances of interviewing at Phibro Animal Health by 2x</p>
#             <a class="find-a-referral__cta" data-impression-id="public_jobs_find-a-referral-cta" data-tracking-control-name="public_jobs_find-a-referral-cta" data-tracking-will-navigate="" href="https://www.linkedin.com/login?session_redirect=https%3A%2F%2Fwww%2Elinkedin%2Ecom%2Fsearch%2Fresults%2Fpeople%2F%3FfacetCurrentCompany%3D41089&amp;emailAddress=&amp;fromSignIn=&amp;trk=public_jobs_find-a-referral-cta">
#               See who you know
#             </a>
#           </div>
#
#
#     </div>
#
#
#
#       </div>
#     </section>
#
#
#
# <!---->    </div>
#
#
#
#
#
#     <section class="job-alert-redirect-section">
#       <icon class="job-alert-redirect-section__icon" data-delayed-url="https://static-exp1.licdn.com/sc/h/dd4yq8pu9gycnw9c7p5uro8qn"></icon>
#       <div class="job-alert-redirect-section__container">
#         <p>Get notified about new <strong class="break-word">Data Analyst</strong> jobs in <strong>Teaneck, NJ</strong>.</p>
#
#         <a class="job-alert-redirect-section__cta" data-impression-id="public_jobs_job-alert-guest-redirect-cta" data-tracking-control-name="public_jobs_job-alert-guest-redirect-cta" data-tracking-will-navigate="" href="https://www.linkedin.com/login?session_redirect=https%3A%2F%2Fwww%2Elinkedin%2Ecom%2Fjobs%2Fview%2Fdata-analyst-at-phibro-animal-health-3318210330&amp;fromSignIn=true&amp;trk=public_jobs_job-alert-guest-redirect-cta">
#           Sign in to create job alert
#         </a>
#       </div>
#     </section>
#
#
# <!---->
#     <code id="decoratedJobPostingId" style="display: none"><!--3318210330--></code>
# <!---->    <code id="joinUrlWithRedirect" style="display: none"><!--"https://www.linkedin.com/signup/cold-join?source=jobs_registration&session_redirect=https%3A%2F%2Fwww.linkedin.com%2Fjobs%2Fview%2Fdata-analyst-at-phibro-animal-health-3318210330&trk=public_jobs_save-job"--></code>
#
#
#
#
#
#
#
# <!---->
#
#
#         </div>
#       </section>
#       <section class="right-rail">
#
#
#
#
#
# <!---->
#
#
#
#
# <!---->
#
# ...
#
#
#
#
#
#
#
#     <form class="create-alert-form">
#       <div class="create-alert-form__body">
#         <p class="create-alert-form__header">Get email updates for new <strong class="break-word">Data Analyst</strong> jobs in <strong>Teaneck, NJ</strong></p>
# <!---->
#
#
#     <section class="dismissable-input create-alert-form-input">
#       <input aria-label="Email address*" autocomplete="off" class="dismissable-input__input" data-tracking-control-name="public_jobs_create-alert-modal_create-alert-form_email-address_dismissable-input" maxlength="500" name="emailAddress" placeholder="Email address*" required="" type="email"/>
#
#         <button class="dismissable-input__button" data-tracking-control-name="public_jobs_create-alert-modal_create-alert-form_email-address_dismissable-input-clear" type="button">
#           <label class="sr-only">Dismiss</label>
#           <icon class="dismissable-input__button-icon" data-delayed-url="https://static-exp1.licdn.com/sc/h/cs55jggk4p3uqh9ozxdmpvjg7"></icon>
#         </button>
#     </section>
#
#
#
#
#               <input name="keywords" type="hidden" value="Data Analyst"/>
#               <input name="geo" type="hidden" value="urn:li:geo:102475265"/>
#               <input name="pageType" type="hidden" value="JOB_DETAILS"/>
#
#
#
#
#
#
#
#
#     <code id="i18n_create_alert_invalid_email" style="display: none"><!--"Please enter a valid email address"--></code>
#     <code id="i18n_generic_error_message" style="display: none"><!--"Your job alert couldn’t be created, please try again later."--></code>
#
#     <p class="create-alert-error-message create-alert-error-message--email" role="alert">
#       <icon class="create-alert-error-message__icon lazy-load"></icon>
#       <span class="create-alert-error-message__container">
#         <span class="create-alert-error-message__text"></span>
# <!---->      </span>
#     </p>
#
#
#         <p class="create-alert-form__agreement-links">
#           By creating this job alert, you agree to the LinkedIn <a class="create-alert-form__agreement-item-link" data-tracking-control-name="public_jobs_create-alert-modal_create-alert-form_user-agreement" data-tracking-will-navigate="" href="https://www.linkedin.com/legal/user-agreement?trk=public_jobs_create-alert-modal_create-alert-form_user-agreement" rel="noopener" target="_blank">User Agreement</a> and <a class="create-alert-form__agreement-item-link" data-tracking-control-name="public_jobs_create-alert-modal_create-alert-form_privacy-policy" data-tracking-will-navigate="" href="https://www.linkedin.com/legal/privacy-policy?trk=public_jobs_create-alert-modal_create-alert-form_privacy-policy" rel="noopener" target="_blank">Privacy Policy</a>. You can unsubscribe from these emails at any time.
#         </p>
#
#
#
#
#
#
#     <code id="i18n_create_alert_invalid_email" style="display: none"><!--"Please enter a valid email address"--></code>
#     <code id="i18n_generic_error_message" style="display: none"><!--"Your job alert couldn’t be created, please try again later."--></code>
#
#     <p class="create-alert-error-message create-alert-error-message--generic" role="alert">
#       <icon class="create-alert-error-message__icon lazy-load"></icon>
#       <span class="create-alert-error-message__container">
#         <span class="create-alert-error-message__text"></span>
#           <a class="create-alert-error-message__sign-in-link hidden" data-tracking-control-name="public_jobs_create-alert-modal_create-alert-form_over-limit-sign-in-link" data-tracking-will-navigate="" href="https://www.linkedin.com/login?session_redirect=https%3A%2F%2Fwww%2Elinkedin%2Ecom%2Fjobs%2Fview%2Fdata-analyst-at-phibro-animal-health-3318210330&amp;fromSignIn=true&amp;trk=public_jobs_create-alert-modal_create-alert-form_over-limit-sign-in-link">Sign in to create more</a>
#       </span>
#     </p>
#
#
#       </div>
#
#       <footer class="create-alert-form__footer">
#         <button class="create-alert-form__footer-button" data-tracking-control-name="public_jobs_create-alert-modal_create-alert-form_submit" type="submit">
#           Create job alert
#         </button>
#       </footer>
#     </form>
#
#
#
#
#
#
#
#
#
#
#
#
#     <div class="alert-activation-status alert-activation-status--hidden">
#       <div class="alert-activation-status__body">
#         <icon class="alert-activation-status__icon" data-delayed-url="https://static-exp1.licdn.com/sc/h/arff5hp08cd5tpj3viooy1sup"></icon>
#
#         <p class="alert-activation-status__headline">
#           Your job alert is set
#         </p>
#         <p class="alert-activation-status__subline">
#           Click the link in the email we sent to <span class="break-word" id="guest-email"></span> to verify your email address and activate your job alert.
#         </p>
#       </div>
#
#       <footer class="alert-activation-status__footer">
#         <button class="alert-activation-status__footer-button" data-tracking-control-name="public_jobs_create-alert-modal_alert-activation-status-close">
#           Done
#         </button>
#       </footer>
#     </div>
#
#
#
#
#
#
#
#
#     <div class="welcome-back-sign-in-form welcome-back-sign-in-form--hidden">
#       <h3 class="welcome-back-sign-in-form__header">
#         Welcome back
#       </h3>
#
#         <p class="welcome-back-sign-in-form__subline">
#
#         Sign in to create your job alert for <span class="create-alert-sign-in-form__query-info">Data Analyst</span> jobs in <span class="create-alert-sign-in-form__query-info">Teaneck, NJ</span>.
#
#         </p>
#
#
#
#
#
#
#
#
#
#
#
#
#     <code id="i18n_sign_in_form_show_text" style="display: none"><!--"Show"--></code>
#     <code id="i18n_sign_in_form_show_label" style="display: none"><!--"Show your LinkedIn password"--></code>
#     <code id="i18n_sign_in_form_hide_text" style="display: none"><!--"Hide"--></code>
#     <code id="i18n_sign_in_form_hide_label" style="display: none"><!--"Hide your LinkedIn password"--></code>
#
#
#     <code id="i18n_username_error_empty" style="display: none"><!--"Please enter an email address or phone number"--></code>
#
#     <code id="i18n_username_error_too_long" style="display: none"><!--"Email or phone number must be between 3 to 128 characters"--></code>
#     <code id="i18n_username_error_too_short" style="display: none"><!--"Email or phone number must be between 3 to 128 characters"--></code>
#
#
#     <code id="i18n_password_error_empty" style="display: none"><!--"Please enter a password"--></code>
#
#     <code id="i18n_password_error_too_short" style="display: none"><!--"The password you provided must have at least 6 characters"--></code>
#
#     <code id="i18n_password_error_too_long" style="display: none"><!--"The password you provided must have at most 400 characters"--></code>
#
#     <form action="https://www.linkedin.com/uas/login-submit" class="create-alert-sign-in-form" data-id="sign-in-form" method="post" novalidate="">
#       <input name="loginCsrfParam" type="hidden" value="7cf50c29-28a5-4cc0-81c7-8426a5c9b866"/>
#
#       <div class="flex flex-col">
#
#     <div class="mt-1.5" data-js-module-id="guest-input">
#       <div class="flex flex-col">
#         <label class="input-label mb-1" for="session_key">
#           Email or phone
#         </label>
#         <div class="text-input flex">
#           <input autocomplete="username" class="text-color-text font-sans text-md outline-0 bg-color-transparent grow" id="session_key" name="session_key" required="" type="text"/>
#
#         </div>
#       </div>
#
#       <p class="input-helper mt-1.5" data-js-module-id="guest-input__message" for="session_key" role="alert"></p>
#     </div>
#
#
#
#     <div class="mt-1.5" data-js-module-id="guest-input">
#       <div class="flex flex-col">
#         <label class="input-label mb-1" for="session_password">
#           Password
#         </label>
#         <div class="text-input flex">
#           <input autocomplete="current-password" class="text-color-text font-sans text-md outline-0 bg-color-transparent grow" id="session_password" name="session_password" required="" type="password"/>
#
#             <button aria-label="Show your LinkedIn password" class="font-sans text-md font-bold text-color-action z-10 ml-[12px] hover:cursor-pointer" data-id="sign-in-form__password-visibility-toggle" data-tracking-control-name="public_jobs_create-alert-modal_sign-in-password-visibility-toggle-btn" type="button">Show</button>
#
#         </div>
#       </div>
#
#       <p class="input-helper mt-1.5" data-js-module-id="guest-input__message" for="session_password" role="alert"></p>
#     </div>
#
#
#         <input name="session_redirect" type="hidden" value="https://www.linkedin.com/jobs/view/3318210330/"/>
#
# <!---->      </div>
#
#       <div class="flex justify-between items-center mt-[16px]" data-id="sign-in-form__footer">
#         <a class="font-sans text-md font-bold link leading-regular" data-id="sign-in-form__forgot-password" data-tracking-control-name="public_jobs_create-alert-modal_forgot_password" data-tracking-will-navigate="" href="https://www.linkedin.com/uas/request-password-reset?trk=public_jobs_create-alert-modal_forgot_password">Forgot password?</a>
#
# <!---->
#         <input name="trk" type="hidden" value="public_jobs_create-alert-modal_sign-in-submit"/>
#         <button class="btn-md btn-primary !text-[20px] px-[24px] flex-shrink-0 cursor-pointer ml-[8px]" data-id="sign-in-form__submit-btn" data-tracking-control-name="public_jobs_create-alert-modal_sign-in-submit-btn" data-tracking-litms="" type="submit">
#           Sign in
#         </button>
#       </div>
#     </form>
#
#     </div>
#
#
#
#             </main>
#
# <!---->          </section>
#         </div>
#       </div>
#     </div>
#
#
#
# <!---->
#
#
#
#
#
#
#
#
#
#
#
#
#
#       <div aria-describedby="cta-modal-subheader" aria-labelledby="cta-modal-header" class="cta-modal overflow-hidden container-raised z-10 fixed bottom-3 right-3 min-h-[56px] w-[290px] p-2 opacity-0 invisible babybear:hidden" data-impression-id="public_jobs_cta-modal" role="dialog">
#           <h2 class="cta-modal__header text-xl leading-regular font-bold text-color-text mr-[28px]" id="cta-modal-header">You’re signed out</h2>
#
#           <h3 class="cta-modal__subheader text-md leading-open font-normal text-color-text mt-0.5" id="cta-modal-subheader">Sign in for the full experience.</h3>
#
#
#       <a class="cta-modal__primary-btn btn-md btn-primary inline-block !text-[20px] w-full mt-3 py-1.5 px-0.5 leading-[25px]" data-tracking-control-name="conversion-modal-signin" data-tracking-will-navigate="" href="https://www.linkedin.com/login?session_redirect=https%3A%2F%2Fwww%2Elinkedin%2Ecom%2Fjobs%2Fview%2Fdata-analyst-at-phibro-animal-health-3318210330&amp;fromSignIn=true&amp;trk=public_jobs_conversion-modal-signin">
#         Sign in
#       </a>
#
# <!---->        <a class="cta-modal__secondary-btn btn-md inline-block !text-[20px] w-full mt-1.5 py-1.5 leading-[25px] btn-secondary-emphasis px-0.5" data-tracking-control-name="conversion-modal-join" data-tracking-will-navigate="" href="https://www.linkedin.com/signup/cold-join?source=jobs_registration&amp;trk=public_jobs_conversion-modal-join&amp;session_redirect=https%3A%2F%2Fwww.linkedin.com%2Fjobs%2Fview%2F3318210330%2F">
#           Join now
#         </a>
#
# <!---->
#
#         <button aria-label="Dismiss" class="cta-modal__dismiss-btn absolute top-2 right-2 hover:cursor-pointer focus:outline focus:outline-2 focus:outline-color-action" data-tracking-control-name="public_jobs_dismiss">
#           <icon class="cta-modal__dismiss-icon block h-3 w-3 onload" data-delayed-url="https://static-exp1.licdn.com/sc/h/gs508lg3t2o81tq7pmcgn6m2"></icon>
#         </button>
#       </div>
#
#
#
#
#     <form action="https://www.linkedin.com/uas/login-submit" class="google-one-tap" method="post">
#       <input name="loginCsrfParam" type="hidden" value="7cf50c29-28a5-4cc0-81c7-8426a5c9b866"/>
#
#         <input name="session_redirect" type="hidden" value="https://www.linkedin.com/jobs/view/3318210330/"/>
#
#       <input name="trk" type="hidden" value="public_jobs_google-one-tap-submit"/>
#       <div class="google-one-tap__container" data-tracking-control-name="public_jobs_google-one-tap" id="google-one-tap__container"></div>
#
#
#     <div class="loader loader--full-screen">
#       <div class="loader__container mb-2 overflow-hidden">
#         <icon class="loader__icon inline-block loader__icon--default text-color-progress-loading" data-delayed-url="https://static-exp1.licdn.com/sc/h/ddi43qwelxeqjxdd45pe3fvs1" data-svg-class-name="loader__icon-svg--large fill-currentColor h-[60px] min-h-[60px] w-[60px] min-w-[60px]"></icon>
#       </div>
#     </div>
#
#     </form>
#
#
#
#
#
#     <div class="toasts fixed z-8 babybear:right-4 mamabear:right-4 papabear:min-h-[96px] top:auto bottom-4 left-4 papabear:w-[400px] toasts--bottom" id="toasts" type="bottom">
#
#
#     <template id="toast-template">
#       <div class="toast container-raised flex toast--bottom transition ease-accelerate duration-xxslow" data-id="toast" role="alert">
#         <div class="toast__message flex flex-1 babybear:items-center mamabear:items-center papabear:items-start py-2 px-1.5" data-id="toast__message">
#           <div class="toast__message-content-container" data-id="toast__message-content-container">
#             <p class="toast__message-content font-sans text-sm opacity-90 inline babybear:self-center mamabear:self-center papabear:self-start" data-id="toast__message-content"></p>
#           </div>
#         </div>
#         <button aria-label="Close" class="toast__dismiss-btn cursor-pointer babybear:self-center mamabear:self-center papabear:self-start pt-3 pb-2 papabear:py-2 pl-0.5 pr-0" data-id="toast__dismiss-btn">
#           <svg class="fill-color-icon" height="24" width="24"><path d="M13 4.32 9.31 8 13 11.69 11.69 13 8 9.31 4.31 13 3 11.69 6.69 8 3 4.31 4.31 3 8 6.69 11.68 3Z"></path></svg>
#         </button>
#       </div>
#     </template>
#       <template id="toast-icon-caution">
#         <icon class="text-color-icon-neutral toast__icon w-3 h-3 shrink-0 mr-2" data-delayed-url="https://static-exp1.licdn.com/sc/h/u6kgm8vi5s4rhtbgmjlphlp6"></icon>
#       </template>
#       <template id="toast-icon-error">
#         <icon class="text-color-icon-negative toast__icon w-3 h-3 shrink-0 mr-2" data-delayed-url="https://static-exp1.licdn.com/sc/h/2ffvlzyh9wb65459t9va8w2ph"></icon>
#       </template>
#       <template id="toast-icon-notify">
#         <icon class="text-color-icon-neutral toast__icon w-3 h-3 shrink-0 mr-2" data-delayed-url="https://static-exp1.licdn.com/sc/h/de23f5me7dfm17unsj9up4vga"></icon>
#       </template>
#       <template id="toast-icon-success">
#         <icon class="text-color-icon-positive toast__icon w-3 h-3 shrink-0 mr-2" data-delayed-url="https://static-exp1.licdn.com/sc/h/c44ryoszao52cyd0y87z7s0uf"></icon>
#       </template>
#     <template id="toast-cta">
#       <a class="toast__cta cta-link font-medium ml-0.5 text-sm text-inherit inline" target="_blank"></a>
#     </template>
#   </div>
#
#
#         <section id="json-refs">
#           <code id="requestSubdomain" style="display: none"><!--"www"--></code>
#           <code id="pageKey" style="display: none"><!--"d_jobs_guest_details"--></code>
#           <code id="guestApptivationPromoCooloffInMinutes" style="display: none"><!--"control"--></code>
#             <code id="isGoogleAutoLoginEnabled" style="display: none"><!--true--></code>
#         </section>
#
#
#             <script async="" src="https://static-exp1.licdn.com/sc/h/1f0o8asarfspok2zpu5dl86by"></script>
#
#           <script async="" defer="" src="https://static-exp1.licdn.com/sc/h/dvyr8x62dw3czwmnenn1843g"></script>
#
# <!---->
#           <script data-delayed-url="https://static-exp1.licdn.com/sc/h/98lptr8kagfxge22q7k1fps8" data-module-id="google-one-tap-lib"></script>
#
#
#
#
#   </body></html>

# %%
def parse_listing(URL, parsing_lib=None):
    '''
    Parses job listings posted LinkedIn on LinkedIn using BeautifulSoup and a dictionary with key:method pairs for easy data object creation.
    '''
    parsing_lib = "html5lib" if parsing_lib==None else parsing_lib
    html_text = requests.get(URL).text
    soup = BeautifulSoup(html_text, parsing_lib)

    listing_filters = {
        '''
        This dict contains methods to assign captured values to a key.
        '''
        "Company_URL":lambda x: x.find("a",{"data-tracking-control-name":"public_jobs_topcard-org-name"})['href'].split("?")[0],
        "Position_Tags":lambda x: [result.text.strip() for result in x.find_all("span",class_="description__job-criteria-text description__job-criteria-text--criteria")],
        "Posted_Time":lambda x: x.find("span", class_="posted-time-ago__text topcard__flavor--metadata").text.strip(),
        "Location":lambda x: x.find("span", class_="topcard__flavor topcard__flavor--bullet").text.strip(),
        "Number_Applicants":lambda x: x.find("span", class_="num-applicants__caption topcard__flavor--metadata topcard__flavor--bullet").text.replace(" applicants","").strip(),
        "Post_Body":lambda x: x.find("div", class_="show-more-less-html__markup show-more-less-html__markup--clamp-after-5").text.strip(),
        "Recruiter_Profile": lambda x: x.find("a", class_="message-the-recruiter__cta")
        # "Salary":..., Looks like this isn't available without login
    }

    data = {key : listing_filters[key](soup) for key in listing_filters}
    return data


PostID = 3318210330
PostURL = f'https://www.linkedin.com/jobs/view/{PostID}/'
parse_listing(PostURL, "html5lib")
# Out:
# {'Company_URL': 'https://www.linkedin.com/company/phibro-animal-health',
#  'Position_Tags': ['Mid-Senior level',
#   'Full-time',
#   'Information Technology',
#   'Pharmaceutical Manufacturing'],
#  'Posted_Time': '1 week ago',
#  'Location': 'Teaneck, NJ',
#  'Number_Applicants': '112',
#  'Post_Body': 'Must-haves - 5+ years of experience as a Data Analyst - Basic SQL knowledge, writing scripts - Experience with Excel -On analytical side of data more than reporting  Plusses - Background in financial industry  Day-to-Day PAHC is seeking a Data Analyst to join their team. This person will be working with financial data, investigating discrepancies in the data, reporting issues to the teams, looking at data quality, and assisting with automation efforts currently at hand. This person will be on-site in Teaneck, NJ at least 2 days a week.',
#  'Recruiter_Profile': <a aria-label="Message Emma Zazzali" class="message-the-recruiter__cta" data-tracking-control-name="public_jobs_message-the-recruiter-cta" data-tracking-will-navigate="" href="https://www.linkedin.com/login?session_redirect=https%3A%2F%2Fwww%2Elinkedin%2Ecom%2Fin%2Femmazazzali&amp;emailAddress=&amp;fromSignIn=&amp;trk=public_jobs_message-the-recruiter-cta">
#              <icon class="message-the-recruiter__cta-icon" data-delayed-url="https://static-exp1.licdn.com/sc/h/em62t8ujch4hqqc45owxy6auu" data-tracking-will-navigate=""></icon>
#            </a>}

# %%
import re
raw_text = "F=C4=93nom Digital"
raw_text2 = 'Medix=E2=84=A2'

# converted = "{}".format(raw_text).replace("=", r"\x")
# print(bytes(converted,'utf-8').decode('utf-8', 'strict'))



# b'F\xC4\x93nom Digital'.decode("utf-8", "strict")

def clean_unicode(entry):
    
    match_pattern = re.compile(r'((=[A-F0-9]{2})+)')
    replacement_func = lambda y: y.group(1).replace("=",r"\x") #TODO find out how to replace character with its unicode equivalent
    clean_func = lambda x: re.sub(match_pattern, replacement_func, x)
    result1 = clean_func(entry)
    exec(f"result=b'{result1}'.decode('utf-8')")
    local_result = result
    return local_result



# c4 = (b'\xC4\x93').decode('utf-8', 'strict')

# result = 
# exec(f"result=b'{clean_func(raw_text2)}'.decode('utf-8')")
print(raw_text)
print(clean_unicode(raw_text))
# Out:
# F=C4=93nom Digital
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 29
#      24 # c4 = (b'\xC4\x93').decode('utf-8', 'strict')
#      25
#      26 # result =
#      27 # exec(f"result=b'{clean_func(raw_text2)}'.decode('utf-8')")
#      28 print(raw_text)
# ---> 29 print(clean_unicode(raw_text))
#
# Cell In [1], line 19, in clean_unicode(entry)
#      17 result1 = clean_func(entry)
#      18 exec(f"result=b'{result1}'.decode('utf-8')")
# ---> 19 local_result = result
#      20 return local_result
#
# NameError: name 'result' is not defined

# %%
print(soup.get_text())
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           function getDfd() {let yFn,nFn;const p=new Promise(function(y, n){yFn=y;nFn=n;});p.resolve=yFn;p.reject=nFn;return p;}
#           window.lazyloader = getDfd();
#           window.tracking = getDfd();
#           window.impressionTracking = getDfd();
#           window.ingraphTracking = getDfd();
#           window.appDetection = getDfd();
#           window.pemTracking = getDfd();
#
#
#
#
#         Skylight hiring Data Engineer (remote) in Washington, District of Columbia, United States | LinkedIn
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       {"@context":"http://schema.org","@type":"JobPosting","datePosted":"2022-09-29T19:14:17.000Z","description":"Skylight is at the forefront of a civic movement to reinvent how the government serves the public in a digital world.&lt;br&gt;&lt;br&gt;We’re looking for a Data Engineer to join our talented team of technologists in driving this movement forward.&lt;br&gt;&lt;br&gt;You’ll be a key part of our small, but rapidly growing team, which consists of former Presidential Innovation Fellows, founders of 18F, and members of the U.S. Digital Service.&lt;br&gt;&lt;br&gt;We work in small, fast, agile teams to create exceptional customer experiences and enduring solutions out of the government’s most complex design and technology challenges. The work is challenging, but highly rewarding.&lt;br&gt;&lt;br&gt;&lt;strong&gt;Requirements&lt;br&gt;&lt;br&gt;&lt;/strong&gt;&lt;strong&gt;What you’ll do:&lt;br&gt;&lt;/strong&gt;&lt;ul&gt;&lt;li&gt;Investigate, change, and modernize existing data systems, and build new ones, if necessary&lt;/li&gt;&lt;li&gt;Design and build data pipelines that transform data into usable formats&lt;/li&gt;&lt;li&gt;Write code to ensure the performance and reliability of data extraction and processing&lt;/li&gt;&lt;li&gt;Analyze systems to identify technical debt, instability, unreliability, and other opportunities for improvement, and design, document, and communicate solutions&lt;/li&gt;&lt;li&gt;Achieve technical excellence by advocating for and adhering to lean-agile engineering principles and practices such as API-first design, simple design, continuous integration, version control, and automated testing&lt;/li&gt;&lt;li&gt;Select and use the right tools, frameworks, languages, and technologies for the job, with a preference for open-source solutions&lt;/li&gt;&lt;li&gt;Collaborate with others as part of a cross-functional team that includes user experience researchers and designers, product managers, engineers, and other functional specialists&lt;/li&gt;&lt;li&gt;Represent Skylight's culture of delivery when interacting with government stakeholders and other contractors&lt;br&gt;&lt;br&gt;&lt;/li&gt;&lt;/ul&gt;&lt;strong&gt;What we’re looking for:&lt;br&gt;&lt;/strong&gt;&lt;ul&gt;&lt;li&gt;In-depth knowledge of computer science&lt;/li&gt;&lt;li&gt;Experience as a backend engineer or data engineer&lt;/li&gt;&lt;li&gt;Expertise programming in languages such as Python or Java&lt;/li&gt;&lt;li&gt;Expertise with relational databases such as PostgreSQL&lt;/li&gt;&lt;li&gt;Expertise creating and consuming APIs&lt;/li&gt;&lt;li&gt;Excellent knowledge of relational and non-relational database systems&lt;/li&gt;&lt;li&gt;Proven ability to apply good software engineering principles and practices&lt;/li&gt;&lt;li&gt;Ability to select and use the right tools for the job, particularly open-source solutions&lt;/li&gt;&lt;li&gt;Ability to communicate clearly to technical and non-technical audiences&lt;/li&gt;&lt;li&gt;Experience working within a multidisciplinary, agile team format&lt;/li&gt;&lt;li&gt;A mindset and work approach that aligns with our core values&lt;/li&gt;&lt;li&gt;Ability to travel from time to time (when it's safe)&lt;br&gt;&lt;br&gt;&lt;/li&gt;&lt;/ul&gt;Don’t meet 100% of the criteria but think you can do the job? We’d love to chat anyway! We’re on a mission to build diverse teams, and studies have shown that women and marginalized folks are less likely to apply to jobs if they don’t check every box.&lt;br&gt;&lt;br&gt;&lt;strong&gt;Benefits&lt;br&gt;&lt;br&gt;&lt;/strong&gt;We focus on supporting you in a variety of ways:&lt;br&gt;&lt;ul&gt;&lt;li&gt;Competitive salary&lt;/li&gt;&lt;li&gt;Medical insurance, dental insurance, vision insurance&lt;/li&gt;&lt;li&gt;Short-term and long-term disability insurance&lt;/li&gt;&lt;li&gt;Life and AD&amp;amp;D insurance&lt;/li&gt;&lt;li&gt;Dependent care FSA, healthcare FSA, health savings account&lt;/li&gt;&lt;li&gt;Dollar-for-dollar 401(k) match up to 10%  ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       Skip to main content
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     LinkedIn
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Data Engineer in Fresno, CA
#
#         Expand search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Jobs
#
#
#
#
#               People
#
#
#
#
#               Learning
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Dismiss
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Dismiss
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Dismiss
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Dismiss
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Dismiss
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       Join now
#
#
#
#
#
#
#         Sign in
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             Data Engineer (remote)
#
#                   Skylight
#
#                   Washington, DC
#
#
#
#
#
#
#
#
#         Apply
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Data Engineer (remote)
#
#
#
#
#
#
#
#
#                 Skylight
#
#
#
#               Washington, DC
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     4 weeks ago
#
#
#
#
#
#
#
#
#
#           64 applicants
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             See who Skylight has hired for this role
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Apply
#
#
#
#
#
#
#             Save
#
#
#
#
#
#
#
#
#
#
#
#
#
#                   Save job
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Save this job with your existing LinkedIn profile, or create a new one.
#
#
#
#
#         Your job seeking activity is only visible to you.
#
#
#
#
#
#
#           Email
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             Continue
#
#
#
#
#
#
#
#
#
#         Welcome back
#
#
#
#
#
#         Sign in to save Data Engineer (remote) at Skylight.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Email or phone
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Password
#
#
#
#
#             Show
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Forgot password?
#
#
#
#
#           Sign in
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                     Report this company
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Skylight is at the forefront of a civic movement to reinvent how the government serves the public in a digital world.We’re looking for a Data Engineer to join our talented team of technologists in driving this movement forward.You’ll be a key part of our small, but rapidly growing team, which consists of former Presidential Innovation Fellows, founders of 18F, and members of the U.S. Digital Service.We work in small, fast, agile teams to create exceptional customer experiences and enduring solutions out of the government’s most complex design and technology challenges. The work is challenging, but highly rewarding.RequirementsWhat you’ll do:Investigate, change, and modernize existing data systems, and build new ones, if necessaryDesign and build data pipelines that transform data into usable formatsWrite code to ensure the performance and reliability of data extraction and processingAnalyze systems to identify technical debt, instability, unreliability, and other opportunities for improvement, and design, document, and communicate solutionsAchieve technical excellence by advocating for and adhering to lean-agile engineering principles and practices such as API-first design, simple design, continuous integration, version control, and automated testingSelect and use the right tools, frameworks, languages, and technologies for the job, with a preference for open-source solutionsCollaborate with others as part of a cross-functional team that includes user experience researchers and designers, product managers, engineers, and other functional specialistsRepresent Skylight's culture of delivery when interacting with government stakeholders and other contractorsWhat we’re looking for:In-depth knowledge of computer scienceExperience as a backend engineer or data engineerExpertise programming in languages such as Python or JavaExpertise with relational databases such as PostgreSQLExpertise creating and consuming APIsExcellent knowledge of relational and non-relational database systemsProven ability to apply good software engineering principles and practicesAbility to select and use the right tools for the job, particularly open-source solutionsAbility to communicate clearly to technical and non-technical audiencesExperience working within a multidisciplinary, agile team formatA mindset and work approach that aligns with our core valuesAbility to travel from time to time (when it's safe)Don’t meet 100% of the criteria but think you can do the job? We’d love to chat anyway! We’re on a mission to build diverse teams, and studies have shown that women and marginalized folks are less likely to apply to jobs if they don’t check every box.BenefitsWe focus on supporting you in a variety of ways:Competitive salaryMedical insurance, dental insurance, vision insuranceShort-term and long-term disability insuranceLife and AD&D insuranceDependent care FSA, healthcare FSA, health savings accountDollar-for-dollar 401(k) match up to 10% of your salaryPaid time off, including 15 accrued vacation days, 11 federal holidays, 5 floating holidays, and flexible sick leaveMinimum of 9 weeks paid time off for all eligible new birth, adoption, or foster parentsPerformance rewards, including annual salary increase, annual performance bonus, spot bonuses, and stock optionsBusiness development / sales bonusesReferral bonusesAnnual $2,000 allowance for professional developmentAnnual $750 allowance for tech-related purchasesAnnual swag budget of $100 to display your Skylight pride with some merchandise (hoodies, hats, and more)Dollar-for-dollar charity donation matching, up to $500 per yearAccess up to $1,000 before payday to cover emergency expensesRemote-friendly work environmentAn environment that empowers you to unleash your superpowers for public goodWe participate in E-Verify and upon hire, will provide the federal government with your Form I-9 information to confirm that you are authorized to work in the U.S.We're an Equal Opportunity/Affirmative Actio ...
#
#
#
#
#
#
#
#
#
#         Show more
#
#
#
#
#
#
#
#
#
#
#
#
#         Show less
#
#
#
#
#
#
#
#
#
#
#
#             Seniority level
#
#
#             Mid-Senior level
#
#
#
#
#           Employment type
#
#
#           Full-time
#
#
#
#
#             Job function
#
#
#             Consulting
#
#
#
#
#             Industries
#
#
#           Technology, Information and Internet
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             Referrals increase your chances of interviewing at Skylight by 2x
#
#               See who you know
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             Turn on job alerts
#
#
#               Data Engineer in Washington, DC
#
#
#
#
#
#
#
#
#
#
#       Turn on job alerts
#
#
#
#
#               On
#
#
#               Off
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Looking for a job?
#
#
#           Visit the Career Advice Hub to see tips on interviewing and resume writing.
#
#
#           View Career Advice Hub
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           LinkedIn
#
#           © 2022
#
#
#
#
#
#
#
#           About
#
#
#
#
#
#
#
#
#           Accessibility
#
#
#
#
#
#
#
#
#           User Agreement
#
#
#
#
#
#
#
#
#           Privacy Policy
#
#
#
#
#
#
#
#
#           Cookie Policy
#
#
#
#
#
#
#
#
#           Copyright Policy
#
#
#
#
#
#
#
#
#           Brand Policy
#
#
#
#
#
#
#
#
#             Guest Controls
#
#
#
#
#
#
#
#
#           Community Guidelines
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 العربية (Arabic)
#
#
#
#
#
#                 Čeština (Czech)
#
#
#
#
#
#                 Dansk (Danish)
#
#
#
#
#
#                 Deutsch (German)
#
#
#
#
#
#                 English (English)
#
#
#
#
#
#                 Español (Spanish)
#
#
#
#
#
#                 Français (French)
#
#
#
#
#
#                 हिंदी (Hindi)
#
#
#
#
#
#                 Bahasa Indonesia (Bahasa Indonesia)
#
#
#
#
#
#                 Italiano (Italian)
#
#
#
#
#
#                 日本語 (Japanese)
#
#
#
#
#
#                 한국어 (Korean)
#
#
#
#
#
#                 Bahasa Malaysia (Malay)
#
#
#
#
#
#                 Nederlands (Dutch)
#
#
#
#
#
#                 Norsk (Norwegian)
#
#
#
#
#
#                 Polski (Polish)
#
#
#
#
#
#                 Português (Portuguese)
#
#
#
#
#
#                 Română (Romanian)
#
#
#
#
#
#                 Русский (Russian)
#
#
#
#
#
#                 Svenska (Swedish)
#
#
#
#
#
#                 ภาษาไทย (Thai)
#
#
#
#
#
#                 Tagalog (Tagalog)
#
#
#
#
#
#                 Türkçe (Turkish)
#
#
#
#
#
#                 Українська (Ukrainian)
#
#
#
#
#
#                 简体中文 (Chinese (Simplified))
#
#
#
#
#
#                 正體中文 (Chinese (Traditional))
#
#
#
#
#
#
#
#
#             Language
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                   Create job alert
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Get email updates for new Data Engineer jobs in Washington, DC
#
#
#
#
#
#
#
#           Dismiss
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           By creating this job alert, you agree to the LinkedIn User Agreement and Privacy Policy. You can unsubscribe from these emails at any time.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Sign in to create more
#
#
#
#
#
#
#
#
#           Create job alert
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Your job alert is set
#
#
#           Click the link in the email we sent to  to verify your email address and activate your job alert.
#
#
#
#
#
#           Done
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Welcome back
#
#
#
#
#         Sign in to create your job alert for Data Engineer jobs in Washington, DC.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Email or phone
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Password
#
#
#
#
#             Show
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Forgot password?
#
#
#
#
#           Sign in
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           You’re signed out
#
#           Sign in for the full experience.
#
#
#
#         Sign in
#
#
#
#           Join now

# %%
results = [result.text.strip() for result in soup.find_all("span",class_="description__job-criteria-text description__job-criteria-text--criteria")]
resultlist = []
for result in results:
    # print(result['class'][0])
    print("RESULT", result)
    resultlist.append(result.text.strip())
        # print(result)
# soup.find_all("span", class_="topcard__flavor")
print(resultlist)
# Out:
# RESULT <span class="description__job-criteria-text description__job-criteria-text--criteria">
#             Mid-Senior level
#           </span>
# RESULT <span class="description__job-criteria-text description__job-criteria-text--criteria">
#           Full-time
#         </span>
# RESULT <span class="description__job-criteria-text description__job-criteria-text--criteria">
#             Consulting
#           </span>
# RESULT <span class="description__job-criteria-text description__job-criteria-text--criteria">
#           Technology, Information and Internet
#           </span>
# ['Mid-Senior level', 'Full-time', 'Consulting', 'Technology, Information and Internet']

# %%
print(resultlist)
# Out:
# []

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
#         <meta content="d_jobs_guest_details" name="pageKey"/>
# <!---->        <meta content="en_US" name="locale"/>
#         <meta data-app-version="2.0.1117" data-browser-id="1dff9275-0459-46f3-8377-5524b63efd3f" data-call-tree-id="AAXsI05iI70yHzrEGzXjGA==" data-disable-jsbeacon-pagekey-suffix="false" data-enable-page-view-heartbeat-tracking="" data-member-id="0" data-multiproduct-name="jobs-guest-frontend" data-page-instance="urn:li:page:d_jobs_guest_details;r5BcxxvQQ42kvOrYcU9dqg==" data-service-name="jobs-guest-frontend" id="config"/>
#         <link href="https://www.linkedin.com/jobs/view/data-engineer-remote-at-skylight-3317379575" rel="canonical"/>
# <!----><!---->
# <!---->
#           <meta content="https://www.linkedin.com/jobs/view/data-engineer-remote-at-skylight-3317379575" property="al:android:url"/>
#           <meta content="com.linkedin.android" property="al:android:package"/>
#           <meta content="LinkedIn" property="al:android:app_name"/>
#           <meta content="https://www.linkedin.com/jobs/view/data-engineer-remote-at-skylight-3317379575" property="al:ios:url"/>
#           <meta content="288429040" property="al:ios:app_store_id"/>
#           <meta content="LinkedIn" property="al:ios:app_name"/>
#
# <!---->
#           <link href="https://static.licdn.com/sc/h/al2o9zrvru7aqj8e1x2rzsrca" rel="icon"/>
#
#         <script>
#           function getDfd() {let yFn,nFn;const p=new Promise(function(y, n){yFn=y;nFn=n;});p.resolve=yFn;p.reject=nFn;return p;}
#           window.lazyloader = getDfd();
#           window.tracking = getDfd();
#           window.impressionTracking = getDfd();
#           window.ingraphTracking = getDfd();
#           window.appDetection = getDfd();
#           window.pemTracking = getDfd();
#         </script>
#
# <!---->
#
#         <title>Skylight hiring Data Engineer (remote) in Washington, District of Columbia, United States | LinkedIn</title>
#         <meta content="Posted 7:14:17 PM. Skylight is at the forefront of a civic movement to reinvent how the government serves the public…See this and similar jobs on LinkedIn." name="description"/>
#         <meta content="noarchive" name="robots"/>
#         <meta content="#293e49" name="theme-color"/>
#         <meta content="width=device-width, initial-scale=1" name="viewport"/>
#         <meta content="jobs-guest-frontend" name="litmsProfileName"/>
#         <meta content="1" data-counter-metric-endpoint="/jobs-guest/api/ingraphs/counter" data-gauge-metric-endpoint="/jobs-guest/api/ingraphs/gauge" name="clientSideIngraphs"/>
#         <meta charset="utf-8"/>
#
#         <meta content="website" property="og:type"/>
#         <meta content="Skylight hiring Data Engineer (remote) in Washington, District of Columbia, United States | LinkedIn" property="og:title"/>
#         <meta content="https://www.linkedin.com/jobs/view/data-engineer-remote-at-skylight-3317379575" property="og:url"/>
#         <meta content="Posted 7:14:17 PM. Skylight is at the forefront of a civic movement to reinvent how the government serves the public…See this and similar jobs on LinkedIn." property="og:description"/>
#         <meta content="https://static.licdn.com/sc/h/9a9u41thxt325ucfh5z8ga4m8" property="og:image"/>
#
#         <meta content="Skylight hiring Data Engineer (remote) in Washington, District of Columbia, United States | LinkedIn" name="twitter:title"/>
#         <meta content="summary_large_image" name="twitter:card"/>
#         <meta content="@LinkedIn" name="twitter:site"/>
#         <meta content="Posted 7:14:17 PM. Skylight is at the forefront of a civic movement to reinvent how the government serves the public…See this and similar jobs on LinkedIn." name="twitter:description"/>
#         <meta content="https://static.licdn.com/sc/h/9a9u41thxt325ucfh5z8ga4m8" name="twitter:image"/>
#           <meta content="2732" name="titleId"/>
#           <meta content="16256294" name="companyId"/>
#           <meta content="6" name="industryIds"/>
#           <meta content="https://www.linkedin.com/jobs/view/3317379575/" property="lnkd:url"/>
#
#
#     <script type="application/ld+json">
#       {"@context":"http://schema.org","@type":"JobPosting","datePosted":"2022-09-29T19:14:17.000Z","description":"Skylight is at the forefront of a civic movement to reinvent how the government serves the public in a digital world.&lt;br&gt;&lt;br&gt;We’re looking for a Data Engineer to join our talented team of technologists in driving this movement forward.&lt;br&gt;&lt;br&gt;You’ll be a key part of our small, but rapidly growing team, which consists of former Presidential Innovation Fellows, founders of 18F, and members of the U.S. Digital Service.&lt;br&gt;&lt;br&gt;We work in small, fast, agile teams to create exceptional customer experiences and enduring solutions out of the government’s most complex design and technology challenges. The work is challenging, but highly rewarding.&lt;br&gt;&lt;br&gt;&lt;strong&gt;Requirements&lt;br&gt;&lt;br&gt;&lt;/strong&gt;&lt;strong&gt;What you’ll do:&lt;br&gt;&lt;/strong&gt;&lt;ul&gt;&lt;li&gt;Investigate, change, and modernize existing data systems, and build new ones, if necessary&lt;/li&gt;&lt;li&gt;Design and build data pipelines that transform data into usable formats&lt;/li&gt;&lt;li&gt;Write code to ensure the performance and reliability of data extraction and processing&lt;/li&gt;&lt;li&gt;Analyze systems to identify technical debt, instability, unreliability, and other opportunities for improvement, and design, document, and communicate solutions&lt;/li&gt;&lt;li&gt;Achieve technical excellence by advocating for and adhering to lean-agile engineering principles and practices such as API-first design, simple design, continuous integration, version control, and automated testing&lt;/li&gt;&lt;li&gt;Select and use the right tools, frameworks, languages, and technologies for the job, with a preference for open-source solutions&lt;/li&gt;&lt;li&gt;Collaborate with others as part of a cross-functional team that includes user experience researchers and designers, product managers, engineers, and other functional specialists&lt;/li&gt;&lt;li&gt;Represent Skylight's culture of delivery when interacting with government stakeholders and other contractors&lt;br&gt;&lt;br&gt;&lt;/li&gt;&lt;/ul&gt;&lt;strong&gt;What we’re looking for:&lt;br&gt;&lt;/strong&gt;&lt;ul&gt;&lt;li&gt;In-depth knowledge of computer science&lt;/li&gt;&lt;li&gt;Experience as a backend engineer or data engineer&lt;/li&gt;&lt;li&gt;Expertise programming in languages such as Python or Java&lt;/li&gt;&lt;li&gt;Expertise with relational databases such as PostgreSQL&lt;/li&gt;&lt;li&gt;Expertise creating and consuming APIs&lt;/li&gt;&lt;li&gt;Excellent knowledge of relational and non-relational database systems&lt;/li&gt;&lt;li&gt;Proven ability to apply good software engineering principles and practices&lt;/li&gt;&lt;li&gt;Ability to select and use the right tools for the job, particularly open-source solutions&lt;/li&gt;&lt;li&gt;Ability to communicate clearly to technical and non-technical audiences&lt;/li&gt;&lt;li&gt;Experience working within a multidisciplinary, agile team format&lt;/li&gt;&lt;li&gt;A mindset and work approach that aligns with our core values&lt;/li&gt;&lt;li&gt;Ability to travel from time to time (when it's safe)&lt;br&gt;&lt;br&gt;&lt;/li&gt;&lt;/ul&gt;Don’t meet 100% of the criteria but think you can do the job? We’d love to chat anyway! We’re on a mission to build diverse teams, and studies have shown that women and marginalized folks are less likely to apply to jobs if they don’t check every box.&lt;br&gt;&lt;br&gt;&lt;strong&gt;Benefits&lt;br&gt;&lt;br&gt;&lt;/strong&gt;We focus on supporting you in a variety of ways:&lt;br&gt;&lt;ul&gt;&lt;li&gt;Competitive salary&lt;/li&gt;&lt;li&gt;Medical insurance, dental insurance, vision insurance&lt;/li&gt;&lt;li&gt;Short-term and long-term disability insurance&lt;/li&gt;&lt;li&gt;Life and AD&amp;amp;D insurance&lt;/li&gt;&lt;li&gt;Dependent care FSA, healthcare FSA, health savings account&lt;/li&gt;&lt;li&gt;Dollar-for-dollar 401(k) match up to 10%  ...
#     </script>
#
#
#         <link href="https://static.licdn.com/sc/h/5j6b39yz2qe3vt5rbex0fcc2" rel="stylesheet"/>
#
# <!---->      </head>
#       <body dir="ltr">
# <!----><!---->
#
#
#
#
#
#
#     <a class="skip-link btn-md btn-primary absolute z-11 -top-[100vh] focus:top-0" href="#main-content">
#       Skip to main content
#     </a>
#
#     <header class="header global-alert-offset sticky-header">
#
#
#
#
#
#
#
#     <nav aria-label="Primary" class="nav pt-1.5 pb-2 flex items-center justify-between relative flex-nowrap babybear:flex-wrap babybear:py-1.5 nav--minified-mobile babybear:flex-wrap">
#
# <!---->
#       <a class="nav__logo-link link-no-visited-state z-1 mr-auto babybear:z-0 babybear:mr-0 babybear:flex-1 hover:no-underline focus:no-underline active:no-underline" data-tracking-control-name="public_jobs_nav-header-logo" data-tracking-will-navigate="" href="/?trk=public_jobs_nav-header-logo">
#
#
#
#     <span class="sr-only">LinkedIn</span>
#       <icon class="text-color-brand papabear:hidden mamabear:hidden babybear:block babybear:h-[27px]" data-delayed-url="https://static.licdn.com/sc/h/4zqr0f9jf98vi2nkijyc3bex2" data-test-id="nav-logo--mobile-inbug"></icon>
#     <icon class="block text-color-brand w-[84px] h-[21px] papabear:w-[135px] papabear:h-[34px] babybear:hidden" data-delayed-url="https://static.licdn.com/sc/h/8fkga714vy9b2wk5auqo5reeb" data-test-id="nav-logo"></icon>
#
#
#       </a>
#
#
#
#
#
#
#
#
#     <section class="search-bar search-bar--minified-mobile" data-current-search-type="JOBS">
#       <button class="search-bar__placeholder show-on-mobile hide-on-desktop" data-tracking-control-name="public_jobs_search-switcher-opener">
#         <div class="search-bar__full-placeholder">
# <!---->              Data Engineer in Fresno, CA
# <!---->        </div>
#         <span class="sr-only">Expand search</span>
#       </button>
#
#
#
#
#
#
#
#
#
#     <div class="switcher-tabs__trigger-and-tabs">
#       <button aria-expanded="false" class="switcher-tabs__placeholder hide-on-mobile" data-tracking-control-name="public_jobs_switcher-tabs-placeholder">
#         <span class="switcher-tabs__placeholder-text"></span>
#         <icon class="switcher-tabs__caret-down-filled onload" data-delayed-url="https://static.licdn.com/sc/h/7asbl4deqijhoy3z2ivveispv"></icon>
#       </button>
#
#       <div class="switcher-tabs hide-on-desktop hide-on-mobile">
#         <ul class="switcher-tabs__list" role="tablist">
#           <li aria-selected="true" class="switcher-tabs__tab switcher-tabs__tab--active" role="tab">
#             <button class="switcher-tabs__button" data-switcher-type="JOBS" data-tracking-control-name="public_jobs_switcher-tabs-jobs-search-switcher" type="button">
#               Jobs
#             </button>
#           </li>
#           <li aria-selected="false" class="switcher-tabs__tab" role="tab">
#             <button class="switcher-tabs__button" data-switcher-type="PEOPLE" data-tracking-control-name="public_jobs_switcher-tabs-people-search-switcher" type="button">
#               People
#             </button>
#           </li>
#           <li aria-selected="false" class="switcher-tabs__tab" role="tab">
#             <button class="switcher-tabs__button" data-switcher-type="LEARNING" data-tracking-control-name="public_jobs_switcher-tabs-learning-search-switcher" type="button">
#               Learning
#             </button>
#           </li>
#         </ul>
#
#         <button aria-label="Close" class="switcher-tabs__cancel-btn hide-on-desktop" data-tracking-control-name="public_jobs_switcher-tabs-cancel-search-switcher" type="button">
#           <icon class="switcher-tabs__cancel-icon onload" data-delayed-url="https://static.licdn.com/sc/h/cs55jggk4p3uqh9ozxdmpvjg7"></icon>
#         </button>
#       </div>
#     </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <section class="base-search-bar w-full h-full" data-searchbar-type="PEOPLE">
#       <form action="/pub/dir" class="base-search-bar__form w-full h-fit flex babybear:mx-mobile-container-padding babybear:flex-col" data-tracking-control-name="public_jobs_people-search-bar_base-search-bar-form" role="search">
#
#
#
#
#
#     <section class="dismissable-input search-input">
#       <input aria-label="First Name" autocomplete="on" class="dismissable-input__input" data-tracking-control-name="public_jobs_people-search-bar_first-name_dismissable-input" maxlength="500" name="firstName" placeholder="First Name" type="search"/>
#
#         <button class="dismissable-input__button" data-tracking-control-name="public_jobs_people-search-bar_first-name_dismissable-input-clear" type="button">
#           <label class="sr-only">Dismiss</label>
#           <icon class="dismissable-input__button-icon" data-delayed-url="https://static.licdn.com/sc/h/cs55jggk4p3uqh9ozxdmpvjg7"></icon>
#         </button>
#     </section>
#
#
#
#
#
#
#     <section class="dismissable-input search-input">
#       <input aria-label="Last Name" autocomplete="on" class="dismissable-input__input" data-tracking-control-name="public_jobs_people-search-bar_last-name_dismissable-input" maxlength="500" name="lastName" placeholder="Last Name" type="search"/>
#
#         <button class="dismissable-input__button" data-tracking-control-name="public_jobs_people-search-bar_last-name_dismissable-input-clear" type="button">
#           <label class="sr-only">Dismiss</label>
#           <icon class="dismissable-input__button-icon" data-delayed-url="https://static.licdn.com/sc/h/cs55jggk4p3uqh9ozxdmpvjg7"></icon>
#         </button>
#     </section>
#
#
#
#         <input name="trk" type="hidden" value="public_jobs_people-search-bar_search-submit"/>
#         <button aria-label="Search" class="base-search-bar__submit-btn block basis-[40px] flex-shrink-0 cursor-pointer babybear:invisible babybear:ml-[-9999px] babybear:w-[1px] babybear:h-[1px]" data-tracking-control-name="public_jobs_people-search-bar_base-search-bar-search-submit" type="submit">
#           <icon class="base-search-bar__search-icon onload mx-auto" data-delayed-url="https://static.licdn.com/sc/h/cb5bsr4tsn2r4sjg9e3ls4tjl"></icon>
#         </button>
#       </form>
#     </section>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <section class="base-search-bar w-full h-full" data-searchbar-type="JOBS">
#       <form action="/jobs/search" class="base-search-bar__form w-full h-fit flex babybear:mx-mobile-container-padding babybear:flex-col" data-tracking-control-name="public_jobs_jobs-search-bar_base-search-bar-form" role="search">
#
#
#
#
#
#
#
#     <code id="i18n_aria_live_text_no-suggestions" style="display: none"><!--"No suggestions found"--></code>
#     <code id="i18n_aria_live_text_one-suggestion" style="display: none"><!--"One Suggestion. Use up and down keys to navigate"--></code>
#     <code id="i18n_aria_live_text_multiple-suggestions" style="display: none"><!--"Multiple Suggestions. Use up and down keys to navigate"--></code>
#
#
#
#
#     <section class="dismissable-input typeahead-input keywords-typeahead-input text-input">
#       <input aria-autocomplete="list" aria-controls="job-search-bar-keywords-typeahead-list" aria-haspopup="listbox" aria-label="Search job titles or companies" autocomplete="off" class="dismissable-input__input" data-tracking-control-name="public_jobs_dismissable-input" maxlength="500" name="keywords" placeholder="Search job titles or companies" role="combobox" type="search" value="Data Engineer"/>
#
# <!---->      <div class="typeahead-input__dropdown">
#         <template class="typeahead-item-template">
#           <li class="typeahead-input__dropdown-item" role="option">
#             <span class="typeahead-input__dropdown-text"></span>
#           </li>
#         </template>
#
#         <ul class="typeahead-input__dropdown-list" id="job-search-bar-keywords-typeahead-list" role="listbox"></ul>
#       </div>
# <!---->
#         <button class="dismissable-input__button" data-tracking-control-name="public_jobs_dismissable-input-clear" type="button">
#           <label class="sr-only">Dismiss</label>
#           <icon class="dismissable-input__button-icon" data-delayed-url="https://static.licdn.com/sc/h/cs55jggk4p3uqh9ozxdmpvjg7"></icon>
#         </button>
#     </section>
#
#
# <!---->
#
#
#
#
#
#     <code id="i18n_aria_live_text_no-suggestions" style="display: none"><!--"No suggestions found"--></code>
#     <code id="i18n_aria_live_text_one-suggestion" style="display: none"><!--"One Suggestion. Use up and down keys to navigate"--></code>
#     <code id="i18n_aria_live_text_multiple-suggestions" style="display: none"><!--"Multiple Suggestions. Use up and down keys to navigate"--></code>
#
#
#
#
#     <section class="dismissable-input typeahead-input location-typeahead-input">
#       <input aria-autocomplete="list" aria-controls="job-search-bar-location-typeahead-list" aria-haspopup="listbox" aria-label="Location" autocomplete="off" class="dismissable-input__input" data-tracking-control-name="public_jobs_dismissable-input" maxlength="500" name="location" placeholder="Location" role="combobox" type="search" value="Fresno, CA"/>
#
# <!---->      <div class="typeahead-input__dropdown">
#         <template class="typeahead-item-template">
#           <li class="typeahead-input__dropdown-item" role="option">
#             <span class="typeahead-input__dropdown-text"></span>
#           </li>
#         </template>
#
#         <ul class="typeahead-input__dropdown-list" id="job-search-bar-location-typeahead-list" role="listbox"></ul>
#       </div>
# <!---->
#         <button class="dismissable-input__button" data-tracking-control-name="public_jobs_dismissable-input-clear" type="button">
#           <label class="sr-only">Dismiss</label>
#           <icon class="dismissable-input__button-icon" data-delayed-url="https://static.licdn.com/sc/h/cs55jggk4p3uqh9ozxdmpvjg7"></icon>
#         </button>
#     </section>
#
#
#         <input name="geoId" type="hidden" value="100969510"/>
#
#         <input name="trk" type="hidden" value="public_jobs_jobs-search-bar_search-submit"/>
#         <button aria-label="Search" class="base-search-bar__submit-btn block basis-[40px] flex-shrink-0 cursor-pointer babybear:invisible babybear:ml-[-9999px] babybear:w-[1px] babybear:h-[1px]" data-tracking-control-name="public_jobs_jobs-search-bar_base-search-bar-search-submit" type="submit">
#           <icon class="base-search-bar__search-icon onload mx-auto" data-delayed-url="https://static.licdn.com/sc/h/cb5bsr4tsn2r4sjg9e3ls4tjl"></icon>
#         </button>
#       </form>
#     </section>
#
#
#
#
#
#
#
#
#
#
#
#     <section class="base-search-bar w-full h-full" data-searchbar-type="LEARNING">
#       <form action="/learning/search" class="base-search-bar__form w-full h-fit flex babybear:mx-mobile-container-padding babybear:flex-col" data-tracking-control-name="public_jobs_learning-search-bar_base-search-bar-form" role="search">
#
#
#
#
#
#     <section class="dismissable-input search-input">
#       <input aria-label="Search skills, subjects, or software" autocomplete="on" class="dismissable-input__input" data-tracking-control-name="public_jobs_learning-search-bar_keywords_dismissable-input" maxlength="500" name="keywords" placeholder="Search skills, subjects, or software" type="search" value="Data Engineer"/>
#
#         <button class="dismissable-input__button" data-tracking-control-name="public_jobs_learning-search-bar_keywords_dismissable-input-clear" type="button">
#           <label class="sr-only">Dismiss</label>
#           <icon class="dismissable-input__button-icon" data-delayed-url="https://static.licdn.com/sc/h/cs55jggk4p3uqh9ozxdmpvjg7"></icon>
#         </button>
#     </section>
#
#
#         <input class="nav__search-uoo" name="upsellOrderOrigin" type="hidden"/>
#
#
#         <input name="trk" type="hidden" value="public_jobs_learning-search-bar_search-submit"/>
#         <button aria-label="Search" class="base-search-bar__submit-btn block basis-[40px] flex-shrink-0 cursor-pointer babybear:invisible babybear:ml-[-9999px] babybear:w-[1px] babybear:h-[1px]" data-tracking-control-name="public_jobs_learning-search-bar_base-search-bar-search-submit" type="submit">
#           <icon class="base-search-bar__search-icon onload mx-auto" data-delayed-url="https://static.licdn.com/sc/h/cb5bsr4tsn2r4sjg9e3ls4tjl"></icon>
#         </button>
#       </form>
#     </section>
#
#
#         <div aria-live="polite" class="search-bar__live-text sr-only" role="status"></div>
#
#
#     </section>
#
#
# <!---->
#       <div class="nav__cta-container order-3 flex gap-x-1 justify-end min-w-[100px] flex-nowrap flex-shrink-0 babybear:flex-wrap flex-2">
#
#
#     <a class="nav__button-tertiary btn-md btn-tertiary" data-test-live-nav-primary-cta="" data-tracking-control-name="public_jobs_nav-header-join" data-tracking-will-navigate="" href="https://www.linkedin.com/signup/cold-join?source=jobs_registration&amp;session_redirect=https%3A%2F%2Fwww.linkedin.com%2Fjobs%2Fview%2F3317379575%2F&amp;trk=public_jobs_nav-header-join">
#       Join now
#     </a>
#
#
#
#
#       <a class="nav__button-secondary btn-md btn-secondary-emphasis" data-tracking-control-name="public_jobs_nav-header-signin" data-tracking-will-navigate="" href="https://www.linkedin.com/login?session_redirect=https%3A%2F%2Fwww%2Elinkedin%2Ecom%2Fjobs%2Fview%2Fdata-engineer-remote-at-skylight-3317379575&amp;fromSignIn=true&amp;trk=public_jobs_nav-header-signin">
#         Sign in
#       </a>
#
#
#           <a aria-label="Sign in" class="nav__link-person papabear:hidden mamabear:hidden" data-tracking-control-name="public_jobs_nav-header-signin" data-tracking-will-navigate="" href="https://www.linkedin.com/login?session_redirect=https%3A%2F%2Fwww%2Elinkedin%2Ecom%2Fjobs%2Fview%2Fdata-engineer-remote-at-skylight-3317379575&amp;fromSignIn=true&amp;trk=public_jobs_nav-header-signin">
#
#       <img alt="" class="inline-block relative rounded-[50%] w-4 h-4 bg-color-entity-ghost-background" data-delayed-url="https://static.licdn.com/sc/h/9c8pery4andzj6ohjkjp54ma2" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static.licdn.com/sc/h/9c8pery4andzj6ohjkjp54ma2"/>
#
#           </a>
#       </div>
#
# <!---->
# <!---->    </nav>
#
#
#     </header>
#
#
# <!---->
#
# <!---->
#     <main class="main" id="main-content" role="main">
#       <section class="core-rail">
#
#
#
#
#         <div class="details">
#
#
#
#
#
#       <section class="sub-nav-cta global-alert-offset" data-impression-id="public_jobs_sub-nav-cta">
#         <div class="sub-nav-cta__content">
#
#
#
#       <img alt="Skylight" class="artdeco-entity-image artdeco-entity-image--square-3 sub-nav-cta__image" data-delayed-url="https://media-exp1.licdn.com/dms/image/C560BAQHkUFBxRQDFjA/company-logo_100_100/0/1628253019234?e=2147483647&amp;v=beta&amp;t=2xaDlh-8RiXLXud5cPK50OoBl7CID298eYSkuU4tZZM" data-ghost-classes="artdeco-entity-image--ghost" data-ghost-url="https://static.licdn.com/sc/h/9a9u41thxt325ucfh5z8ga4m8"/>
#
#           <div class="sub-nav-cta__text-container">
#             <h3 class="sub-nav-cta__header">Data Engineer (remote)</h3>
#               <div class="sub-nav-cta__sub-text-container">
#                   <a class="sub-nav-cta__optional-url" data-tracking-control-name="public_jobs_sub-nav-cta-optional-url" data-tracking-will-navigate="" href="https://www.linkedin.com/company/skylight-hq?trk=public_jobs_sub-nav-cta-optional-url" title="Skylight">Skylight</a>
#
#                   <span class="sub-nav-cta__meta-text">Washington, DC</span>
#               </div>
#           </div>
#
#
#
#
#
#       <button class="apply-button apply-button--default btn-md btn-primary" data-reference-id="UCelrwEBS9ihgxhLQWsmww==" data-tracking-control-name="public_jobs_apply-link-onsite" id="topbar-apply">
#         Apply
#       </button>
#
#
#         </div>
#       </section>
#
#
#
#
#
#
#
#     <section class="top-card-layout container-lined overflow-hidden babybear:rounded-[0px]">
#
#
#
#       <div class="top-card-layout__card relative p-2 papabear:p-details-container-padding">
#
#
#       <a data-tracking-control-name="public_jobs_topcard_logo" data-tracking-will-navigate="" href="https://www.linkedin.com/company/skylight-hq?trk=public_jobs_topcard_logo" target="_self">
#
#
#       <img alt="Skylight" class="artdeco-entity-image artdeco-entity-image--square-5" data-delayed-url="https://media-exp1.licdn.com/dms/image/C560BAQHkUFBxRQDFjA/company-logo_100_100/0/1628253019234?e=2147483647&amp;v=beta&amp;t=2xaDlh-8RiXLXud5cPK50OoBl7CID298eYSkuU4tZZM" data-ghost-classes="artdeco-entity-image--ghost" data-ghost-url="https://static.licdn.com/sc/h/9a9u41thxt325ucfh5z8ga4m8"/>
#
#
#       </a>
#
#
#
#           <div class="top-card-layout__entity-info-container flex flex-wrap papabear:flex-nowrap">
#             <div class="top-card-layout__entity-info flex-grow flex-shrink-0 basis-0 babybear:flex-none babybear:w-full babybear:flex-none babybear:w-full">
#
#           <h1 class="top-card-layout__title font-sans text-lg papabear:text-xl font-bold leading-open text-color-text mb-0 topcard__title">Data Engineer (remote)</h1>
#
# <!---->
# <!---->
#                 <h4 class="top-card-layout__second-subline font-sans text-sm leading-open text-color-text-low-emphasis mt-0.5">
#
#         <div class="topcard__flavor-row">
#           <span class="topcard__flavor">
#               <a class="topcard__org-name-link topcard__flavor--black-link" data-tracking-control-name="public_jobs_topcard-org-name" data-tracking-will-navigate="" href="https://www.linkedin.com/company/skylight-hq?trk=public_jobs_topcard-org-name" rel="noopener" target="_blank">
#                 Skylight
#               </a>
#           </span>
#             <span class="topcard__flavor topcard__flavor--bullet">
#               Washington, DC
#             </span>
#         </div>
#         <div class="topcard__flavor-row">
#
#       <span class="posted-time-ago__text topcard__flavor--metadata">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     4 weeks ago
#
#       </span>
#
#
#
#
#
#
#         <span class="num-applicants__caption topcard__flavor--metadata topcard__flavor--bullet">
#           64 applicants
#         </span>
#
#         </div>
#
#
#
#
#
#     <div class="face-pile flex see-who-was-hired">
#       <div class="face-pile__images-container self-start flex-shrink-0 mr-1 leading-[1]">
#
#       <img alt="" class="inline-block relative rounded-[50%] w-4 h-4 face-pile__image border-1 border-solid border-color-transparent -ml-2 first:ml-0" data-delayed-url="https://static.licdn.com/sc/h/1r5y4gyavxb048v7fvnl06mjs" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static.licdn.com/sc/h/9c8pery4andzj6ohjkjp54ma2"/>
#
#
#       <img alt="" class="inline-block relative rounded-[50%] w-4 h-4 face-pile__image border-1 border-solid border-color-transparent -ml-2 first:ml-0" data-delayed-url="https://static.licdn.com/sc/h/bzm35e3651eojcpnxxuyvpjpo" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static.licdn.com/sc/h/9c8pery4andzj6ohjkjp54ma2"/>
#
#
#       <img alt="" class="inline-block relative rounded-[50%] w-4 h-4 face-pile__image border-1 border-solid border-color-transparent -ml-2 first:ml-0" data-delayed-url="https://static.licdn.com/sc/h/224mq0thanhnrp5hhso7l1k9p" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static.licdn.com/sc/h/9c8pery4andzj6ohjkjp54ma2"/>
#
#       </div>
#           <a class="face-pile__cta self-center link-no-visited-state" data-tracking-control-name="public_jobs_see-who-was-hired_people-search-link_face-pile-cta" data-tracking-will-navigate="" href="https://www.linkedin.com/login?session_redirect=https%3A%2F%2Fwww%2Elinkedin%2Ecom%2Fsearch%2Fresults%2Fpeople%2F%3FfacetCurrentCompany%3D16256294%26title%3DData%2BEngineer&amp;emailAddress=&amp;fromSignIn=&amp;trk=public_jobs_see-who-was-hired_people-search-link_face-pile-cta">
#             See who Skylight has hired for this role
#           </a>
#     </div>
#
#
#
# <!---->
#                 </h4>
#
#               <div class="top-card-layout__cta-container flex flex-wrap mt-0.5 papabear:mt-0 ml-[-12px]">
#
#
#
#
#
#       <button class="apply-button apply-button--default top-card-layout__cta mt-2 ml-1.5 h-auto babybear:flex-auto top-card-layout__cta--primary btn-md btn-primary" data-reference-id="UCelrwEBS9ihgxhLQWsmww==" data-tracking-control-name="public_jobs_apply-link-onsite">
#         Apply
#       </button>
#
#
#
#
#           <button class="top-card-layout__cta mt-2 ml-1.5 h-auto babybear:flex-auto top-card-layout__cta--secondary btn-md btn-secondary save-job-modal-outlet" data-impression-id="public_jobs_topcard-save-job" data-modal="save-job-modal-outlet" data-tracking-control-name="public_jobs_topcard-save-job">
#             Save
#           </button>
#
#
#
#
#
#
#     <div class="">
# <!---->
#       <div class="modal save-job-modal" data-outlet="save-job-modal-outlet" id="save-job-modal">
#         <div class="modal__overlay flex items-center bg-color-background-scrim justify-center fixed bottom-0 left-0 right-0 top-0 opacity-0 invisible pointer-events-none z-[1000] transition-[opacity] ease-[cubic-bezier(0.25,0.1,0.25,1.0)] duration-[0.17s] py-4">
#           <section aria-labelledby="save-job-modal-modal-header" aria-modal="true" class="max-h-full modal__wrapper overflow-auto p-0 bg-color-background-container max-w-[1128px] min-h-[160px] relative scale-[0.25] shadow-sm shadow-color-border-faint transition-[transform] ease-[cubic-bezier(0.25,0.1,0.25,1.0)] duration-[0.33s] focus:outline-0 w-[1128px] mamabear:w-[744px] babybear:w-[360px] rounded-md" role="dialog" tabindex="-1">
#               <header class="modal__header flex items-center justify-between border-b-1 border-solid border-color-border-faint py-1.5 px-3">
#                   <h2 class="modal__title font-normal leading-open text-color-text text-lg" id="save-job-modal-modal-header">Save job</h2>
#                 <button aria-label="Dismiss" class="modal__dismiss modal__dismiss--with-icon btn-tertiary h-[40px] w-[40px] p-0 rounded-full indent-0" data-tracking-control-name="public_jobs_save-job-modal_modal_dismiss" type="button">
#                     <icon class="modal__dismiss-icon relative top-[2px]" data-delayed-url="https://static.licdn.com/sc/h/gs508lg3t2o81tq7pmcgn6m2"></icon>
#                 </button>
# <!---->              </header>
#             <main class="modal__main w-full">
#
#
#     <div class="loader loader--absolute">
#       <div class="loader__container mb-2 overflow-hidden">
#         <icon class="loader__icon inline-block loader__icon--muted text-color-icon-active" data-delayed-url="https://static.licdn.com/sc/h/ddi43qwelxeqjxdd45pe3fvs1" data-svg-class-name="loader__icon-svg--small fill-currentColor h-[30px] min-h-[30px] w-[30px] min-w-[30px]"></icon>
#       </div>
#     </div>
#
#
#
#
#
#
#
#
#
#     <code id="i18n_save_job_form_email_check_error" style="display: none"><!--"We’re sorry, something went wrong on our end. Please try again."--></code>
#
#
#
#
#
#     <div class="email-input-page save-job-form-page">
#
#       <form class="email-input-page__content-new-user">
#         <div class="email-input-page__content">
#           <h3 class="email-input-page__header">
#
#         <figure class="save-job-form__inbug">
#           <icon data-delayed-url="https://static.licdn.com/sc/h/ercwkzy8m5jnkaliyweviswct" data-svg-class-name="save-job-form__inbug-icon"></icon>
#         </figure>
#         Save this job with your existing LinkedIn profile, or create a new one.
#
#           </h3>
#           <span class="email-input-page__body">
#
#         Your job seeking activity is only visible to you.
#
#           </span>
#
#     <div class="mt-1.5" data-js-module-id="guest-input">
#       <div class="flex flex-col">
#         <label class="input-label mb-1" for="public_jobs_save-job_email-input">
#           Email
#         </label>
#         <div class="text-input flex">
#           <input autocomplete="off" class="text-color-text font-sans text-md outline-0 bg-color-transparent grow" data-tracking-control-name="public_jobs_save-job_enter-email" id="public_jobs_save-job_email-input" name="email-input-page__input" placeholder="Email address" required="" type="text"/>
#
#         </div>
#       </div>
#
#       <p class="input-helper mt-1.5" data-js-module-id="guest-input__message" for="public_jobs_save-job_email-input" role="alert"></p>
#     </div>
#
#
#           <code id="email-input-page-error-message" style="display: none"><!--"Please enter a valid email address."--></code>
#         </div>
#
#         <footer class="save-job-form__footer">
#           <button class="save-job-form__button" data-tracking-control-name="public_jobs_save-job-form-continue" type="submit">
#             Continue
#           </button>
#         </footer>
#
#       </form>
#
#
#
#     <div class="welcome-back-sign-in-form welcome-back-sign-in-form--hidden" data-impression-id="save-job-sign-in-form">
#       <h3 class="welcome-back-sign-in-form__header">
#         Welcome back
#       </h3>
#
#         <p class="welcome-back-sign-in-form__subline">
#
#
#         Sign in to save <b>Data Engineer (remote)</b> at <b>Skylight</b>.
#
#
#         </p>
#
#
#
#
#
#
#
#
#
#
#
#
#     <code id="i18n_sign_in_form_show_text" style="display: none"><!--"Show"--></code>
#     <code id="i18n_sign_in_form_show_label" style="display: none"><!--"Show your LinkedIn password"--></code>
#     <code id="i18n_sign_in_form_hide_text" style="display: none"><!--"Hide"--></code>
#     <code id="i18n_sign_in_form_hide_label" style="display: none"><!--"Hide your LinkedIn password"--></code>
#
#
#     <code id="i18n_username_error_empty" style="display: none"><!--"Please enter an email address or phone number"--></code>
#
#     <code id="i18n_username_error_too_long" style="display: none"><!--"Email or phone number must be between 3 to 128 characters"--></code>
#     <code id="i18n_username_error_too_short" style="display: none"><!--"Email or phone number must be between 3 to 128 characters"--></code>
#
#
#     <code id="i18n_password_error_empty" style="display: none"><!--"Please enter a password"--></code>
#
#     <code id="i18n_password_error_too_short" style="display: none"><!--"The password you provided must have at least 6 characters"--></code>
#
#     <code id="i18n_password_error_too_long" style="display: none"><!--"The password you provided must have at most 400 characters"--></code>
#
#     <form action="https://www.linkedin.com/uas/login-submit" class="save-job-form-sign-in-form" data-id="sign-in-form" method="post" novalidate="">
#       <input name="loginCsrfParam" type="hidden" value="1dff9275-0459-46f3-8377-5524b63efd3f"/>
#
#       <div class="flex flex-col">
#
#     <div class="mt-1.5" data-js-module-id="guest-input">
#       <div class="flex flex-col">
#         <label class="input-label mb-1" for="session_key">
#           Email or phone
#         </label>
#         <div class="text-input flex">
#           <input autocomplete="username" class="text-color-text font-sans text-md outline-0 bg-color-transparent grow" id="session_key" name="session_key" required="" type="text"/>
#
#         </div>
#       </div>
#
#       <p class="input-helper mt-1.5" data-js-module-id="guest-input__message" for="session_key" role="alert"></p>
#     </div>
#
#
#
#     <div class="mt-1.5" data-js-module-id="guest-input">
#       <div class="flex flex-col">
#         <label class="input-label mb-1" for="session_password">
#           Password
#         </label>
#         <div class="text-input flex">
#           <input autocomplete="current-password" class="text-color-text font-sans text-md outline-0 bg-color-transparent grow" id="session_password" name="session_password" required="" type="password"/>
#
#             <button aria-label="Show your LinkedIn password" class="font-sans text-md font-bold text-color-action z-10 ml-[12px] hover:cursor-pointer" data-id="sign-in-form__password-visibility-toggle" data-tracking-control-name="public_jobs_save-job_sign-in-password-visibility-toggle-btn" type="button">Show</button>
#
#         </div>
#       </div>
#
#       <p class="input-helper mt-1.5" data-js-module-id="guest-input__message" for="session_password" role="alert"></p>
#     </div>
#
#
#         <input name="session_redirect" type="hidden" value="https://www.linkedin.com/jobs/view/data-engineer-remote-at-skylight-3317379575"/>
#
# <!---->      </div>
#
#       <div class="flex justify-between items-center mt-[16px]" data-id="sign-in-form__footer">
#         <a class="font-sans text-md font-bold link leading-regular" data-id="sign-in-form__forgot-password" data-tracking-control-name="public_jobs_save-job_forgot_password" data-tracking-will-navigate="" href="https://www.linkedin.com/uas/request-password-reset?trk=public_jobs_save-job_forgot_password">Forgot password?</a>
#
# <!---->
#         <input name="trk" type="hidden" value="public_jobs_save-job_sign-in-submit"/>
#         <button class="btn-md btn-primary !text-[20px] px-[24px] flex-shrink-0 cursor-pointer ml-[8px]" data-id="sign-in-form__submit-btn" data-tracking-control-name="public_jobs_save-job_sign-in-submit-btn" data-tracking-litms="" type="submit">
#           Sign in
#         </button>
#       </div>
#     </form>
#
#     </div>
#
#     </div>
#
#
#
#             </main>
#
# <!---->          </section>
#         </div>
#       </div>
#     </div>
#
#
#
#               </div>
#             </div>
#
# <!---->          </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#       <div class="ellipsis-menu absolute right-0 top-0 top-card-layout__ellipsis-menu mr-1 papabear:mt-0.5 papabear:mr-2">
#
#
#
#
#     <div class="collapsible-dropdown flex items-center relative hyphens-auto">
#
#             <button aria-expanded="false" aria-label="Open menu" class="ellipsis-menu__trigger collapsible-dropdown__button btn-md btn-tertiary cursor-pointer !py-[6px] !px-1 flex items-center rounded-[50%]" data-tracking-control-name="public_jobs_ellipsis-menu-trigger">
#               <icon class="ellipsis-menu__trigger-icon m-0 p-0 centered-icon" data-delayed-url="https://static.licdn.com/sc/h/671xosfpvk4c0kqtyl87hashi"></icon>
#             </button>
#
#
#         <ul class="collapsible-dropdown__list hidden container-raised absolute w-auto overflow-y-auto flex-col items-stretch z-1 bottom-auto top-[100%]" role="menu" tabindex="-1">
#
#
#
#                 <li class="ellipsis-menu__item border-t-1 border-solid border-color-border-low-emphasis first-of-type:border-none">
#                   <a class="ellipsis-menu__item-button flex items-center w-full p-1 cursor-pointer font-sans text-sm font-bold link-styled focus:link-styled link:no-underline active:bg-color-background-container-tint focus:bg-color-background-container-tint hover:bg-color-background-container-tint" data-tracking-control-name="public_jobs_ellipsis-menu-sign-in-redirect" data-tracking-will-navigate="" href="https://www.linkedin.com/login?session_redirect=https%3A%2F%2Fwww%2Elinkedin%2Ecom%2Fjobs%2Fview%2Fdata-engineer-remote-at-skylight-3317379575&amp;fromSignIn=true&amp;trk=public_jobs_ellipsis-menu-sign-in-redirect">
#                     <icon class="ellipsis-menu__item-icon text-color-text h-[24px] w-[24px] mr-1" data-delayed-url="https://static.licdn.com/sc/h/iq0x9q37wj214o129ai1yjut"></icon>
#                     Report this company
#                   </a>
#                 </li>
#
#         </ul>
#
# <!---->    </div>
#
#
#       </div>
#
#
# <!---->      </div>
#     </section>
#
#
#
#     <div class="decorated-job-posting__details">
# <!---->
#
#
#
#
#
#
#
#
#     <section class="core-section-container my-3 description">
# <!---->
# <!---->
# <!---->
#       <div class="core-section-container__content break-words">
#
# <!---->
#     <div class="description__text description__text--rich">
#
#     <section class="show-more-less-html" data-max-lines="5">
#       <div class="show-more-less-html__markup show-more-less-html__markup--clamp-after-5">
#         Skylight is at the forefront of a civic movement to reinvent how the government serves the public in a digital world.<br/><br/>We’re looking for a Data Engineer to join our talented team of technologists in driving this movement forward.<br/><br/>You’ll be a key part of our small, but rapidly growing team, which consists of former Presidential Innovation Fellows, founders of 18F, and members of the U.S. Digital Service.<br/><br/>We work in small, fast, agile teams to create exceptional customer experiences and enduring solutions out of the government’s most complex design and technology challenges. The work is challenging, but highly rewarding.<br/><br/><strong>Requirements<br/><br/></strong><strong>What you’ll do:<br/></strong><ul><li>Investigate, change, and modernize existing data systems, and build new ones, if necessary</li><li>Design and build data pipelines that transform data into usable formats</li><li>Write code to ensure the performance and reliability of data extraction and processing</li><li>Analyze systems to identify technical debt, instability, unreliability, and other opportunities for improvement, and design, document, and communicate solutions</li><li>Achieve technical excellence by advocating for and adhering to lean-agile engineering principles and practices such as API-first design, simple design, continuous integration, version control, and automated testing</li><li>Select and use the right tools, frameworks, languages, and technologies for the job, with a preference for open-source solutions</li><li>Collaborate with others as part of a cross-functional team that includes user experience researchers and designers, product managers, engineers, and other functional specialists</li><li>Represent Skylight's culture of delivery when interacting with government stakeholders and other contractors<br/><br/></li></ul><strong>What we’re looking for:<br/></strong><ul><li>In-depth knowledge of computer science</li><li>Experience as a backend engineer or data engineer</li><li>Expertise programming in languages such as Python or Java</li><li>Expertise with relational databases such as PostgreSQL</li><li>Expertise creating and consuming APIs</li><li>Excellent knowledge of relational and non-relational database systems</li><li>Proven ability to apply good software engineering principles and practices</li><li>Ability to select and use the right tools for the job, particularly open-source solutions</li><li>Ability to communicate clearly to technical and non-technical audiences</li><li>Experience working within a multidisciplinary, agile team format</li><li>A mindset and work approach that aligns with our core values</li><li>Ability to travel from time to time (when it's safe)<br/><br/></li></ul>Don’t meet 100% of the criteria but think you can do the job? We’d love to chat anyway! We’re on a mission to build diverse teams, and studies have shown that women and marginalized folks are less likely to apply to jobs if they don’t check every box.<br/><br/><strong>Benefits<br/><br/></strong>We focus on supporting you in a variety of ways:<br/><ul><li>Competitive salary</li><li>Medical insurance, dental insurance, vision insurance</li><li>Short-term and long-term disability insurance</li><li>Life and AD&amp;D insurance</li><li>Dependent care FSA, healthcare FSA, health savings account</li><li>Dollar-for-dollar 401(k) match up to 10% of your salary</li><li>Paid time off, including 15 accrued vacation days, 11 federal holidays, 5 floating holidays, and flexible sick leave</li><li>Minimum of 9 weeks paid time off for all eligible new birth, adoption, or foster parents</li><li>Performance rewards, including annual salary increase, annual performance bonus, spot bonuses, and stock options</li><li>Business development / sales bonuses</li><li>Referral bonuses</li><li>Annual $2,000 allowance for professional development</li><li>Annual $750 allowance for tech-related purchases</li><li>Annual swag budget of $100 to display your Sk ...
#       </div>
#
#
#
#
#
#
#
#     <button aria-expanded="false" aria-label="Show more, visually expands previously read content above" class="show-more-less-html__button show-more-less-html__button--more" data-tracking-control-name="public_jobs_show-more-html-btn">
#         Show more
#
#         <icon class="show-more-less-html__button-icon" data-delayed-url="https://static.licdn.com/sc/h/cyolgscd0imw2ldqppkrb84vo"></icon>
#     </button>
#
#
#
#
#
#
#
#
#     <button aria-expanded="true" aria-label="Show less" class="show-more-less-html__button show-more-less-html__button--less" data-tracking-control-name="public_jobs_show-less-html-btn">
#         Show less
#
#         <icon class="show-more-less-html__button-icon" data-delayed-url="https://static.licdn.com/sc/h/4chtt12k98xwnba1nimld2oyg"></icon>
#     </button>
#
#     </section>
#
#     </div>
#
#     <ul class="description__job-criteria-list">
#         <li class="description__job-criteria-item">
#           <h3 class="description__job-criteria-subheader">
#             Seniority level
#           </h3>
#           <span class="description__job-criteria-text description__job-criteria-text--criteria">
#             Mid-Senior level
#           </span>
#         </li>
#       <li class="description__job-criteria-item">
#         <h3 class="description__job-criteria-subheader">
#           Employment type
#         </h3>
#         <span class="description__job-criteria-text description__job-criteria-text--criteria">
#           Full-time
#         </span>
#       </li>
#         <li class="description__job-criteria-item">
#           <h3 class="description__job-criteria-subheader">
#             Job function
#           </h3>
#           <span class="description__job-criteria-text description__job-criteria-text--criteria">
#             Consulting
#           </span>
#         </li>
#         <li class="description__job-criteria-item">
#           <h3 class="description__job-criteria-subheader">
#             Industries
#           </h3>
#           <span class="description__job-criteria-text description__job-criteria-text--criteria">
#           Technology, Information and Internet
#           </span>
#         </li>
#     </ul>
#
#       </div>
#     </section>
#
#
#
#
#
#
#
#
#     <section class="core-section-container my-3 find-a-referral">
# <!---->
# <!---->
# <!---->
#       <div class="core-section-container__content break-words">
#
#
#
#     <div class="face-pile flex">
#       <div class="face-pile__images-container self-start flex-shrink-0 mr-1 leading-[1]">
#
#       <img alt="" class="inline-block relative rounded-[50%] w-4 h-4 face-pile__image border-1 border-solid border-color-transparent -ml-2 first:ml-0" data-delayed-url="https://static.licdn.com/sc/h/2idbv5yww3ifd3ug4r2gn2d68" data-ghost-classes="bg-color-entity-ghost-background" data-ghost-url="https://static.licdn.com/sc/h/9c8pery4andzj6ohjkjp54ma2"/>
#
#
# ...
#             <main class="modal__main w-full">
#
#
#
#
#
#
#
#     <form class="create-alert-form">
#       <div class="create-alert-form__body">
#         <p class="create-alert-form__header">Get email updates for new <strong class="break-word">Data Engineer</strong> jobs in <strong>Washington, DC</strong></p>
# <!---->
#
#
#     <section class="dismissable-input create-alert-form-input">
#       <input aria-label="Email address*" autocomplete="off" class="dismissable-input__input" data-tracking-control-name="public_jobs_create-alert-modal_create-alert-form_email-address_dismissable-input" maxlength="500" name="emailAddress" placeholder="Email address*" required="" type="email"/>
#
#         <button class="dismissable-input__button" data-tracking-control-name="public_jobs_create-alert-modal_create-alert-form_email-address_dismissable-input-clear" type="button">
#           <label class="sr-only">Dismiss</label>
#           <icon class="dismissable-input__button-icon" data-delayed-url="https://static.licdn.com/sc/h/cs55jggk4p3uqh9ozxdmpvjg7"></icon>
#         </button>
#     </section>
#
#
#
#
#               <input name="keywords" type="hidden" value="Data Engineer"/>
#               <input name="geo" type="hidden" value="urn:li:geo:104383890"/>
#               <input name="pageType" type="hidden" value="JOB_DETAILS"/>
#
#
#
#
#
#
#
#
#     <code id="i18n_create_alert_invalid_email" style="display: none"><!--"Please enter a valid email address"--></code>
#     <code id="i18n_generic_error_message" style="display: none"><!--"Your job alert couldn’t be created, please try again later."--></code>
#
#     <p class="create-alert-error-message create-alert-error-message--email" role="alert">
#       <icon class="create-alert-error-message__icon lazy-load"></icon>
#       <span class="create-alert-error-message__container">
#         <span class="create-alert-error-message__text"></span>
# <!---->      </span>
#     </p>
#
#
#         <p class="create-alert-form__agreement-links">
#           By creating this job alert, you agree to the LinkedIn <a class="create-alert-form__agreement-item-link" data-tracking-control-name="public_jobs_create-alert-modal_create-alert-form_user-agreement" data-tracking-will-navigate="" href="https://www.linkedin.com/legal/user-agreement?trk=public_jobs_create-alert-modal_create-alert-form_user-agreement" rel="noopener" target="_blank">User Agreement</a> and <a class="create-alert-form__agreement-item-link" data-tracking-control-name="public_jobs_create-alert-modal_create-alert-form_privacy-policy" data-tracking-will-navigate="" href="https://www.linkedin.com/legal/privacy-policy?trk=public_jobs_create-alert-modal_create-alert-form_privacy-policy" rel="noopener" target="_blank">Privacy Policy</a>. You can unsubscribe from these emails at any time.
#         </p>
#
#
#
#
#
#
#     <code id="i18n_create_alert_invalid_email" style="display: none"><!--"Please enter a valid email address"--></code>
#     <code id="i18n_generic_error_message" style="display: none"><!--"Your job alert couldn’t be created, please try again later."--></code>
#
#     <p class="create-alert-error-message create-alert-error-message--generic" role="alert">
#       <icon class="create-alert-error-message__icon lazy-load"></icon>
#       <span class="create-alert-error-message__container">
#         <span class="create-alert-error-message__text"></span>
#           <a class="create-alert-error-message__sign-in-link hidden" data-tracking-control-name="public_jobs_create-alert-modal_create-alert-form_over-limit-sign-in-link" data-tracking-will-navigate="" href="https://www.linkedin.com/login?session_redirect=https%3A%2F%2Fwww%2Elinkedin%2Ecom%2Fjobs%2Fview%2Fdata-engineer-remote-at-skylight-3317379575&amp;fromSignIn=true&amp;trk=public_jobs_create-alert-modal_create-alert-form_over-limit-sign-in-link">Sign in to create more</a>
#       </span>
#     </p>
#
#
#       </div>
#
#       <footer class="create-alert-form__footer">
#         <button class="create-alert-form__footer-button" data-tracking-control-name="public_jobs_create-alert-modal_create-alert-form_submit" type="submit">
#           Create job alert
#         </button>
#       </footer>
#     </form>
#
#
#
#
#
#
#
#
#
#
#
#
#     <div class="alert-activation-status alert-activation-status--hidden">
#       <div class="alert-activation-status__body">
#         <icon class="alert-activation-status__icon" data-delayed-url="https://static.licdn.com/sc/h/arff5hp08cd5tpj3viooy1sup"></icon>
#
#         <p class="alert-activation-status__headline">
#           Your job alert is set
#         </p>
#         <p class="alert-activation-status__subline">
#           Click the link in the email we sent to <span class="break-word" id="guest-email"></span> to verify your email address and activate your job alert.
#         </p>
#       </div>
#
#       <footer class="alert-activation-status__footer">
#         <button class="alert-activation-status__footer-button" data-tracking-control-name="public_jobs_create-alert-modal_alert-activation-status-close">
#           Done
#         </button>
#       </footer>
#     </div>
#
#
#
#
#
#
#
#
#     <div class="welcome-back-sign-in-form welcome-back-sign-in-form--hidden">
#       <h3 class="welcome-back-sign-in-form__header">
#         Welcome back
#       </h3>
#
#         <p class="welcome-back-sign-in-form__subline">
#
#         Sign in to create your job alert for <span class="create-alert-sign-in-form__query-info">Data Engineer</span> jobs in <span class="create-alert-sign-in-form__query-info">Washington, DC</span>.
#
#         </p>
#
#
#
#
#
#
#
#
#
#
#
#
#     <code id="i18n_sign_in_form_show_text" style="display: none"><!--"Show"--></code>
#     <code id="i18n_sign_in_form_show_label" style="display: none"><!--"Show your LinkedIn password"--></code>
#     <code id="i18n_sign_in_form_hide_text" style="display: none"><!--"Hide"--></code>
#     <code id="i18n_sign_in_form_hide_label" style="display: none"><!--"Hide your LinkedIn password"--></code>
#
#
#     <code id="i18n_username_error_empty" style="display: none"><!--"Please enter an email address or phone number"--></code>
#
#     <code id="i18n_username_error_too_long" style="display: none"><!--"Email or phone number must be between 3 to 128 characters"--></code>
#     <code id="i18n_username_error_too_short" style="display: none"><!--"Email or phone number must be between 3 to 128 characters"--></code>
#
#
#     <code id="i18n_password_error_empty" style="display: none"><!--"Please enter a password"--></code>
#
#     <code id="i18n_password_error_too_short" style="display: none"><!--"The password you provided must have at least 6 characters"--></code>
#
#     <code id="i18n_password_error_too_long" style="display: none"><!--"The password you provided must have at most 400 characters"--></code>
#
#     <form action="https://www.linkedin.com/uas/login-submit" class="create-alert-sign-in-form" data-id="sign-in-form" method="post" novalidate="">
#       <input name="loginCsrfParam" type="hidden" value="1dff9275-0459-46f3-8377-5524b63efd3f"/>
#
#       <div class="flex flex-col">
#
#     <div class="mt-1.5" data-js-module-id="guest-input">
#       <div class="flex flex-col">
#         <label class="input-label mb-1" for="session_key">
#           Email or phone
#         </label>
#         <div class="text-input flex">
#           <input autocomplete="username" class="text-color-text font-sans text-md outline-0 bg-color-transparent grow" id="session_key" name="session_key" required="" type="text"/>
#
#         </div>
#       </div>
#
#       <p class="input-helper mt-1.5" data-js-module-id="guest-input__message" for="session_key" role="alert"></p>
#     </div>
#
#
#
#     <div class="mt-1.5" data-js-module-id="guest-input">
#       <div class="flex flex-col">
#         <label class="input-label mb-1" for="session_password">
#           Password
#         </label>
#         <div class="text-input flex">
#           <input autocomplete="current-password" class="text-color-text font-sans text-md outline-0 bg-color-transparent grow" id="session_password" name="session_password" required="" type="password"/>
#
#             <button aria-label="Show your LinkedIn password" class="font-sans text-md font-bold text-color-action z-10 ml-[12px] hover:cursor-pointer" data-id="sign-in-form__password-visibility-toggle" data-tracking-control-name="public_jobs_create-alert-modal_sign-in-password-visibility-toggle-btn" type="button">Show</button>
#
#         </div>
#       </div>
#
#       <p class="input-helper mt-1.5" data-js-module-id="guest-input__message" for="session_password" role="alert"></p>
#     </div>
#
#
#         <input name="session_redirect" type="hidden" value="https://www.linkedin.com/jobs/view/3317379575/"/>
#
# <!---->      </div>
#
#       <div class="flex justify-between items-center mt-[16px]" data-id="sign-in-form__footer">
#         <a class="font-sans text-md font-bold link leading-regular" data-id="sign-in-form__forgot-password" data-tracking-control-name="public_jobs_create-alert-modal_forgot_password" data-tracking-will-navigate="" href="https://www.linkedin.com/uas/request-password-reset?trk=public_jobs_create-alert-modal_forgot_password">Forgot password?</a>
#
# <!---->
#         <input name="trk" type="hidden" value="public_jobs_create-alert-modal_sign-in-submit"/>
#         <button class="btn-md btn-primary !text-[20px] px-[24px] flex-shrink-0 cursor-pointer ml-[8px]" data-id="sign-in-form__submit-btn" data-tracking-control-name="public_jobs_create-alert-modal_sign-in-submit-btn" data-tracking-litms="" type="submit">
#           Sign in
#         </button>
#       </div>
#     </form>
#
#     </div>
#
#
#
#             </main>
#
# <!---->          </section>
#         </div>
#       </div>
#     </div>
#
#
#
# <!---->
#
#
#
#
#
#
#
#
#
#
#
#
#
#       <div aria-describedby="cta-modal-subheader" aria-labelledby="cta-modal-header" class="cta-modal overflow-hidden container-raised z-10 fixed bottom-3 right-3 min-h-[56px] w-[290px] p-2 opacity-0 invisible babybear:hidden" data-impression-id="public_jobs_cta-modal" role="dialog">
#           <h2 class="cta-modal__header text-xl leading-regular font-bold text-color-text mr-[28px]" id="cta-modal-header">You’re signed out</h2>
#
#           <h3 class="cta-modal__subheader text-md leading-open font-normal text-color-text mt-0.5" id="cta-modal-subheader">Sign in for the full experience.</h3>
#
#
#       <a class="cta-modal__primary-btn btn-md btn-primary inline-block !text-[20px] w-full mt-3 py-1.5 px-0.5 leading-[25px]" data-tracking-control-name="conversion-modal-signin" data-tracking-will-navigate="" href="https://www.linkedin.com/login?session_redirect=https%3A%2F%2Fwww%2Elinkedin%2Ecom%2Fjobs%2Fview%2Fdata-engineer-remote-at-skylight-3317379575&amp;fromSignIn=true&amp;trk=public_jobs_conversion-modal-signin">
#         Sign in
#       </a>
#
# <!---->        <a class="cta-modal__secondary-btn btn-md inline-block !text-[20px] w-full mt-1.5 py-1.5 leading-[25px] btn-secondary-emphasis px-0.5" data-tracking-control-name="conversion-modal-join" data-tracking-will-navigate="" href="https://www.linkedin.com/signup/cold-join?source=jobs_registration&amp;trk=public_jobs_conversion-modal-join&amp;session_redirect=https%3A%2F%2Fwww.linkedin.com%2Fjobs%2Fview%2F3317379575%2F">
#           Join now
#         </a>
#
# <!---->
#
#         <button aria-label="Dismiss" class="cta-modal__dismiss-btn absolute top-2 right-2 hover:cursor-pointer focus:outline focus:outline-2 focus:outline-color-action" data-tracking-control-name="public_jobs_dismiss">
#           <icon class="cta-modal__dismiss-icon block h-3 w-3 onload" data-delayed-url="https://static.licdn.com/sc/h/gs508lg3t2o81tq7pmcgn6m2"></icon>
#         </button>
#       </div>
#
#
#
#
#     <form action="https://www.linkedin.com/uas/login-submit" class="google-one-tap" method="post">
#       <input name="loginCsrfParam" type="hidden" value="1dff9275-0459-46f3-8377-5524b63efd3f"/>
#
#         <input name="session_redirect" type="hidden" value="https://www.linkedin.com/jobs/view/3317379575/"/>
#
#       <input name="trk" type="hidden" value="public_jobs_google-one-tap-submit"/>
#       <div class="google-one-tap__container" data-tracking-control-name="public_jobs_google-one-tap" id="google-one-tap__container"></div>
#
#
#     <div class="loader loader--full-screen">
#       <div class="loader__container mb-2 overflow-hidden">
#         <icon class="loader__icon inline-block loader__icon--default text-color-progress-loading" data-delayed-url="https://static.licdn.com/sc/h/ddi43qwelxeqjxdd45pe3fvs1" data-svg-class-name="loader__icon-svg--large fill-currentColor h-[60px] min-h-[60px] w-[60px] min-w-[60px]"></icon>
#       </div>
#     </div>
#
#     </form>
#
#
#
#
#
#     <div class="toasts fixed z-8 babybear:right-4 mamabear:right-4 papabear:min-h-[96px] top:auto bottom-4 left-4 papabear:w-[400px] toasts--bottom" id="toasts" type="bottom">
#
#
#     <template id="toast-template">
#       <div class="toast container-raised flex toast--bottom transition ease-accelerate duration-xxslow" data-id="toast" role="alert">
#         <div class="toast__message flex flex-1 babybear:items-center mamabear:items-center papabear:items-start py-2 px-1.5" data-id="toast__message">
#           <div class="toast__message-content-container" data-id="toast__message-content-container">
#             <p class="toast__message-content font-sans text-sm opacity-90 inline babybear:self-center mamabear:self-center papabear:self-start" data-id="toast__message-content"></p>
#           </div>
#         </div>
#         <button aria-label="Close" class="toast__dismiss-btn cursor-pointer babybear:self-center mamabear:self-center papabear:self-start pt-3 pb-2 papabear:py-2 pl-0.5 pr-0" data-id="toast__dismiss-btn">
#           <svg class="fill-color-icon" height="24" width="24"><path d="M13 4.32 9.31 8 13 11.69 11.69 13 8 9.31 4.31 13 3 11.69 6.69 8 3 4.31 4.31 3 8 6.69 11.68 3Z"></path></svg>
#         </button>
#       </div>
#     </template>
#       <template id="toast-icon-caution">
#         <icon class="text-color-icon-neutral toast__icon w-3 h-3 shrink-0 mr-2" data-delayed-url="https://static.licdn.com/sc/h/u6kgm8vi5s4rhtbgmjlphlp6"></icon>
#       </template>
#       <template id="toast-icon-error">
#         <icon class="text-color-icon-negative toast__icon w-3 h-3 shrink-0 mr-2" data-delayed-url="https://static.licdn.com/sc/h/2ffvlzyh9wb65459t9va8w2ph"></icon>
#       </template>
#       <template id="toast-icon-notify">
#         <icon class="text-color-icon-neutral toast__icon w-3 h-3 shrink-0 mr-2" data-delayed-url="https://static.licdn.com/sc/h/de23f5me7dfm17unsj9up4vga"></icon>
#       </template>
#       <template id="toast-icon-success">
#         <icon class="text-color-icon-positive toast__icon w-3 h-3 shrink-0 mr-2" data-delayed-url="https://static.licdn.com/sc/h/c44ryoszao52cyd0y87z7s0uf"></icon>
#       </template>
#     <template id="toast-cta">
#       <a class="toast__cta cta-link font-medium ml-0.5 text-sm text-inherit inline" target="_blank"></a>
#     </template>
#   </div>
#
#
#         <section id="json-refs">
#           <code id="requestSubdomain" style="display: none"><!--"www"--></code>
#           <code id="pageKey" style="display: none"><!--"d_jobs_guest_details"--></code>
#           <code id="guestApptivationPromoCooloffInMinutes" style="display: none"><!--"control"--></code>
#             <code id="isGoogleAutoLoginEnabled" style="display: none"><!--true--></code>
#         </section>
#
#
#             <script async="" src="https://static.licdn.com/sc/h/1f0o8asarfspok2zpu5dl86by"></script>
#
#           <script async="" defer="" src="https://static.licdn.com/sc/h/dvyr8x62dw3czwmnenn1843g"></script>
#
# <!---->
#           <script data-delayed-url="https://static.licdn.com/sc/h/98lptr8kagfxge22q7k1fps8" data-module-id="google-one-tap-lib"></script>
#
#
#
#
#   </body></html>

# %%
import base64
import email
file_path="..\\data\\test_data\\Your application to Data Engineer at Applicantz.eml"
with open(file_path, 'r', encoding = 'utf-8') as file:
    # decoded = base64.b64decode(file)
    
    # print("decoded: ", decoded)
    alphabet_soup = BeautifulSoup(file,"utf-8")
    print(alphabet_soup.find_all("X-LinkedIn-Template:"))
# Out:
# []

# %%
import email
def decode_mime_stuff(s):
    # print(s)
    if "=?" in s:
        # print(s)
        results =  u''.join(
            word.decode(encoding or 'utf8') if isinstance(word, bytes) else word
            for word, encoding in email.header.decode_header(s))
    else:
        results = s
    results = " ".join(results.replace("\n","").strip().split(" ")[3:])
    return results

test_text = "=?UTF-8?Q?You_applied_for_Data_Analyst_at_F=C4=93nom_Digital?="
parse_me = "You applied for Software Engineer at Simple Securities"
a = lambda x: decode_mime_stuff(x)
print(a(test_text))
print(a(parse_me))
# Out:
# Data Analyst at Fēnom Digital
# Butt Secks at Simple Securities

# %%
def decode_mime_stuff_2(s):
    return u''.join(
        word.decode(encoding or 'utf8') if isinstance(word, bytes) else word
        for word, encoding in email.header.decode_header(s))

decode_mime_stuff_2(test_text)
# Out:
# 'You applied for Data Analyst at Fēnom Digital'
